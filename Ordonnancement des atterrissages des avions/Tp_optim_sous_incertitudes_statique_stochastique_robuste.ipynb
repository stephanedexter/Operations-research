# %% [markdown]
# # TP d'optimisation sous incertitude - ENAC - M2RO - 2021
#
#
# ## Avant de commencer...
#
#
# L'implémentation sera faite en utilisant le langage de programmation <tt>python</tt> dans ce <tt>notebook</tt> et la bibliothèque <tt>pulp</tt> (https://pypi.org/project/PuLP/). Pour chaque question, un  squelette vous est fourni et doit être complété.
#
# <b>Il est attendu un compte rendu avec les réponses à toutes les questions (5 pages max) et la remise des codes via le notebook.</b>
#
#
# La cellule ci-dessous charge les librairies et effectue un test du bon fonctionnement de puLp. Si tout se passe bien, vous devez obtenir la sortie suivante:
#
# <tt> === Programme de test (ENAC) ===<br>
# Résolution d'un PLNE basique... Ok: x1 = 0.0, x2 = 2.0.<br>
# === Fin du programme === </tt>

# %%
# -*- encoding: utf-8 -*-

from __future__ import print_function

from airland import read_instance, read_scenarios
import pulp
from pulp import LpStatus

import argparse
import os
import sys
import verifier

import test_pulp
test_pulp.test_pulp()
# Out:
# === Programme de test (ENAC) ===
# Résolution d'un PLNE basique... Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mtds/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ecb783947e664dbe89e4ba85d178fbc4-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/ecb783947e664dbe89e4ba85d178fbc4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 12 COLUMNS
# At line 29 RHS
# At line 37 BOUNDS
# At line 38 ENDATA
# Problem MODEL has 7 rows, 2 columns and 14 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 0 (-7) rows, 0 (-2) columns and 0 (-14) elements
# Empty problem - 0 rows, 0 columns and 0 elements
# Optimal - objective value -2
# After Postsolve, objective -2, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective -2 - 0 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Ok: x1 = 0.0, x2 = 2.0.
# === Fin du programme ===
# /home/mtds/anaconda3/lib/python3.11/site-packages/pulp/pulp.py:1352: UserWarning: Spaces are not permitted in the name. Converted to '_'
#   warnings.warn("Spaces are not permitted in the name. Converted to '_'")

# %% [markdown]
# ## Le processus d'atterrissage d'un avion dans un aéroport
#
# La figure ci-dessous illustre les principes de contrôle de la navigation d'un avion commercial sur un exemple de vol Orly-Toulouse. Pendant le vol de croisière le contrôle est assuré par un centre de contrôle régional, par exemple Paris et Bordeaux sur les deux avant derniers tronçons. Ensuite la tour de contrôle de l'aéroport prend le relai pour le contrôle d'approche.
#
# Un avion $i$ entrant dans la zone de contrôle de l'aéroport à l'instant $a_i$ a une date d'atterrissage au plus tôt $e_i$ correspondant à la vitesse maximale qu'il peut atteindre et une date d'atterrissage au plus tard $d_i$ correspondant à la date d'atterrissage maximale possible compte-tenu du carburant disponible et de la possibilité de tourner en rond dans la zone d'attente. Par ailleurs, compte-tenu de sa vitesse de croisière, un avion a également une date d'atterrissage préférentielle $t_i$. En cas de violation de cette date préférentielle, des coûts unitaires en cas de retard  $g_i$ et en cas d'avance $h_i$ sont à payer. De plus, entre l'atterrissage de deux avions $i$ et $j$, un temps de séparation minimum noté $s_{ij}$ dépendant du type des deux appareils doit être respecté.
#
# Le rôle des contrôleurs aériens est d'attribuer à tout avion une date d'atterrissage effective $T_i\in[e_i,d_i]$ ainsi qu'une piste d'atterrissage (lorsque plusieurs sont disponibles). Il n'est pas toujours possible de choisir $T_i=t_i$ pour tout avion en raison de possibilités d'engorgement suite à des arrivées proches de différents avions.
#
# ![title](images/procedure-atterrissage.png)
# (Source: Cinq sur cinq numéro 15 - septembre 2016)
#
#
# ## 1. Le problème statique déterministe
#
# Le problème statique détermine consiste, à partir d'un ensemble d'avion donné $P$, dont toutes les caractéristiques sont supposées connues à l'avance, et d'un ensemble de piste d'atterrissages $R$, à trouver les dates d'atterrissage qui respectent les contraintes décrites dans la section précédente et qui minimisent la somme pondérée des coûts d'avance et de retard. Il s'agit d'un problème d'ordonnancement NP-difficile, étudié dans l'article de Beasley *et al.* [1].  Un ensemble d'instances du problème proposé par les auteurs de cet article est téléchargeable sur le site de la OR-library (ces instances sont égalements fournies dans l'archive du TP), une bibliothèque de problèmes classiques de Recherche Opérationnelle (http://people.brunel.ac.uk/%7Emastjjb/jeb/orlib/airlandinfo.html).
#
# <i> Exemple : Dans le cours 1, les données de l'instance "airland1.txt" à 10 avions et un exemple de solution  de coût total 1210 pour une seule piste d'atterrissage sont décrits.</i>
#
# Dans cet article, le problème est formulé comme un programme linéaire en nombre entiers (PLNE). Une version simplifiée <b> et incomplète </b> est proposée ci-dessous.
#
# En plus des paramètres déjà présentés, on introduit les variables de décisions binaires $x_{ij}$ qui indiquent que l'avion $i\in P$ atterrit avant l'avion $j\in P$ sur la même piste d'atterrissage et les variables binaires $y_{ir}$ qui indiquent que l'avion $i\in P$ atterrit sur la piste $r\in R$. On définit également des variables de décision continues : $T_i$ pour la date d'atterrissage de l'avion $i\in P$, $L_i$ pour le retard de l'avion $i\in P$, $E_i$ pour l'avance de l'avion $i\in P$ et $z$ pour l'objectif.
#
# \begin{align}
#   \min \quad & z\label{obj} & &\quad  (1) \\ % \sum_{i\in P} ( g_i L_i + h_u E_i ) \\
#   \mbox{s.c. } \quad & T_i \geq e_i & \forall i\in P &\quad (2)\\
#              &T_i \leq d_i & \forall i\in P&\quad  (3) \\
#              % &x_{ij}+x_{ji}  \leq 3 - y_{ir} - y_{jr} & \forall i,j\in P,i<j,\forall r\in R&\quad(4)\\
#              % &x_{ij}+x_{ji}  \geq y_{ir} + y_{jr} - 1 & \forall i,j\in P,i<j,\forall r\in R&\quad(5) \\
#              % & \sum_{r\in R} y_{ir} = 1 & \forall i\in P&\quad(6)\\
#              &T_j \geq T_i + s_{ij} x_{ij} - M_{ij} (1 - x_{ij} ) & \forall i,j\in P,i\neq j &\quad(4)\\
#              & L_i \geq T_i-t_i & \forall i\in P&\quad(5)\\
#              & E_i \geq t_i - T_i &\forall i \in P &\quad(6)\\
#              & x_{ij}\in\{0,1\} & \forall i,j\in P,i\neq j &\quad(7)\\
#              & y_{ir}\in\{0,1\} & \forall i \in P, \forall r\in R &\quad(8)\\
#              & L_i, E_i, T_i \geq 0 &  \forall i \in P &\quad(9)
# \end{align}
#
# Les contraintes (2),(3) indiquent qu'un avion ne peut atterrir avant sa date d'arrivée au plus tôt ou après sa date d'arrivée au plus tard. Les contraintes (5),(6)  définissent les retards et les avances. Les domaines de définition des variables de décisions sont donnés par (7),(8),(9).
#
# [1]: J.E. Beasley, M. Krishnamoorthy, Y.M. Sharaiha and
# D. Abramson. Scheduling aircraft landings - the static case, Transportation Science, vol.34, 2000, pp180-197 (https://core.ac.uk/download/pdf/337240.pdf).

# %% [markdown]
# Nous commençons par lire une instance du problème. Pour tester avec d'autres instances il suffit de mentionner un autre nom de fichier contenu dans le répertoire <tt>instance</tt> de l'archive fournie.

# %%
import io
instance_name = 'instances/airland3.txt'
instance = open(instance_name)

runways=3

P, F, A, E, L, T, S, G, H = read_instance(instance)
print('Nombre d\'avions P='+str(P))
print()
print('Nombre de pistes R='+str(P))
print()
print('Largeur de la fenêtre de fixation des dates d\'atterrissage F='+str(F))
print()
print('Dates d\'apparition des avions A='+str(A))
print()
print('Dates d\'atterrissage au plus tôt E='+str(E))
print()
print('Dates d\'atterrissage au plus tard L='+str(L))
print()
print('Dates d\'atterrissage préférentielles T='+str(T))
print()
print('Pénalités unitaires de retard G='+str(G))
print()
print('Pénalités unitaires d\'avance H='+str(H))
print()

P = range(P)
print('matrice des temps de séparation')
import numpy as np
print(np.array(S))
#for i in P:
#    print(S[i])

R = range(runways)
# Out:
# Nombre d'avions P=20
#
# Nombre de pistes R=20
#
# Largeur de la fenêtre de fixation des dates d'atterrissage F=10
#
# Dates d'apparition des avions A=[0, 82, 59, 28, 126, 20, 110, 23, 42, 42, 57, 39, 186, 175, 139, 235, 194, 162, 69, 76]
#
# Dates d'atterrissage au plus tôt E=[75, 157, 134, 103, 201, 95, 185, 98, 117, 117, 132, 114, 261, 250, 214, 310, 269, 237, 144, 151]
#
# Dates d'atterrissage au plus tard L=[486, 628, 561, 565, 735, 524, 664, 523, 578, 569, 615, 551, 834, 790, 688, 967, 818, 726, 607, 624]
#
# Dates d'atterrissage préférentielles T=[82, 197, 160, 117, 261, 106, 229, 108, 132, 130, 149, 126, 336, 316, 258, 409, 338, 287, 160, 169]
#
# Pénalités unitaires de retard G=[30.0, 10.0, 10.0, 30.0, 10.0, 30.0, 10.0, 30.0, 30.0, 30.0, 30.0, 30.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 30.0, 30.0]
#
# Pénalités unitaires d'avance H=[30.0, 10.0, 10.0, 30.0, 10.0, 30.0, 10.0, 30.0, 30.0, 30.0, 30.0, 30.0, 10.0, 10.0, 10.0, 10.0, 10.0, 10.0, 30.0, 30.0]
#
# matrice des temps de séparation
# [[99999    15    15     8    15     8    15     8     8     8     8     8
#      15    15    15    15    15    15     8     8]
#  [   15 99999     3    15     3    15     3    15    15    15    15    15
#       3     3     3     3     3     3    15    15]
#  [   15     3 99999    15     3    15     3    15    15    15    15    15
#       3     3     3     3     3     3    15    15]
#  [    8    15    15 99999    15     8    15     8     8     8     8     8
#      15    15    15    15    15    15     8     8]
#  [   15     3     3    15 99999    15     3    15    15    15    15    15
#       3     3     3     3     3     3    15    15]
#  [    8    15    15     8    15 99999    15     8     8     8     8     8
#      15    15    15    15    15    15     8     8]
#  [   15     3     3    15     3    15 99999    15    15    15    15    15
#       3     3     3     3     3     3    15    15]
#  [    8    15    15     8    15     8    15 99999     8     8     8     8
#      15    15    15    15    15    15     8     8]
#  [    8    15    15     8    15     8    15     8 99999     8     8     8
#      15    15    15    15    15    15     8     8]
#  [    8    15    15     8    15     8    15     8     8 99999     8     8
#      15    15    15    15    15    15     8     8]
#  [    8    15    15     8    15     8    15     8     8     8 99999     8
#      15    15    15    15    15    15     8     8]
#  [    8    15    15     8    15     8    15     8     8     8     8 99999
#      15    15    15    15    15    15     8     8]
#  [   15     3     3    15     3    15     3    15    15    15    15    15
#   99999     3     3     3     3     3    15    15]
#  [   15     3     3    15     3    15     3    15    15    15    15    15
#       3 99999     3     3     3     3    15    15]
#  [   15     3     3    15     3    15     3    15    15    15    15    15
#       3     3 99999     3     3     3    15    15]
#  [   15     3     3    15     3    15     3    15    15    15    15    15
#       3     3     3 99999     3     3    15    15]
#  [   15     3     3    15     3    15     3    15    15    15    15    15
#       3     3     3     3 99999     3    15    15]
#  [   15     3     3    15     3    15     3    15    15    15    15    15
#       3     3     3     3     3 99999    15    15]
#  [    8    15    15     8    15     8    15     8     8     8     8     8
#      15    15    15    15    15    15 99999     8]
#  [    8    15    15     8    15     8    15     8     8     8     8     8
#      15    15    15    15    15    15     8 99999]]

# %% [markdown]
# ### Question 1.1
#
# L'objectif du programme linéaire ci-dessus est de minimiser la somme pondérée des coûts liés aux avances et retard.
#
# <i>Ajouter une contrainte pour préciser l'expression de l'objectif $z$.</i>
#
#
# ### Question 1.2
#
# Le PLNE présenté ci-dessus est incomplet. En effet, il est possible que deux avions $i$ et $j$ ne soit pas séquencés ($x_{ij} = 0$ et $x_{ji} = 0$), ou bien qu'un avion ne soit affecté à aucune ou à plusieurs pistes ($y_{ir_1} = y_{ir_2} = 0$ ou $y_{ir_1} = y_{ir_2} = 1$).
#
# <i> Ajouter <b>2</b> contraintes afin de régler ces deux problèmes.
#
#
# ### Question 1.3
#
# <i>Expliquer la contrainte (4) en considérant que les $M_{ij}$ ont des valeurs très grandes. Quelle(s) bornes(s) peuvent être choisies pour les $M_{ij}$ afin d'obtenir un PLNE efficace et valide ?</i>
#
#
#
# ### Question 1.4
#
# <i> Programmer le PLNE ci-dessus avec la bibliothèque de modélisation PuLP en complétant la fonctoin <tt>get_problem_q1</tt> ci-dessous et tester le programme surles instances fournies. Donner un tableau avec pour chaque instance, la valeur objectif obtenue pour différents temps de calcul et différents nombres de pistes d'aterrissage. Qu'en concluez-vous sur l'impact de la taille de l'instance sur la résolution ?</i>

# %%
from pulp import lpDot, lpSum,\
     LpProblem, LpMinimize, \
     LpVariable, LpBinary, LpInteger

def get_problem_q1(**kargs):

    P = kargs['P']  # Liste d'avions (0, 1, 2, ..., N)
    R = kargs['R']  # Pistes d'atterrissage (0, 1, 2, ..., M)
    e = kargs['e']  # Dates d'atterrissage au plus tôt
    d = kargs['d']  # Dates d'atterrissage au plus tard
    t = kargs['t']  # Dates d'atterrissage préférentielles
    s = kargs['s']  # Délais de séparation
    g = kargs['g']  # Coûts unitaires de retard
    h = kargs['h']  # Coûts unitaires d'avance

    # -- Calcul des bigs M à faire !
    M = [[d[i]-e[j] for j in P] for i in P]

    # -- Création du problème
    problem = LpProblem("Ordonnancement des atterrissages - Le problème statique", LpMinimize)

    # -- Création des variables

    # T - Date d'atterrissage
    T = [LpVariable('T_{}'.format(i), e[i], d[i]) for i in P]

    # E - Avance de l'avion
    E = [LpVariable('E_{}'.format(i), 0) for i in P]
    # L - Retard de l'avion
    L = [LpVariable('L_{}'.format(i), 0) for i in P]

    # x - x_ij = 1 si l'avion i attérit avant l'avion j
    x = [[LpVariable('x_{}_{}'.format(i, j), cat=LpBinary) for j in P] for i in P]

    # y  - y_ir = 1 si l'avion i atterit sur la piste r
    y = [[LpVariable('y_{}_{}'.format(i, r), cat=LpBinary) for r in R] for i in P]

    # -- Création de l'objectif à faire !

    problem += lpDot(g, L) + lpDot(h, E)

    # -- Création des contraintes

    # Contraintes (2) et (3)
    # -> Inutiles car bornes données dans la création de T

    # Contraintes (4)
    for i in P:
        for j in filter(lambda x: x != i, P):
            problem += T[j] >= T[i] + s[i][j] * x[i][j] - M[i][j] * (1 - x[i][j])

    # Contraintes (5) et (6)
    for i in P:
        problem += L[i] >= T[i] - t[i]
        problem += E[i] >= t[i] - T[i]

    # Contraintes (7) - (9)
    # -> Inutiles car bornes données dans la création des variables
    
    # Contraintes (10) à ajouter !
    for i in P:
        for j in filter(lambda x: x != i, P):
            for r in R:
                problem += x[i][j] + x[j][i] >= y[i][r] + y[j][r] - 1

    # Contraintes d'affectation des avions aux pistes
    for i in P:
        problem += lpSum(y[i][r] for r in R) == 1

    
    print(problem)
    return problem

# %% [markdown]
# Construction des arguments pour la fonction get_problem et exécution de la méthode <tt>solve</tt> pour le solveur <tt>CBC</tt> (<i>Coin-or branch and cut</i>) avec <tt>msg=True</tt> activant l'affichage des sorties du solveur (vous pouvez voir le nombre de variables et de contraintes puis les inforemations sur les étapes de résolution). Un temps de calcul maximum peut être défini (ici 60 secondes). Faites varier ce temps pour voir la différence dans les solutions trouvées sur les différentes instances.

# %%
kargs = {'P': P, 'R': R, 'e': E, 'd': L, 't': T, 's': S, 'g': G, 'h': H}
problem = get_problem_q1(**kargs)
status = problem.solve(pulp.PULP_CBC_CMD(msg=False,maxSeconds=200))
# Out:
# Ordonnancement_des_atterrissages_-_Le_problème_statique:
# MINIMIZE
# 30.0*E_0 + 10.0*E_1 + 30.0*E_10 + 30.0*E_11 + 10.0*E_12 + 10.0*E_13 + 10.0*E_14 + 10.0*E_15 + 10.0*E_16 + 10.0*E_17 + 30.0*E_18 + 30.0*E_19 + 10.0*E_2 + 30.0*E_3 + 10.0*E_4 + 30.0*E_5 + 10.0*E_6 + 30.0*E_7 + 30.0*E_8 + 30.0*E_9 + 30.0*L_0 + 10.0*L_1 + 30.0*L_10 + 30.0*L_11 + 10.0*L_12 + 10.0*L_13 + 10.0*L_14 + 10.0*L_15 + 10.0*L_16 + 10.0*L_17 + 30.0*L_18 + 30.0*L_19 + 10.0*L_2 + 30.0*L_3 + 10.0*L_4 + 30.0*L_5 + 10.0*L_6 + 30.0*L_7 + 30.0*L_8 + 30.0*L_9 + 0.0
# SUBJECT TO
# _C1: - T_0 + T_1 - 344 x_0_1 >= -329
#
# _C2: - T_0 + T_2 - 367 x_0_2 >= -352
#
# _C3: - T_0 + T_3 - 391 x_0_3 >= -383
#
# _C4: - T_0 + T_4 - 300 x_0_4 >= -285
#
# _C5: - T_0 + T_5 - 399 x_0_5 >= -391
#
# _C6: - T_0 + T_6 - 316 x_0_6 >= -301
#
# _C7: - T_0 + T_7 - 396 x_0_7 >= -388
#
# _C8: - T_0 + T_8 - 377 x_0_8 >= -369
#
# _C9: - T_0 + T_9 - 377 x_0_9 >= -369
#
# _C10: - T_0 + T_10 - 362 x_0_10 >= -354
#
# _C11: - T_0 + T_11 - 380 x_0_11 >= -372
#
# _C12: - T_0 + T_12 - 240 x_0_12 >= -225
#
# _C13: - T_0 + T_13 - 251 x_0_13 >= -236
#
# _C14: - T_0 + T_14 - 287 x_0_14 >= -272
#
# _C15: - T_0 + T_15 - 191 x_0_15 >= -176
#
# _C16: - T_0 + T_16 - 232 x_0_16 >= -217
#
# _C17: - T_0 + T_17 - 264 x_0_17 >= -249
#
# _C18: - T_0 + T_18 - 350 x_0_18 >= -342
#
# _C19: - T_0 + T_19 - 343 x_0_19 >= -335
#
# _C20: T_0 - T_1 - 568 x_1_0 >= -553
#
# _C21: - T_1 + T_2 - 497 x_1_2 >= -494
#
# _C22: - T_1 + T_3 - 540 x_1_3 >= -525
#
# _C23: - T_1 + T_4 - 430 x_1_4 >= -427
#
# _C24: - T_1 + T_5 - 548 x_1_5 >= -533
#
# _C25: - T_1 + T_6 - 446 x_1_6 >= -443
#
# _C26: - T_1 + T_7 - 545 x_1_7 >= -530
#
# _C27: - T_1 + T_8 - 526 x_1_8 >= -511
#
# _C28: - T_1 + T_9 - 526 x_1_9 >= -511
#
# _C29: - T_1 + T_10 - 511 x_1_10 >= -496
#
# _C30: - T_1 + T_11 - 529 x_1_11 >= -514
#
# _C31: - T_1 + T_12 - 370 x_1_12 >= -367
#
# _C32: - T_1 + T_13 - 381 x_1_13 >= -378
#
# _C33: - T_1 + T_14 - 417 x_1_14 >= -414
#
# _C34: - T_1 + T_15 - 321 x_1_15 >= -318
#
# _C35: - T_1 + T_16 - 362 x_1_16 >= -359
#
# _C36: - T_1 + T_17 - 394 x_1_17 >= -391
#
# _C37: - T_1 + T_18 - 499 x_1_18 >= -484
#
# _C38: - T_1 + T_19 - 492 x_1_19 >= -477
#
# _C39: T_0 - T_2 - 501 x_2_0 >= -486
#
# _C40: T_1 - T_2 - 407 x_2_1 >= -404
#
# _C41: - T_2 + T_3 - 473 x_2_3 >= -458
#
# _C42: - T_2 + T_4 - 363 x_2_4 >= -360
#
# _C43: - T_2 + T_5 - 481 x_2_5 >= -466
#
# _C44: - T_2 + T_6 - 379 x_2_6 >= -376
#
# _C45: - T_2 + T_7 - 478 x_2_7 >= -463
#
# _C46: - T_2 + T_8 - 459 x_2_8 >= -444
#
# _C47: - T_2 + T_9 - 459 x_2_9 >= -444
#
# _C48: T_10 - T_2 - 444 x_2_10 >= -429
#
# _C49: T_11 - T_2 - 462 x_2_11 >= -447
#
# _C50: T_12 - T_2 - 303 x_2_12 >= -300
#
# _C51: T_13 - T_2 - 314 x_2_13 >= -311
#
# _C52: T_14 - T_2 - 350 x_2_14 >= -347
#
# _C53: T_15 - T_2 - 254 x_2_15 >= -251
#
# _C54: T_16 - T_2 - 295 x_2_16 >= -292
#
# _C55: T_17 - T_2 - 327 x_2_17 >= -324
#
# _C56: T_18 - T_2 - 432 x_2_18 >= -417
#
# _C57: T_19 - T_2 - 425 x_2_19 >= -410
#
# _C58: T_0 - T_3 - 498 x_3_0 >= -490
#
# _C59: T_1 - T_3 - 423 x_3_1 >= -408
#
# _C60: T_2 - T_3 - 446 x_3_2 >= -431
#
# _C61: - T_3 + T_4 - 379 x_3_4 >= -364
#
# _C62: - T_3 + T_5 - 478 x_3_5 >= -470
#
# _C63: - T_3 + T_6 - 395 x_3_6 >= -380
#
# _C64: - T_3 + T_7 - 475 x_3_7 >= -467
#
# _C65: - T_3 + T_8 - 456 x_3_8 >= -448
#
# _C66: - T_3 + T_9 - 456 x_3_9 >= -448
#
# _C67: T_10 - T_3 - 441 x_3_10 >= -433
#
# _C68: T_11 - T_3 - 459 x_3_11 >= -451
#
# _C69: T_12 - T_3 - 319 x_3_12 >= -304
#
# _C70: T_13 - T_3 - 330 x_3_13 >= -315
#
# _C71: T_14 - T_3 - 366 x_3_14 >= -351
#
# _C72: T_15 - T_3 - 270 x_3_15 >= -255
#
# _C73: T_16 - T_3 - 311 x_3_16 >= -296
#
# _C74: T_17 - T_3 - 343 x_3_17 >= -328
#
# _C75: T_18 - T_3 - 429 x_3_18 >= -421
#
# _C76: T_19 - T_3 - 422 x_3_19 >= -414
#
# _C77: T_0 - T_4 - 675 x_4_0 >= -660
#
# _C78: T_1 - T_4 - 581 x_4_1 >= -578
#
# _C79: T_2 - T_4 - 604 x_4_2 >= -601
#
# _C80: T_3 - T_4 - 647 x_4_3 >= -632
#
# _C81: - T_4 + T_5 - 655 x_4_5 >= -640
#
# _C82: - T_4 + T_6 - 553 x_4_6 >= -550
#
# _C83: - T_4 + T_7 - 652 x_4_7 >= -637
#
# _C84: - T_4 + T_8 - 633 x_4_8 >= -618
#
# _C85: - T_4 + T_9 - 633 x_4_9 >= -618
#
# _C86: T_10 - T_4 - 618 x_4_10 >= -603
#
# _C87: T_11 - T_4 - 636 x_4_11 >= -621
#
# _C88: T_12 - T_4 - 477 x_4_12 >= -474
#
# _C89: T_13 - T_4 - 488 x_4_13 >= -485
#
# _C90: T_14 - T_4 - 524 x_4_14 >= -521
#
# _C91: T_15 - T_4 - 428 x_4_15 >= -425
#
# _C92: T_16 - T_4 - 469 x_4_16 >= -466
#
# _C93: T_17 - T_4 - 501 x_4_17 >= -498
#
# _C94: T_18 - T_4 - 606 x_4_18 >= -591
#
# _C95: T_19 - T_4 - 599 x_4_19 >= -584
#
# _C96: T_0 - T_5 - 457 x_5_0 >= -449
#
# _C97: T_1 - T_5 - 382 x_5_1 >= -367
#
# _C98: T_2 - T_5 - 405 x_5_2 >= -390
#
# _C99: T_3 - T_5 - 429 x_5_3 >= -421
#
# _C100: T_4 - T_5 - 338 x_5_4 >= -323
#
# _C101: - T_5 + T_6 - 354 x_5_6 >= -339
#
# _C102: - T_5 + T_7 - 434 x_5_7 >= -426
#
# _C103: - T_5 + T_8 - 415 x_5_8 >= -407
#
# _C104: - T_5 + T_9 - 415 x_5_9 >= -407
#
# _C105: T_10 - T_5 - 400 x_5_10 >= -392
#
# _C106: T_11 - T_5 - 418 x_5_11 >= -410
#
# _C107: T_12 - T_5 - 278 x_5_12 >= -263
#
# _C108: T_13 - T_5 - 289 x_5_13 >= -274
#
# _C109: T_14 - T_5 - 325 x_5_14 >= -310
#
# _C110: T_15 - T_5 - 229 x_5_15 >= -214
#
# _C111: T_16 - T_5 - 270 x_5_16 >= -255
#
# _C112: T_17 - T_5 - 302 x_5_17 >= -287
#
# _C113: T_18 - T_5 - 388 x_5_18 >= -380
#
# _C114: T_19 - T_5 - 381 x_5_19 >= -373
#
# _C115: T_0 - T_6 - 604 x_6_0 >= -589
#
# _C116: T_1 - T_6 - 510 x_6_1 >= -507
#
# _C117: T_2 - T_6 - 533 x_6_2 >= -530
#
# _C118: T_3 - T_6 - 576 x_6_3 >= -561
#
# _C119: T_4 - T_6 - 466 x_6_4 >= -463
#
# _C120: T_5 - T_6 - 584 x_6_5 >= -569
#
# _C121: - T_6 + T_7 - 581 x_6_7 >= -566
#
# _C122: - T_6 + T_8 - 562 x_6_8 >= -547
#
# _C123: - T_6 + T_9 - 562 x_6_9 >= -547
#
# _C124: T_10 - T_6 - 547 x_6_10 >= -532
#
# _C125: T_11 - T_6 - 565 x_6_11 >= -550
#
# _C126: T_12 - T_6 - 406 x_6_12 >= -403
#
# _C127: T_13 - T_6 - 417 x_6_13 >= -414
#
# _C128: T_14 - T_6 - 453 x_6_14 >= -450
#
# _C129: T_15 - T_6 - 357 x_6_15 >= -354
#
# _C130: T_16 - T_6 - 398 x_6_16 >= -395
#
# _C131: T_17 - T_6 - 430 x_6_17 >= -427
#
# _C132: T_18 - T_6 - 535 x_6_18 >= -520
#
# _C133: T_19 - T_6 - 528 x_6_19 >= -513
#
# _C134: T_0 - T_7 - 456 x_7_0 >= -448
#
# _C135: T_1 - T_7 - 381 x_7_1 >= -366
#
# _C136: T_2 - T_7 - 404 x_7_2 >= -389
#
# _C137: T_3 - T_7 - 428 x_7_3 >= -420
#
# _C138: T_4 - T_7 - 337 x_7_4 >= -322
#
# _C139: T_5 - T_7 - 436 x_7_5 >= -428
#
# _C140: T_6 - T_7 - 353 x_7_6 >= -338
#
# _C141: - T_7 + T_8 - 414 x_7_8 >= -406
#
# _C142: - T_7 + T_9 - 414 x_7_9 >= -406
#
# _C143: T_10 - T_7 - 399 x_7_10 >= -391
#
# _C144: T_11 - T_7 - 417 x_7_11 >= -409
#
# _C145: T_12 - T_7 - 277 x_7_12 >= -262
#
# _C146: T_13 - T_7 - 288 x_7_13 >= -273
#
# _C147: T_14 - T_7 - 324 x_7_14 >= -309
#
# _C148: T_15 - T_7 - 228 x_7_15 >= -213
#
# _C149: T_16 - T_7 - 269 x_7_16 >= -254
#
# _C150: T_17 - T_7 - 301 x_7_17 >= -286
#
# _C151: T_18 - T_7 - 387 x_7_18 >= -379
#
# _C152: T_19 - T_7 - 380 x_7_19 >= -372
#
# _C153: T_0 - T_8 - 511 x_8_0 >= -503
#
# _C154: T_1 - T_8 - 436 x_8_1 >= -421
#
# _C155: T_2 - T_8 - 459 x_8_2 >= -444
#
# _C156: T_3 - T_8 - 483 x_8_3 >= -475
#
# _C157: T_4 - T_8 - 392 x_8_4 >= -377
#
# _C158: T_5 - T_8 - 491 x_8_5 >= -483
#
# _C159: T_6 - T_8 - 408 x_8_6 >= -393
#
# _C160: T_7 - T_8 - 488 x_8_7 >= -480
#
# _C161: - T_8 + T_9 - 469 x_8_9 >= -461
#
# _C162: T_10 - T_8 - 454 x_8_10 >= -446
#
# _C163: T_11 - T_8 - 472 x_8_11 >= -464
#
# _C164: T_12 - T_8 - 332 x_8_12 >= -317
#
# _C165: T_13 - T_8 - 343 x_8_13 >= -328
#
# _C166: T_14 - T_8 - 379 x_8_14 >= -364
#
# _C167: T_15 - T_8 - 283 x_8_15 >= -268
#
# _C168: T_16 - T_8 - 324 x_8_16 >= -309
#
# _C169: T_17 - T_8 - 356 x_8_17 >= -341
#
# _C170: T_18 - T_8 - 442 x_8_18 >= -434
#
# _C171: T_19 - T_8 - 435 x_8_19 >= -427
#
# _C172: T_0 - T_9 - 502 x_9_0 >= -494
#
# _C173: T_1 - T_9 - 427 x_9_1 >= -412
#
# _C174: T_2 - T_9 - 450 x_9_2 >= -435
#
# _C175: T_3 - T_9 - 474 x_9_3 >= -466
#
# _C176: T_4 - T_9 - 383 x_9_4 >= -368
#
# _C177: T_5 - T_9 - 482 x_9_5 >= -474
#
# _C178: T_6 - T_9 - 399 x_9_6 >= -384
#
# _C179: T_7 - T_9 - 479 x_9_7 >= -471
#
# _C180: T_8 - T_9 - 460 x_9_8 >= -452
#
# _C181: T_10 - T_9 - 445 x_9_10 >= -437
#
# _C182: T_11 - T_9 - 463 x_9_11 >= -455
#
# _C183: T_12 - T_9 - 323 x_9_12 >= -308
#
# _C184: T_13 - T_9 - 334 x_9_13 >= -319
#
# _C185: T_14 - T_9 - 370 x_9_14 >= -355
#
# _C186: T_15 - T_9 - 274 x_9_15 >= -259
#
# _C187: T_16 - T_9 - 315 x_9_16 >= -300
#
# _C188: T_17 - T_9 - 347 x_9_17 >= -332
#
# _C189: T_18 - T_9 - 433 x_9_18 >= -425
#
# _C190: T_19 - T_9 - 426 x_9_19 >= -418
#
# _C191: T_0 - T_10 - 548 x_10_0 >= -540
#
# _C192: T_1 - T_10 - 473 x_10_1 >= -458
#
# _C193: - T_10 + T_2 - 496 x_10_2 >= -481
#
# _C194: - T_10 + T_3 - 520 x_10_3 >= -512
#
# _C195: - T_10 + T_4 - 429 x_10_4 >= -414
#
# _C196: - T_10 + T_5 - 528 x_10_5 >= -520
#
# _C197: - T_10 + T_6 - 445 x_10_6 >= -430
#
# _C198: - T_10 + T_7 - 525 x_10_7 >= -517
#
# _C199: - T_10 + T_8 - 506 x_10_8 >= -498
#
# _C200: - T_10 + T_9 - 506 x_10_9 >= -498
#
# _C201: - T_10 + T_11 - 509 x_10_11 >= -501
#
# _C202: - T_10 + T_12 - 369 x_10_12 >= -354
#
# _C203: - T_10 + T_13 - 380 x_10_13 >= -365
#
# _C204: - T_10 + T_14 - 416 x_10_14 >= -401
#
# _C205: - T_10 + T_15 - 320 x_10_15 >= -305
#
# _C206: - T_10 + T_16 - 361 x_10_16 >= -346
#
# _C207: - T_10 + T_17 - 393 x_10_17 >= -378
#
# _C208: - T_10 + T_18 - 479 x_10_18 >= -471
#
# _C209: - T_10 + T_19 - 472 x_10_19 >= -464
#
# _C210: T_0 - T_11 - 484 x_11_0 >= -476
#
# _C211: T_1 - T_11 - 409 x_11_1 >= -394
#
# _C212: - T_11 + T_2 - 432 x_11_2 >= -417
#
# _C213: - T_11 + T_3 - 456 x_11_3 >= -448
#
# _C214: - T_11 + T_4 - 365 x_11_4 >= -350
#
# _C215: - T_11 + T_5 - 464 x_11_5 >= -456
#
# _C216: - T_11 + T_6 - 381 x_11_6 >= -366
#
# _C217: - T_11 + T_7 - 461 x_11_7 >= -453
#
# _C218: - T_11 + T_8 - 442 x_11_8 >= -434
#
# _C219: - T_11 + T_9 - 442 x_11_9 >= -434
#
# _C220: T_10 - T_11 - 427 x_11_10 >= -419
#
# _C221: - T_11 + T_12 - 305 x_11_12 >= -290
#
# _C222: - T_11 + T_13 - 316 x_11_13 >= -301
#
# _C223: - T_11 + T_14 - 352 x_11_14 >= -337
#
# _C224: - T_11 + T_15 - 256 x_11_15 >= -241
#
# _C225: - T_11 + T_16 - 297 x_11_16 >= -282
#
# _C226: - T_11 + T_17 - 329 x_11_17 >= -314
#
# _C227: - T_11 + T_18 - 415 x_11_18 >= -407
#
# _C228: - T_11 + T_19 - 408 x_11_19 >= -400
#
# _C229: T_0 - T_12 - 774 x_12_0 >= -759
#
# _C230: T_1 - T_12 - 680 x_12_1 >= -677
#
# _C231: - T_12 + T_2 - 703 x_12_2 >= -700
#
# _C232: - T_12 + T_3 - 746 x_12_3 >= -731
#
# _C233: - T_12 + T_4 - 636 x_12_4 >= -633
#
# _C234: - T_12 + T_5 - 754 x_12_5 >= -739
#
# _C235: - T_12 + T_6 - 652 x_12_6 >= -649
#
# _C236: - T_12 + T_7 - 751 x_12_7 >= -736
#
# _C237: - T_12 + T_8 - 732 x_12_8 >= -717
#
# _C238: - T_12 + T_9 - 732 x_12_9 >= -717
#
# _C239: T_10 - T_12 - 717 x_12_10 >= -702
#
# _C240: T_11 - T_12 - 735 x_12_11 >= -720
#
# _C241: - T_12 + T_13 - 587 x_12_13 >= -584
#
# _C242: - T_12 + T_14 - 623 x_12_14 >= -620
#
# _C243: - T_12 + T_15 - 527 x_12_15 >= -524
#
# _C244: - T_12 + T_16 - 568 x_12_16 >= -565
#
# _C245: - T_12 + T_17 - 600 x_12_17 >= -597
#
# _C246: - T_12 + T_18 - 705 x_12_18 >= -690
#
# _C247: - T_12 + T_19 - 698 x_12_19 >= -683
#
# _C248: T_0 - T_13 - 730 x_13_0 >= -715
#
# _C249: T_1 - T_13 - 636 x_13_1 >= -633
#
# _C250: - T_13 + T_2 - 659 x_13_2 >= -656
#
# _C251: - T_13 + T_3 - 702 x_13_3 >= -687
#
# _C252: - T_13 + T_4 - 592 x_13_4 >= -589
#
# _C253: - T_13 + T_5 - 710 x_13_5 >= -695
#
# _C254: - T_13 + T_6 - 608 x_13_6 >= -605
#
# _C255: - T_13 + T_7 - 707 x_13_7 >= -692
#
# _C256: - T_13 + T_8 - 688 x_13_8 >= -673
#
# _C257: - T_13 + T_9 - 688 x_13_9 >= -673
#
# _C258: T_10 - T_13 - 673 x_13_10 >= -658
#
# _C259: T_11 - T_13 - 691 x_13_11 >= -676
#
# _C260: T_12 - T_13 - 532 x_13_12 >= -529
#
# _C261: - T_13 + T_14 - 579 x_13_14 >= -576
#
# _C262: - T_13 + T_15 - 483 x_13_15 >= -480
#
# _C263: - T_13 + T_16 - 524 x_13_16 >= -521
#
# _C264: - T_13 + T_17 - 556 x_13_17 >= -553
#
# _C265: - T_13 + T_18 - 661 x_13_18 >= -646
#
# _C266: - T_13 + T_19 - 654 x_13_19 >= -639
#
# _C267: T_0 - T_14 - 628 x_14_0 >= -613
#
# _C268: T_1 - T_14 - 534 x_14_1 >= -531
#
# _C269: - T_14 + T_2 - 557 x_14_2 >= -554
#
# _C270: - T_14 + T_3 - 600 x_14_3 >= -585
#
# _C271: - T_14 + T_4 - 490 x_14_4 >= -487
#
# _C272: - T_14 + T_5 - 608 x_14_5 >= -593
#
# _C273: - T_14 + T_6 - 506 x_14_6 >= -503
#
# _C274: - T_14 + T_7 - 605 x_14_7 >= -590
#
# _C275: - T_14 + T_8 - 586 x_14_8 >= -571
#
# _C276: - T_14 + T_9 - 586 x_14_9 >= -571
#
# _C277: T_10 - T_14 - 571 x_14_10 >= -556
#
# _C278: T_11 - T_14 - 589 x_14_11 >= -574
#
# _C279: T_12 - T_14 - 430 x_14_12 >= -427
#
# _C280: T_13 - T_14 - 441 x_14_13 >= -438
#
# _C281: - T_14 + T_15 - 381 x_14_15 >= -378
#
# _C282: - T_14 + T_16 - 422 x_14_16 >= -419
#
# _C283: - T_14 + T_17 - 454 x_14_17 >= -451
#
# _C284: - T_14 + T_18 - 559 x_14_18 >= -544
#
# _C285: - T_14 + T_19 - 552 x_14_19 >= -537
#
# _C286: T_0 - T_15 - 907 x_15_0 >= -892
#
# _C287: T_1 - T_15 - 813 x_15_1 >= -810
#
# _C288: - T_15 + T_2 - 836 x_15_2 >= -833
#
# _C289: - T_15 + T_3 - 879 x_15_3 >= -864
#
# _C290: - T_15 + T_4 - 769 x_15_4 >= -766
#
# _C291: - T_15 + T_5 - 887 x_15_5 >= -872
#
# _C292: - T_15 + T_6 - 785 x_15_6 >= -782
#
# _C293: - T_15 + T_7 - 884 x_15_7 >= -869
#
# _C294: - T_15 + T_8 - 865 x_15_8 >= -850
#
# _C295: - T_15 + T_9 - 865 x_15_9 >= -850
#
# _C296: T_10 - T_15 - 850 x_15_10 >= -835
#
# _C297: T_11 - T_15 - 868 x_15_11 >= -853
#
# _C298: T_12 - T_15 - 709 x_15_12 >= -706
#
# _C299: T_13 - T_15 - 720 x_15_13 >= -717
#
# _C300: T_14 - T_15 - 756 x_15_14 >= -753
#
# _C301: - T_15 + T_16 - 701 x_15_16 >= -698
#
# _C302: - T_15 + T_17 - 733 x_15_17 >= -730
#
# _C303: - T_15 + T_18 - 838 x_15_18 >= -823
#
# _C304: - T_15 + T_19 - 831 x_15_19 >= -816
#
# _C305: T_0 - T_16 - 758 x_16_0 >= -743
#
# _C306: T_1 - T_16 - 664 x_16_1 >= -661
#
# _C307: - T_16 + T_2 - 687 x_16_2 >= -684
#
# _C308: - T_16 + T_3 - 730 x_16_3 >= -715
#
# _C309: - T_16 + T_4 - 620 x_16_4 >= -617
#
# _C310: - T_16 + T_5 - 738 x_16_5 >= -723
#
# _C311: - T_16 + T_6 - 636 x_16_6 >= -633
#
# _C312: - T_16 + T_7 - 735 x_16_7 >= -720
#
# _C313: - T_16 + T_8 - 716 x_16_8 >= -701
#
# _C314: - T_16 + T_9 - 716 x_16_9 >= -701
#
# _C315: T_10 - T_16 - 701 x_16_10 >= -686
#
# _C316: T_11 - T_16 - 719 x_16_11 >= -704
#
# _C317: T_12 - T_16 - 560 x_16_12 >= -557
#
# _C318: T_13 - T_16 - 571 x_16_13 >= -568
#
# _C319: T_14 - T_16 - 607 x_16_14 >= -604
#
# _C320: T_15 - T_16 - 511 x_16_15 >= -508
#
# _C321: - T_16 + T_17 - 584 x_16_17 >= -581
#
# _C322: - T_16 + T_18 - 689 x_16_18 >= -674
#
# _C323: - T_16 + T_19 - 682 x_16_19 >= -667
#
# _C324: T_0 - T_17 - 666 x_17_0 >= -651
#
# _C325: T_1 - T_17 - 572 x_17_1 >= -569
#
# _C326: - T_17 + T_2 - 595 x_17_2 >= -592
#
# _C327: - T_17 + T_3 - 638 x_17_3 >= -623
#
# _C328: - T_17 + T_4 - 528 x_17_4 >= -525
#
# _C329: - T_17 + T_5 - 646 x_17_5 >= -631
#
# _C330: - T_17 + T_6 - 544 x_17_6 >= -541
#
# _C331: - T_17 + T_7 - 643 x_17_7 >= -628
#
# _C332: - T_17 + T_8 - 624 x_17_8 >= -609
#
# _C333: - T_17 + T_9 - 624 x_17_9 >= -609
#
# _C334: T_10 - T_17 - 609 x_17_10 >= -594
#
# _C335: T_11 - T_17 - 627 x_17_11 >= -612
#
# _C336: T_12 - T_17 - 468 x_17_12 >= -465
#
# _C337: T_13 - T_17 - 479 x_17_13 >= -476
#
# _C338: T_14 - T_17 - 515 x_17_14 >= -512
#
# _C339: T_15 - T_17 - 419 x_17_15 >= -416
#
# _C340: T_16 - T_17 - 460 x_17_16 >= -457
#
# _C341: - T_17 + T_18 - 597 x_17_18 >= -582
#
# _C342: - T_17 + T_19 - 590 x_17_19 >= -575
#
# _C343: T_0 - T_18 - 540 x_18_0 >= -532
#
# _C344: T_1 - T_18 - 465 x_18_1 >= -450
#
# _C345: - T_18 + T_2 - 488 x_18_2 >= -473
#
# _C346: - T_18 + T_3 - 512 x_18_3 >= -504
#
# _C347: - T_18 + T_4 - 421 x_18_4 >= -406
#
# _C348: - T_18 + T_5 - 520 x_18_5 >= -512
#
# _C349: - T_18 + T_6 - 437 x_18_6 >= -422
#
# _C350: - T_18 + T_7 - 517 x_18_7 >= -509
#
# _C351: - T_18 + T_8 - 498 x_18_8 >= -490
#
# _C352: - T_18 + T_9 - 498 x_18_9 >= -490
#
# _C353: T_10 - T_18 - 483 x_18_10 >= -475
#
# _C354: T_11 - T_18 - 501 x_18_11 >= -493
#
# _C355: T_12 - T_18 - 361 x_18_12 >= -346
#
# _C356: T_13 - T_18 - 372 x_18_13 >= -357
#
# _C357: T_14 - T_18 - 408 x_18_14 >= -393
#
# _C358: T_15 - T_18 - 312 x_18_15 >= -297
#
# _C359: T_16 - T_18 - 353 x_18_16 >= -338
#
# _C360: T_17 - T_18 - 385 x_18_17 >= -370
#
# _C361: - T_18 + T_19 - 464 x_18_19 >= -456
#
# _C362: T_0 - T_19 - 557 x_19_0 >= -549
#
# _C363: T_1 - T_19 - 482 x_19_1 >= -467
#
# _C364: - T_19 + T_2 - 505 x_19_2 >= -490
#
# _C365: - T_19 + T_3 - 529 x_19_3 >= -521
#
# _C366: - T_19 + T_4 - 438 x_19_4 >= -423
#
# _C367: - T_19 + T_5 - 537 x_19_5 >= -529
#
# _C368: - T_19 + T_6 - 454 x_19_6 >= -439
#
# _C369: - T_19 + T_7 - 534 x_19_7 >= -526
#
# _C370: - T_19 + T_8 - 515 x_19_8 >= -507
#
# _C371: - T_19 + T_9 - 515 x_19_9 >= -507
#
# _C372: T_10 - T_19 - 500 x_19_10 >= -492
#
# _C373: T_11 - T_19 - 518 x_19_11 >= -510
#
# _C374: T_12 - T_19 - 378 x_19_12 >= -363
#
# _C375: T_13 - T_19 - 389 x_19_13 >= -374
#
# _C376: T_14 - T_19 - 425 x_19_14 >= -410
#
# _C377: T_15 - T_19 - 329 x_19_15 >= -314
#
# _C378: T_16 - T_19 - 370 x_19_16 >= -355
#
# _C379: T_17 - T_19 - 402 x_19_17 >= -387
#
# _C380: T_18 - T_19 - 488 x_19_18 >= -480
#
# _C381: L_0 - T_0 >= -82
#
# _C382: E_0 + T_0 >= 82
#
# _C383: L_1 - T_1 >= -197
#
# _C384: E_1 + T_1 >= 197
#
# _C385: L_2 - T_2 >= -160
#
# _C386: E_2 + T_2 >= 160
#
# _C387: L_3 - T_3 >= -117
#
# _C388: E_3 + T_3 >= 117
#
# _C389: L_4 - T_4 >= -261
#
# _C390: E_4 + T_4 >= 261
#
# _C391: L_5 - T_5 >= -106
#
# _C392: E_5 + T_5 >= 106
#
# _C393: L_6 - T_6 >= -229
#
# _C394: E_6 + T_6 >= 229
#
# _C395: L_7 - T_7 >= -108
#
# _C396: E_7 + T_7 >= 108
#
# _C397: L_8 - T_8 >= -132
#
# _C398: E_8 + T_8 >= 132
#
# _C399: L_9 - T_9 >= -130
#
# _C400: E_9 + T_9 >= 130
#
# _C401: L_10 - T_10 >= -149
#
# _C402: E_10 + T_10 >= 149
#
# _C403: L_11 - T_11 >= -126
#
# _C404: E_11 + T_11 >= 126
#
# _C405: L_12 - T_12 >= -336
#
# _C406: E_12 + T_12 >= 336
#
# _C407: L_13 - T_13 >= -316
#
# _C408: E_13 + T_13 >= 316
#
# _C409: L_14 - T_14 >= -258
#
# _C410: E_14 + T_14 >= 258
#
# _C411: L_15 - T_15 >= -409
#
# _C412: E_15 + T_15 >= 409
#
# _C413: L_16 - T_16 >= -338
#
# _C414: E_16 + T_16 >= 338
#
# _C415: L_17 - T_17 >= -287
#
# _C416: E_17 + T_17 >= 287
#
# _C417: L_18 - T_18 >= -160
#
# _C418: E_18 + T_18 >= 160
#
# _C419: L_19 - T_19 >= -169
#
# _C420: E_19 + T_19 >= 169
#
# _C421: x_0_1 + x_1_0 - y_0_0 - y_1_0 >= -1
#
# _C422: x_0_1 + x_1_0 - y_0_1 - y_1_1 >= -1
#
# _C423: x_0_1 + x_1_0 - y_0_2 - y_1_2 >= -1
#
# _C424: x_0_2 + x_2_0 - y_0_0 - y_2_0 >= -1
#
# _C425: x_0_2 + x_2_0 - y_0_1 - y_2_1 >= -1
#
# _C426: x_0_2 + x_2_0 - y_0_2 - y_2_2 >= -1
#
# _C427: x_0_3 + x_3_0 - y_0_0 - y_3_0 >= -1
#
# _C428: x_0_3 + x_3_0 - y_0_1 - y_3_1 >= -1
#
# _C429: x_0_3 + x_3_0 - y_0_2 - y_3_2 >= -1
#
# _C430: x_0_4 + x_4_0 - y_0_0 - y_4_0 >= -1
#
# _C431: x_0_4 + x_4_0 - y_0_1 - y_4_1 >= -1
#
# _C432: x_0_4 + x_4_0 - y_0_2 - y_4_2 >= -1
#
# _C433: x_0_5 + x_5_0 - y_0_0 - y_5_0 >= -1
#
# _C434: x_0_5 + x_5_0 - y_0_1 - y_5_1 >= -1
#
# _C435: x_0_5 + x_5_0 - y_0_2 - y_5_2 >= -1
#
# _C436: x_0_6 + x_6_0 - y_0_0 - y_6_0 >= -1
#
# _C437: x_0_6 + x_6_0 - y_0_1 - y_6_1 >= -1
#
# _C438: x_0_6 + x_6_0 - y_0_2 - y_6_2 >= -1
#
# _C439: x_0_7 + x_7_0 - y_0_0 - y_7_0 >= -1
#
# _C440: x_0_7 + x_7_0 - y_0_1 - y_7_1 >= -1
#
# _C441: x_0_7 + x_7_0 - y_0_2 - y_7_2 >= -1
#
# _C442: x_0_8 + x_8_0 - y_0_0 - y_8_0 >= -1
#
# _C443: x_0_8 + x_8_0 - y_0_1 - y_8_1 >= -1
#
# _C444: x_0_8 + x_8_0 - y_0_2 - y_8_2 >= -1
#
# _C445: x_0_9 + x_9_0 - y_0_0 - y_9_0 >= -1
#
# _C446: x_0_9 + x_9_0 - y_0_1 - y_9_1 >= -1
#
# _C447: x_0_9 + x_9_0 - y_0_2 - y_9_2 >= -1
#
# _C448: x_0_10 + x_10_0 - y_0_0 - y_10_0 >= -1
#
# _C449: x_0_10 + x_10_0 - y_0_1 - y_10_1 >= -1
#
# _C450: x_0_10 + x_10_0 - y_0_2 - y_10_2 >= -1
#
# _C451: x_0_11 + x_11_0 - y_0_0 - y_11_0 >= -1
#
# _C452: x_0_11 + x_11_0 - y_0_1 - y_11_1 >= -1
#
# _C453: x_0_11 + x_11_0 - y_0_2 - y_11_2 >= -1
#
# _C454: x_0_12 + x_12_0 - y_0_0 - y_12_0 >= -1
#
# _C455: x_0_12 + x_12_0 - y_0_1 - y_12_1 >= -1
#
# _C456: x_0_12 + x_12_0 - y_0_2 - y_12_2 >= -1
#
# _C457: x_0_13 + x_13_0 - y_0_0 - y_13_0 >= -1
#
# _C458: x_0_13 + x_13_0 - y_0_1 - y_13_1 >= -1
#
# _C459: x_0_13 + x_13_0 - y_0_2 - y_13_2 >= -1
#
# _C460: x_0_14 + x_14_0 - y_0_0 - y_14_0 >= -1
#
# _C461: x_0_14 + x_14_0 - y_0_1 - y_14_1 >= -1
#
# _C462: x_0_14 + x_14_0 - y_0_2 - y_14_2 >= -1
#
# _C463: x_0_15 + x_15_0 - y_0_0 - y_15_0 >= -1
#
# _C464: x_0_15 + x_15_0 - y_0_1 - y_15_1 >= -1
#
# _C465: x_0_15 + x_15_0 - y_0_2 - y_15_2 >= -1
#
# _C466: x_0_16 + x_16_0 - y_0_0 - y_16_0 >= -1
#
# _C467: x_0_16 + x_16_0 - y_0_1 - y_16_1 >= -1
#
# _C468: x_0_16 + x_16_0 - y_0_2 - y_16_2 >= -1
#
# _C469: x_0_17 + x_17_0 - y_0_0 - y_17_0 >= -1
#
# _C470: x_0_17 + x_17_0 - y_0_1 - y_17_1 >= -1
#
# _C471: x_0_17 + x_17_0 - y_0_2 - y_17_2 >= -1
#
# _C472: x_0_18 + x_18_0 - y_0_0 - y_18_0 >= -1
#
# _C473: x_0_18 + x_18_0 - y_0_1 - y_18_1 >= -1
#
# _C474: x_0_18 + x_18_0 - y_0_2 - y_18_2 >= -1
#
# _C475: x_0_19 + x_19_0 - y_0_0 - y_19_0 >= -1
#
# _C476: x_0_19 + x_19_0 - y_0_1 - y_19_1 >= -1
#
# _C477: x_0_19 + x_19_0 - y_0_2 - y_19_2 >= -1
#
# _C478: x_0_1 + x_1_0 - y_0_0 - y_1_0 >= -1
#
# _C479: x_0_1 + x_1_0 - y_0_1 - y_1_1 >= -1
#
# _C480: x_0_1 + x_1_0 - y_0_2 - y_1_2 >= -1
#
# _C481: x_1_2 + x_2_1 - y_1_0 - y_2_0 >= -1
#
# _C482: x_1_2 + x_2_1 - y_1_1 - y_2_1 >= -1
#
# _C483: x_1_2 + x_2_1 - y_1_2 - y_2_2 >= -1
#
# _C484: x_1_3 + x_3_1 - y_1_0 - y_3_0 >= -1
#
# _C485: x_1_3 + x_3_1 - y_1_1 - y_3_1 >= -1
#
# _C486: x_1_3 + x_3_1 - y_1_2 - y_3_2 >= -1
#
# _C487: x_1_4 + x_4_1 - y_1_0 - y_4_0 >= -1
#
# _C488: x_1_4 + x_4_1 - y_1_1 - y_4_1 >= -1
#
# _C489: x_1_4 + x_4_1 - y_1_2 - y_4_2 >= -1
#
# _C490: x_1_5 + x_5_1 - y_1_0 - y_5_0 >= -1
#
# _C491: x_1_5 + x_5_1 - y_1_1 - y_5_1 >= -1
#
# _C492: x_1_5 + x_5_1 - y_1_2 - y_5_2 >= -1
#
# _C493: x_1_6 + x_6_1 - y_1_0 - y_6_0 >= -1
#
# _C494: x_1_6 + x_6_1 - y_1_1 - y_6_1 >= -1
#
# _C495: x_1_6 + x_6_1 - y_1_2 - y_6_2 >= -1
#
# _C496: x_1_7 + x_7_1 - y_1_0 - y_7_0 >= -1
#
# _C497: x_1_7 + x_7_1 - y_1_1 - y_7_1 >= -1
#
# _C498: x_1_7 + x_7_1 - y_1_2 - y_7_2 >= -1
#
# _C499: x_1_8 + x_8_1 - y_1_0 - y_8_0 >= -1
#
# _C500: x_1_8 + x_8_1 - y_1_1 - y_8_1 >= -1
#
# _C501: x_1_8 + x_8_1 - y_1_2 - y_8_2 >= -1
#
# _C502: x_1_9 + x_9_1 - y_1_0 - y_9_0 >= -1
#
# _C503: x_1_9 + x_9_1 - y_1_1 - y_9_1 >= -1
#
# _C504: x_1_9 + x_9_1 - y_1_2 - y_9_2 >= -1
#
# _C505: x_10_1 + x_1_10 - y_10_0 - y_1_0 >= -1
#
# _C506: x_10_1 + x_1_10 - y_10_1 - y_1_1 >= -1
#
# _C507: x_10_1 + x_1_10 - y_10_2 - y_1_2 >= -1
#
# _C508: x_11_1 + x_1_11 - y_11_0 - y_1_0 >= -1
#
# _C509: x_11_1 + x_1_11 - y_11_1 - y_1_1 >= -1
#
# _C510: x_11_1 + x_1_11 - y_11_2 - y_1_2 >= -1
#
# _C511: x_12_1 + x_1_12 - y_12_0 - y_1_0 >= -1
#
# _C512: x_12_1 + x_1_12 - y_12_1 - y_1_1 >= -1
#
# _C513: x_12_1 + x_1_12 - y_12_2 - y_1_2 >= -1
#
# _C514: x_13_1 + x_1_13 - y_13_0 - y_1_0 >= -1
#
# _C515: x_13_1 + x_1_13 - y_13_1 - y_1_1 >= -1
#
# _C516: x_13_1 + x_1_13 - y_13_2 - y_1_2 >= -1
#
# _C517: x_14_1 + x_1_14 - y_14_0 - y_1_0 >= -1
#
# _C518: x_14_1 + x_1_14 - y_14_1 - y_1_1 >= -1
#
# _C519: x_14_1 + x_1_14 - y_14_2 - y_1_2 >= -1
#
# _C520: x_15_1 + x_1_15 - y_15_0 - y_1_0 >= -1
#
# _C521: x_15_1 + x_1_15 - y_15_1 - y_1_1 >= -1
#
# _C522: x_15_1 + x_1_15 - y_15_2 - y_1_2 >= -1
#
# _C523: x_16_1 + x_1_16 - y_16_0 - y_1_0 >= -1
#
# _C524: x_16_1 + x_1_16 - y_16_1 - y_1_1 >= -1
#
# _C525: x_16_1 + x_1_16 - y_16_2 - y_1_2 >= -1
#
# _C526: x_17_1 + x_1_17 - y_17_0 - y_1_0 >= -1
#
# _C527: x_17_1 + x_1_17 - y_17_1 - y_1_1 >= -1
#
# _C528: x_17_1 + x_1_17 - y_17_2 - y_1_2 >= -1
#
# _C529: x_18_1 + x_1_18 - y_18_0 - y_1_0 >= -1
#
# _C530: x_18_1 + x_1_18 - y_18_1 - y_1_1 >= -1
#
# _C531: x_18_1 + x_1_18 - y_18_2 - y_1_2 >= -1
#
# _C532: x_19_1 + x_1_19 - y_19_0 - y_1_0 >= -1
#
# _C533: x_19_1 + x_1_19 - y_19_1 - y_1_1 >= -1
#
# _C534: x_19_1 + x_1_19 - y_19_2 - y_1_2 >= -1
#
# _C535: x_0_2 + x_2_0 - y_0_0 - y_2_0 >= -1
#
# _C536: x_0_2 + x_2_0 - y_0_1 - y_2_1 >= -1
#
# _C537: x_0_2 + x_2_0 - y_0_2 - y_2_2 >= -1
#
# _C538: x_1_2 + x_2_1 - y_1_0 - y_2_0 >= -1
#
# _C539: x_1_2 + x_2_1 - y_1_1 - y_2_1 >= -1
#
# _C540: x_1_2 + x_2_1 - y_1_2 - y_2_2 >= -1
#
# _C541: x_2_3 + x_3_2 - y_2_0 - y_3_0 >= -1
#
# _C542: x_2_3 + x_3_2 - y_2_1 - y_3_1 >= -1
#
# _C543: x_2_3 + x_3_2 - y_2_2 - y_3_2 >= -1
#
# _C544: x_2_4 + x_4_2 - y_2_0 - y_4_0 >= -1
#
# _C545: x_2_4 + x_4_2 - y_2_1 - y_4_1 >= -1
#
# _C546: x_2_4 + x_4_2 - y_2_2 - y_4_2 >= -1
#
# _C547: x_2_5 + x_5_2 - y_2_0 - y_5_0 >= -1
#
# _C548: x_2_5 + x_5_2 - y_2_1 - y_5_1 >= -1
#
# _C549: x_2_5 + x_5_2 - y_2_2 - y_5_2 >= -1
#
# _C550: x_2_6 + x_6_2 - y_2_0 - y_6_0 >= -1
#
# _C551: x_2_6 + x_6_2 - y_2_1 - y_6_1 >= -1
#
# _C552: x_2_6 + x_6_2 - y_2_2 - y_6_2 >= -1
#
# _C553: x_2_7 + x_7_2 - y_2_0 - y_7_0 >= -1
#
# _C554: x_2_7 + x_7_2 - y_2_1 - y_7_1 >= -1
#
# _C555: x_2_7 + x_7_2 - y_2_2 - y_7_2 >= -1
#
# _C556: x_2_8 + x_8_2 - y_2_0 - y_8_0 >= -1
#
# _C557: x_2_8 + x_8_2 - y_2_1 - y_8_1 >= -1
#
# _C558: x_2_8 + x_8_2 - y_2_2 - y_8_2 >= -1
#
# _C559: x_2_9 + x_9_2 - y_2_0 - y_9_0 >= -1
#
# _C560: x_2_9 + x_9_2 - y_2_1 - y_9_1 >= -1
#
# _C561: x_2_9 + x_9_2 - y_2_2 - y_9_2 >= -1
#
# _C562: x_10_2 + x_2_10 - y_10_0 - y_2_0 >= -1
#
# _C563: x_10_2 + x_2_10 - y_10_1 - y_2_1 >= -1
#
# _C564: x_10_2 + x_2_10 - y_10_2 - y_2_2 >= -1
#
# _C565: x_11_2 + x_2_11 - y_11_0 - y_2_0 >= -1
#
# _C566: x_11_2 + x_2_11 - y_11_1 - y_2_1 >= -1
#
# _C567: x_11_2 + x_2_11 - y_11_2 - y_2_2 >= -1
#
# _C568: x_12_2 + x_2_12 - y_12_0 - y_2_0 >= -1
#
# _C569: x_12_2 + x_2_12 - y_12_1 - y_2_1 >= -1
#
# _C570: x_12_2 + x_2_12 - y_12_2 - y_2_2 >= -1
#
# _C571: x_13_2 + x_2_13 - y_13_0 - y_2_0 >= -1
#
# _C572: x_13_2 + x_2_13 - y_13_1 - y_2_1 >= -1
#
# _C573: x_13_2 + x_2_13 - y_13_2 - y_2_2 >= -1
#
# _C574: x_14_2 + x_2_14 - y_14_0 - y_2_0 >= -1
#
# _C575: x_14_2 + x_2_14 - y_14_1 - y_2_1 >= -1
#
# _C576: x_14_2 + x_2_14 - y_14_2 - y_2_2 >= -1
#
# _C577: x_15_2 + x_2_15 - y_15_0 - y_2_0 >= -1
#
# _C578: x_15_2 + x_2_15 - y_15_1 - y_2_1 >= -1
#
# _C579: x_15_2 + x_2_15 - y_15_2 - y_2_2 >= -1
#
# _C580: x_16_2 + x_2_16 - y_16_0 - y_2_0 >= -1
#
# _C581: x_16_2 + x_2_16 - y_16_1 - y_2_1 >= -1
#
# _C582: x_16_2 + x_2_16 - y_16_2 - y_2_2 >= -1
#
# _C583: x_17_2 + x_2_17 - y_17_0 - y_2_0 >= -1
#
# _C584: x_17_2 + x_2_17 - y_17_1 - y_2_1 >= -1
#
# _C585: x_17_2 + x_2_17 - y_17_2 - y_2_2 >= -1
#
# _C586: x_18_2 + x_2_18 - y_18_0 - y_2_0 >= -1
#
# _C587: x_18_2 + x_2_18 - y_18_1 - y_2_1 >= -1
#
# _C588: x_18_2 + x_2_18 - y_18_2 - y_2_2 >= -1
#
# _C589: x_19_2 + x_2_19 - y_19_0 - y_2_0 >= -1
#
# _C590: x_19_2 + x_2_19 - y_19_1 - y_2_1 >= -1
#
# _C591: x_19_2 + x_2_19 - y_19_2 - y_2_2 >= -1
#
# _C592: x_0_3 + x_3_0 - y_0_0 - y_3_0 >= -1
#
# _C593: x_0_3 + x_3_0 - y_0_1 - y_3_1 >= -1
#
# _C594: x_0_3 + x_3_0 - y_0_2 - y_3_2 >= -1
#
# _C595: x_1_3 + x_3_1 - y_1_0 - y_3_0 >= -1
#
# _C596: x_1_3 + x_3_1 - y_1_1 - y_3_1 >= -1
#
# _C597: x_1_3 + x_3_1 - y_1_2 - y_3_2 >= -1
#
# _C598: x_2_3 + x_3_2 - y_2_0 - y_3_0 >= -1
#
# _C599: x_2_3 + x_3_2 - y_2_1 - y_3_1 >= -1
#
# _C600: x_2_3 + x_3_2 - y_2_2 - y_3_2 >= -1
#
# _C601: x_3_4 + x_4_3 - y_3_0 - y_4_0 >= -1
#
# _C602: x_3_4 + x_4_3 - y_3_1 - y_4_1 >= -1
#
# _C603: x_3_4 + x_4_3 - y_3_2 - y_4_2 >= -1
#
# _C604: x_3_5 + x_5_3 - y_3_0 - y_5_0 >= -1
#
# _C605: x_3_5 + x_5_3 - y_3_1 - y_5_1 >= -1
#
# _C606: x_3_5 + x_5_3 - y_3_2 - y_5_2 >= -1
#
# _C607: x_3_6 + x_6_3 - y_3_0 - y_6_0 >= -1
#
# _C608: x_3_6 + x_6_3 - y_3_1 - y_6_1 >= -1
#
# _C609: x_3_6 + x_6_3 - y_3_2 - y_6_2 >= -1
#
# _C610: x_3_7 + x_7_3 - y_3_0 - y_7_0 >= -1
#
# _C611: x_3_7 + x_7_3 - y_3_1 - y_7_1 >= -1
#
# _C612: x_3_7 + x_7_3 - y_3_2 - y_7_2 >= -1
#
# _C613: x_3_8 + x_8_3 - y_3_0 - y_8_0 >= -1
#
# _C614: x_3_8 + x_8_3 - y_3_1 - y_8_1 >= -1
#
# _C615: x_3_8 + x_8_3 - y_3_2 - y_8_2 >= -1
#
# _C616: x_3_9 + x_9_3 - y_3_0 - y_9_0 >= -1
#
# _C617: x_3_9 + x_9_3 - y_3_1 - y_9_1 >= -1
#
# _C618: x_3_9 + x_9_3 - y_3_2 - y_9_2 >= -1
#
# _C619: x_10_3 + x_3_10 - y_10_0 - y_3_0 >= -1
#
# _C620: x_10_3 + x_3_10 - y_10_1 - y_3_1 >= -1
#
# _C621: x_10_3 + x_3_10 - y_10_2 - y_3_2 >= -1
#
# _C622: x_11_3 + x_3_11 - y_11_0 - y_3_0 >= -1
#
# _C623: x_11_3 + x_3_11 - y_11_1 - y_3_1 >= -1
#
# _C624: x_11_3 + x_3_11 - y_11_2 - y_3_2 >= -1
#
# _C625: x_12_3 + x_3_12 - y_12_0 - y_3_0 >= -1
#
# _C626: x_12_3 + x_3_12 - y_12_1 - y_3_1 >= -1
#
# _C627: x_12_3 + x_3_12 - y_12_2 - y_3_2 >= -1
#
# _C628: x_13_3 + x_3_13 - y_13_0 - y_3_0 >= -1
#
# _C629: x_13_3 + x_3_13 - y_13_1 - y_3_1 >= -1
#
# _C630: x_13_3 + x_3_13 - y_13_2 - y_3_2 >= -1
#
# _C631: x_14_3 + x_3_14 - y_14_0 - y_3_0 >= -1
#
# _C632: x_14_3 + x_3_14 - y_14_1 - y_3_1 >= -1
#
# _C633: x_14_3 + x_3_14 - y_14_2 - y_3_2 >= -1
#
# _C634: x_15_3 + x_3_15 - y_15_0 - y_3_0 >= -1
#
# _C635: x_15_3 + x_3_15 - y_15_1 - y_3_1 >= -1
#
# _C636: x_15_3 + x_3_15 - y_15_2 - y_3_2 >= -1
#
# _C637: x_16_3 + x_3_16 - y_16_0 - y_3_0 >= -1
#
# _C638: x_16_3 + x_3_16 - y_16_1 - y_3_1 >= -1
#
# _C639: x_16_3 + x_3_16 - y_16_2 - y_3_2 >= -1
#
# _C640: x_17_3 + x_3_17 - y_17_0 - y_3_0 >= -1
#
# _C641: x_17_3 + x_3_17 - y_17_1 - y_3_1 >= -1
#
# _C642: x_17_3 + x_3_17 - y_17_2 - y_3_2 >= -1
#
# _C643: x_18_3 + x_3_18 - y_18_0 - y_3_0 >= -1
#
# _C644: x_18_3 + x_3_18 - y_18_1 - y_3_1 >= -1
#
# _C645: x_18_3 + x_3_18 - y_18_2 - y_3_2 >= -1
#
# _C646: x_19_3 + x_3_19 - y_19_0 - y_3_0 >= -1
#
# _C647: x_19_3 + x_3_19 - y_19_1 - y_3_1 >= -1
#
# _C648: x_19_3 + x_3_19 - y_19_2 - y_3_2 >= -1
#
# _C649: x_0_4 + x_4_0 - y_0_0 - y_4_0 >= -1
#
# _C650: x_0_4 + x_4_0 - y_0_1 - y_4_1 >= -1
#
# _C651: x_0_4 + x_4_0 - y_0_2 - y_4_2 >= -1
#
# _C652: x_1_4 + x_4_1 - y_1_0 - y_4_0 >= -1
#
# _C653: x_1_4 + x_4_1 - y_1_1 - y_4_1 >= -1
#
# _C654: x_1_4 + x_4_1 - y_1_2 - y_4_2 >= -1
#
# _C655: x_2_4 + x_4_2 - y_2_0 - y_4_0 >= -1
#
# _C656: x_2_4 + x_4_2 - y_2_1 - y_4_1 >= -1
#
# _C657: x_2_4 + x_4_2 - y_2_2 - y_4_2 >= -1
#
# _C658: x_3_4 + x_4_3 - y_3_0 - y_4_0 >= -1
#
# _C659: x_3_4 + x_4_3 - y_3_1 - y_4_1 >= -1
#
# _C660: x_3_4 + x_4_3 - y_3_2 - y_4_2 >= -1
#
# _C661: x_4_5 + x_5_4 - y_4_0 - y_5_0 >= -1
#
# _C662: x_4_5 + x_5_4 - y_4_1 - y_5_1 >= -1
#
# _C663: x_4_5 + x_5_4 - y_4_2 - y_5_2 >= -1
#
# _C664: x_4_6 + x_6_4 - y_4_0 - y_6_0 >= -1
#
# _C665: x_4_6 + x_6_4 - y_4_1 - y_6_1 >= -1
#
# _C666: x_4_6 + x_6_4 - y_4_2 - y_6_2 >= -1
#
# _C667: x_4_7 + x_7_4 - y_4_0 - y_7_0 >= -1
#
# _C668: x_4_7 + x_7_4 - y_4_1 - y_7_1 >= -1
#
# _C669: x_4_7 + x_7_4 - y_4_2 - y_7_2 >= -1
#
# _C670: x_4_8 + x_8_4 - y_4_0 - y_8_0 >= -1
#
# _C671: x_4_8 + x_8_4 - y_4_1 - y_8_1 >= -1
#
# _C672: x_4_8 + x_8_4 - y_4_2 - y_8_2 >= -1
#
# _C673: x_4_9 + x_9_4 - y_4_0 - y_9_0 >= -1
#
# _C674: x_4_9 + x_9_4 - y_4_1 - y_9_1 >= -1
#
# _C675: x_4_9 + x_9_4 - y_4_2 - y_9_2 >= -1
#
# _C676: x_10_4 + x_4_10 - y_10_0 - y_4_0 >= -1
#
# _C677: x_10_4 + x_4_10 - y_10_1 - y_4_1 >= -1
#
# _C678: x_10_4 + x_4_10 - y_10_2 - y_4_2 >= -1
#
# _C679: x_11_4 + x_4_11 - y_11_0 - y_4_0 >= -1
#
# _C680: x_11_4 + x_4_11 - y_11_1 - y_4_1 >= -1
#
# _C681: x_11_4 + x_4_11 - y_11_2 - y_4_2 >= -1
#
# _C682: x_12_4 + x_4_12 - y_12_0 - y_4_0 >= -1
#
# _C683: x_12_4 + x_4_12 - y_12_1 - y_4_1 >= -1
#
# _C684: x_12_4 + x_4_12 - y_12_2 - y_4_2 >= -1
#
# _C685: x_13_4 + x_4_13 - y_13_0 - y_4_0 >= -1
#
# _C686: x_13_4 + x_4_13 - y_13_1 - y_4_1 >= -1
#
# _C687: x_13_4 + x_4_13 - y_13_2 - y_4_2 >= -1
#
# _C688: x_14_4 + x_4_14 - y_14_0 - y_4_0 >= -1
#
# _C689: x_14_4 + x_4_14 - y_14_1 - y_4_1 >= -1
#
# _C690: x_14_4 + x_4_14 - y_14_2 - y_4_2 >= -1
#
# _C691: x_15_4 + x_4_15 - y_15_0 - y_4_0 >= -1
#
# _C692: x_15_4 + x_4_15 - y_15_1 - y_4_1 >= -1
#
# _C693: x_15_4 + x_4_15 - y_15_2 - y_4_2 >= -1
#
# _C694: x_16_4 + x_4_16 - y_16_0 - y_4_0 >= -1
#
# _C695: x_16_4 + x_4_16 - y_16_1 - y_4_1 >= -1
#
# _C696: x_16_4 + x_4_16 - y_16_2 - y_4_2 >= -1
#
# _C697: x_17_4 + x_4_17 - y_17_0 - y_4_0 >= -1
#
# _C698: x_17_4 + x_4_17 - y_17_1 - y_4_1 >= -1
#
# _C699: x_17_4 + x_4_17 - y_17_2 - y_4_2 >= -1
#
# _C700: x_18_4 + x_4_18 - y_18_0 - y_4_0 >= -1
#
# _C701: x_18_4 + x_4_18 - y_18_1 - y_4_1 >= -1
#
# _C702: x_18_4 + x_4_18 - y_18_2 - y_4_2 >= -1
#
# _C703: x_19_4 + x_4_19 - y_19_0 - y_4_0 >= -1
#
# _C704: x_19_4 + x_4_19 - y_19_1 - y_4_1 >= -1
#
# _C705: x_19_4 + x_4_19 - y_19_2 - y_4_2 >= -1
#
# _C706: x_0_5 + x_5_0 - y_0_0 - y_5_0 >= -1
#
# _C707: x_0_5 + x_5_0 - y_0_1 - y_5_1 >= -1
#
# _C708: x_0_5 + x_5_0 - y_0_2 - y_5_2 >= -1
#
# _C709: x_1_5 + x_5_1 - y_1_0 - y_5_0 >= -1
#
# _C710: x_1_5 + x_5_1 - y_1_1 - y_5_1 >= -1
#
# _C711: x_1_5 + x_5_1 - y_1_2 - y_5_2 >= -1
#
# _C712: x_2_5 + x_5_2 - y_2_0 - y_5_0 >= -1
#
# _C713: x_2_5 + x_5_2 - y_2_1 - y_5_1 >= -1
#
# _C714: x_2_5 + x_5_2 - y_2_2 - y_5_2 >= -1
#
# _C715: x_3_5 + x_5_3 - y_3_0 - y_5_0 >= -1
#
# _C716: x_3_5 + x_5_3 - y_3_1 - y_5_1 >= -1
#
# _C717: x_3_5 + x_5_3 - y_3_2 - y_5_2 >= -1
#
# _C718: x_4_5 + x_5_4 - y_4_0 - y_5_0 >= -1
#
# _C719: x_4_5 + x_5_4 - y_4_1 - y_5_1 >= -1
#
# _C720: x_4_5 + x_5_4 - y_4_2 - y_5_2 >= -1
#
# _C721: x_5_6 + x_6_5 - y_5_0 - y_6_0 >= -1
#
# _C722: x_5_6 + x_6_5 - y_5_1 - y_6_1 >= -1
#
# _C723: x_5_6 + x_6_5 - y_5_2 - y_6_2 >= -1
#
# _C724: x_5_7 + x_7_5 - y_5_0 - y_7_0 >= -1
#
# _C725: x_5_7 + x_7_5 - y_5_1 - y_7_1 >= -1
#
# _C726: x_5_7 + x_7_5 - y_5_2 - y_7_2 >= -1
#
# _C727: x_5_8 + x_8_5 - y_5_0 - y_8_0 >= -1
#
# _C728: x_5_8 + x_8_5 - y_5_1 - y_8_1 >= -1
#
# _C729: x_5_8 + x_8_5 - y_5_2 - y_8_2 >= -1
#
# _C730: x_5_9 + x_9_5 - y_5_0 - y_9_0 >= -1
#
# _C731: x_5_9 + x_9_5 - y_5_1 - y_9_1 >= -1
#
# _C732: x_5_9 + x_9_5 - y_5_2 - y_9_2 >= -1
#
# _C733: x_10_5 + x_5_10 - y_10_0 - y_5_0 >= -1
#
# _C734: x_10_5 + x_5_10 - y_10_1 - y_5_1 >= -1
#
# _C735: x_10_5 + x_5_10 - y_10_2 - y_5_2 >= -1
#
# _C736: x_11_5 + x_5_11 - y_11_0 - y_5_0 >= -1
#
# _C737: x_11_5 + x_5_11 - y_11_1 - y_5_1 >= -1
#
# _C738: x_11_5 + x_5_11 - y_11_2 - y_5_2 >= -1
#
# _C739: x_12_5 + x_5_12 - y_12_0 - y_5_0 >= -1
#
# _C740: x_12_5 + x_5_12 - y_12_1 - y_5_1 >= -1
#
# _C741: x_12_5 + x_5_12 - y_12_2 - y_5_2 >= -1
#
# _C742: x_13_5 + x_5_13 - y_13_0 - y_5_0 >= -1
#
# _C743: x_13_5 + x_5_13 - y_13_1 - y_5_1 >= -1
#
# _C744: x_13_5 + x_5_13 - y_13_2 - y_5_2 >= -1
#
# _C745: x_14_5 + x_5_14 - y_14_0 - y_5_0 >= -1
#
# _C746: x_14_5 + x_5_14 - y_14_1 - y_5_1 >= -1
#
# _C747: x_14_5 + x_5_14 - y_14_2 - y_5_2 >= -1
#
# _C748: x_15_5 + x_5_15 - y_15_0 - y_5_0 >= -1
#
# _C749: x_15_5 + x_5_15 - y_15_1 - y_5_1 >= -1
#
# _C750: x_15_5 + x_5_15 - y_15_2 - y_5_2 >= -1
#
# _C751: x_16_5 + x_5_16 - y_16_0 - y_5_0 >= -1
#
# _C752: x_16_5 + x_5_16 - y_16_1 - y_5_1 >= -1
#
# _C753: x_16_5 + x_5_16 - y_16_2 - y_5_2 >= -1
#
# _C754: x_17_5 + x_5_17 - y_17_0 - y_5_0 >= -1
#
# _C755: x_17_5 + x_5_17 - y_17_1 - y_5_1 >= -1
#
# _C756: x_17_5 + x_5_17 - y_17_2 - y_5_2 >= -1
#
# _C757: x_18_5 + x_5_18 - y_18_0 - y_5_0 >= -1
#
# _C758: x_18_5 + x_5_18 - y_18_1 - y_5_1 >= -1
#
# _C759: x_18_5 + x_5_18 - y_18_2 - y_5_2 >= -1
#
# _C760: x_19_5 + x_5_19 - y_19_0 - y_5_0 >= -1
#
# _C761: x_19_5 + x_5_19 - y_19_1 - y_5_1 >= -1
#
# _C762: x_19_5 + x_5_19 - y_19_2 - y_5_2 >= -1
#
# _C763: x_0_6 + x_6_0 - y_0_0 - y_6_0 >= -1
#
# _C764: x_0_6 + x_6_0 - y_0_1 - y_6_1 >= -1
#
# _C765: x_0_6 + x_6_0 - y_0_2 - y_6_2 >= -1
#
# _C766: x_1_6 + x_6_1 - y_1_0 - y_6_0 >= -1
#
# _C767: x_1_6 + x_6_1 - y_1_1 - y_6_1 >= -1
#
# _C768: x_1_6 + x_6_1 - y_1_2 - y_6_2 >= -1
#
# _C769: x_2_6 + x_6_2 - y_2_0 - y_6_0 >= -1
#
# _C770: x_2_6 + x_6_2 - y_2_1 - y_6_1 >= -1
#
# _C771: x_2_6 + x_6_2 - y_2_2 - y_6_2 >= -1
#
# _C772: x_3_6 + x_6_3 - y_3_0 - y_6_0 >= -1
#
# _C773: x_3_6 + x_6_3 - y_3_1 - y_6_1 >= -1
#
# _C774: x_3_6 + x_6_3 - y_3_2 - y_6_2 >= -1
#
# _C775: x_4_6 + x_6_4 - y_4_0 - y_6_0 >= -1
#
# _C776: x_4_6 + x_6_4 - y_4_1 - y_6_1 >= -1
#
# _C777: x_4_6 + x_6_4 - y_4_2 - y_6_2 >= -1
#
# _C778: x_5_6 + x_6_5 - y_5_0 - y_6_0 >= -1
#
# _C779: x_5_6 + x_6_5 - y_5_1 - y_6_1 >= -1
#
# _C780: x_5_6 + x_6_5 - y_5_2 - y_6_2 >= -1
#
# _C781: x_6_7 + x_7_6 - y_6_0 - y_7_0 >= -1
#
# _C782: x_6_7 + x_7_6 - y_6_1 - y_7_1 >= -1
#
# _C783: x_6_7 + x_7_6 - y_6_2 - y_7_2 >= -1
#
# _C784: x_6_8 + x_8_6 - y_6_0 - y_8_0 >= -1
#
# _C785: x_6_8 + x_8_6 - y_6_1 - y_8_1 >= -1
#
# _C786: x_6_8 + x_8_6 - y_6_2 - y_8_2 >= -1
#
# _C787: x_6_9 + x_9_6 - y_6_0 - y_9_0 >= -1
#
# _C788: x_6_9 + x_9_6 - y_6_1 - y_9_1 >= -1
#
# _C789: x_6_9 + x_9_6 - y_6_2 - y_9_2 >= -1
#
# _C790: x_10_6 + x_6_10 - y_10_0 - y_6_0 >= -1
#
# _C791: x_10_6 + x_6_10 - y_10_1 - y_6_1 >= -1
#
# _C792: x_10_6 + x_6_10 - y_10_2 - y_6_2 >= -1
#
# _C793: x_11_6 + x_6_11 - y_11_0 - y_6_0 >= -1
#
# _C794: x_11_6 + x_6_11 - y_11_1 - y_6_1 >= -1
#
# _C795: x_11_6 + x_6_11 - y_11_2 - y_6_2 >= -1
#
# _C796: x_12_6 + x_6_12 - y_12_0 - y_6_0 >= -1
#
# _C797: x_12_6 + x_6_12 - y_12_1 - y_6_1 >= -1
#
# _C798: x_12_6 + x_6_12 - y_12_2 - y_6_2 >= -1
#
# _C799: x_13_6 + x_6_13 - y_13_0 - y_6_0 >= -1
#
# _C800: x_13_6 + x_6_13 - y_13_1 - y_6_1 >= -1
#
# _C801: x_13_6 + x_6_13 - y_13_2 - y_6_2 >= -1
#
# _C802: x_14_6 + x_6_14 - y_14_0 - y_6_0 >= -1
#
# _C803: x_14_6 + x_6_14 - y_14_1 - y_6_1 >= -1
#
# _C804: x_14_6 + x_6_14 - y_14_2 - y_6_2 >= -1
#
# _C805: x_15_6 + x_6_15 - y_15_0 - y_6_0 >= -1
#
# _C806: x_15_6 + x_6_15 - y_15_1 - y_6_1 >= -1
#
# _C807: x_15_6 + x_6_15 - y_15_2 - y_6_2 >= -1
#
# _C808: x_16_6 + x_6_16 - y_16_0 - y_6_0 >= -1
#
# _C809: x_16_6 + x_6_16 - y_16_1 - y_6_1 >= -1
#
# _C810: x_16_6 + x_6_16 - y_16_2 - y_6_2 >= -1
#
# _C811: x_17_6 + x_6_17 - y_17_0 - y_6_0 >= -1
#
# _C812: x_17_6 + x_6_17 - y_17_1 - y_6_1 >= -1
#
# _C813: x_17_6 + x_6_17 - y_17_2 - y_6_2 >= -1
#
# _C814: x_18_6 + x_6_18 - y_18_0 - y_6_0 >= -1
#
# _C815: x_18_6 + x_6_18 - y_18_1 - y_6_1 >= -1
#
# _C816: x_18_6 + x_6_18 - y_18_2 - y_6_2 >= -1
#
# _C817: x_19_6 + x_6_19 - y_19_0 - y_6_0 >= -1
#
# _C818: x_19_6 + x_6_19 - y_19_1 - y_6_1 >= -1
#
# _C819: x_19_6 + x_6_19 - y_19_2 - y_6_2 >= -1
#
# _C820: x_0_7 + x_7_0 - y_0_0 - y_7_0 >= -1
#
# _C821: x_0_7 + x_7_0 - y_0_1 - y_7_1 >= -1
#
# _C822: x_0_7 + x_7_0 - y_0_2 - y_7_2 >= -1
#
# _C823: x_1_7 + x_7_1 - y_1_0 - y_7_0 >= -1
#
# _C824: x_1_7 + x_7_1 - y_1_1 - y_7_1 >= -1
#
# _C825: x_1_7 + x_7_1 - y_1_2 - y_7_2 >= -1
#
# _C826: x_2_7 + x_7_2 - y_2_0 - y_7_0 >= -1
#
# _C827: x_2_7 + x_7_2 - y_2_1 - y_7_1 >= -1
#
# _C828: x_2_7 + x_7_2 - y_2_2 - y_7_2 >= -1
#
# _C829: x_3_7 + x_7_3 - y_3_0 - y_7_0 >= -1
#
# _C830: x_3_7 + x_7_3 - y_3_1 - y_7_1 >= -1
#
# _C831: x_3_7 + x_7_3 - y_3_2 - y_7_2 >= -1
#
# _C832: x_4_7 + x_7_4 - y_4_0 - y_7_0 >= -1
#
# _C833: x_4_7 + x_7_4 - y_4_1 - y_7_1 >= -1
#
# _C834: x_4_7 + x_7_4 - y_4_2 - y_7_2 >= -1
#
# _C835: x_5_7 + x_7_5 - y_5_0 - y_7_0 >= -1
#
# _C836: x_5_7 + x_7_5 - y_5_1 - y_7_1 >= -1
#
# _C837: x_5_7 + x_7_5 - y_5_2 - y_7_2 >= -1
#
# _C838: x_6_7 + x_7_6 - y_6_0 - y_7_0 >= -1
#
# _C839: x_6_7 + x_7_6 - y_6_1 - y_7_1 >= -1
#
# _C840: x_6_7 + x_7_6 - y_6_2 - y_7_2 >= -1
#
# _C841: x_7_8 + x_8_7 - y_7_0 - y_8_0 >= -1
#
# _C842: x_7_8 + x_8_7 - y_7_1 - y_8_1 >= -1
#
# _C843: x_7_8 + x_8_7 - y_7_2 - y_8_2 >= -1
#
# _C844: x_7_9 + x_9_7 - y_7_0 - y_9_0 >= -1
#
# _C845: x_7_9 + x_9_7 - y_7_1 - y_9_1 >= -1
#
# _C846: x_7_9 + x_9_7 - y_7_2 - y_9_2 >= -1
#
# _C847: x_10_7 + x_7_10 - y_10_0 - y_7_0 >= -1
#
# _C848: x_10_7 + x_7_10 - y_10_1 - y_7_1 >= -1
#
# _C849: x_10_7 + x_7_10 - y_10_2 - y_7_2 >= -1
#
# _C850: x_11_7 + x_7_11 - y_11_0 - y_7_0 >= -1
#
# _C851: x_11_7 + x_7_11 - y_11_1 - y_7_1 >= -1
#
# _C852: x_11_7 + x_7_11 - y_11_2 - y_7_2 >= -1
#
# _C853: x_12_7 + x_7_12 - y_12_0 - y_7_0 >= -1
#
# _C854: x_12_7 + x_7_12 - y_12_1 - y_7_1 >= -1
#
# _C855: x_12_7 + x_7_12 - y_12_2 - y_7_2 >= -1
#
# _C856: x_13_7 + x_7_13 - y_13_0 - y_7_0 >= -1
#
# _C857: x_13_7 + x_7_13 - y_13_1 - y_7_1 >= -1
#
# _C858: x_13_7 + x_7_13 - y_13_2 - y_7_2 >= -1
#
# _C859: x_14_7 + x_7_14 - y_14_0 - y_7_0 >= -1
#
# _C860: x_14_7 + x_7_14 - y_14_1 - y_7_1 >= -1
#
# _C861: x_14_7 + x_7_14 - y_14_2 - y_7_2 >= -1
#
# _C862: x_15_7 + x_7_15 - y_15_0 - y_7_0 >= -1
#
# _C863: x_15_7 + x_7_15 - y_15_1 - y_7_1 >= -1
#
# _C864: x_15_7 + x_7_15 - y_15_2 - y_7_2 >= -1
#
# _C865: x_16_7 + x_7_16 - y_16_0 - y_7_0 >= -1
#
# _C866: x_16_7 + x_7_16 - y_16_1 - y_7_1 >= -1
#
# _C867: x_16_7 + x_7_16 - y_16_2 - y_7_2 >= -1
#
# _C868: x_17_7 + x_7_17 - y_17_0 - y_7_0 >= -1
#
# _C869: x_17_7 + x_7_17 - y_17_1 - y_7_1 >= -1
#
# _C870: x_17_7 + x_7_17 - y_17_2 - y_7_2 >= -1
#
# _C871: x_18_7 + x_7_18 - y_18_0 - y_7_0 >= -1
#
# _C872: x_18_7 + x_7_18 - y_18_1 - y_7_1 >= -1
#
# _C873: x_18_7 + x_7_18 - y_18_2 - y_7_2 >= -1
#
# _C874: x_19_7 + x_7_19 - y_19_0 - y_7_0 >= -1
#
# _C875: x_19_7 + x_7_19 - y_19_1 - y_7_1 >= -1
#
# _C876: x_19_7 + x_7_19 - y_19_2 - y_7_2 >= -1
#
# _C877: x_0_8 + x_8_0 - y_0_0 - y_8_0 >= -1
#
# _C878: x_0_8 + x_8_0 - y_0_1 - y_8_1 >= -1
#
# _C879: x_0_8 + x_8_0 - y_0_2 - y_8_2 >= -1
#
# _C880: x_1_8 + x_8_1 - y_1_0 - y_8_0 >= -1
#
# _C881: x_1_8 + x_8_1 - y_1_1 - y_8_1 >= -1
#
# _C882: x_1_8 + x_8_1 - y_1_2 - y_8_2 >= -1
#
# _C883: x_2_8 + x_8_2 - y_2_0 - y_8_0 >= -1
#
# _C884: x_2_8 + x_8_2 - y_2_1 - y_8_1 >= -1
#
# _C885: x_2_8 + x_8_2 - y_2_2 - y_8_2 >= -1
#
# _C886: x_3_8 + x_8_3 - y_3_0 - y_8_0 >= -1
#
# _C887: x_3_8 + x_8_3 - y_3_1 - y_8_1 >= -1
#
# _C888: x_3_8 + x_8_3 - y_3_2 - y_8_2 >= -1
#
# _C889: x_4_8 + x_8_4 - y_4_0 - y_8_0 >= -1
#
# _C890: x_4_8 + x_8_4 - y_4_1 - y_8_1 >= -1
#
# _C891: x_4_8 + x_8_4 - y_4_2 - y_8_2 >= -1
#
# _C892: x_5_8 + x_8_5 - y_5_0 - y_8_0 >= -1
#
# _C893: x_5_8 + x_8_5 - y_5_1 - y_8_1 >= -1
#
# _C894: x_5_8 + x_8_5 - y_5_2 - y_8_2 >= -1
#
# _C895: x_6_8 + x_8_6 - y_6_0 - y_8_0 >= -1
#
# _C896: x_6_8 + x_8_6 - y_6_1 - y_8_1 >= -1
#
# _C897: x_6_8 + x_8_6 - y_6_2 - y_8_2 >= -1
#
# _C898: x_7_8 + x_8_7 - y_7_0 - y_8_0 >= -1
#
# _C899: x_7_8 + x_8_7 - y_7_1 - y_8_1 >= -1
#
# _C900: x_7_8 + x_8_7 - y_7_2 - y_8_2 >= -1
#
# _C901: x_8_9 + x_9_8 - y_8_0 - y_9_0 >= -1
#
# _C902: x_8_9 + x_9_8 - y_8_1 - y_9_1 >= -1
#
# _C903: x_8_9 + x_9_8 - y_8_2 - y_9_2 >= -1
#
# _C904: x_10_8 + x_8_10 - y_10_0 - y_8_0 >= -1
#
# _C905: x_10_8 + x_8_10 - y_10_1 - y_8_1 >= -1
#
# _C906: x_10_8 + x_8_10 - y_10_2 - y_8_2 >= -1
#
# _C907: x_11_8 + x_8_11 - y_11_0 - y_8_0 >= -1
#
# _C908: x_11_8 + x_8_11 - y_11_1 - y_8_1 >= -1
#
# _C909: x_11_8 + x_8_11 - y_11_2 - y_8_2 >= -1
#
# _C910: x_12_8 + x_8_12 - y_12_0 - y_8_0 >= -1
#
# _C911: x_12_8 + x_8_12 - y_12_1 - y_8_1 >= -1
#
# _C912: x_12_8 + x_8_12 - y_12_2 - y_8_2 >= -1
#
# _C913: x_13_8 + x_8_13 - y_13_0 - y_8_0 >= -1
#
# _C914: x_13_8 + x_8_13 - y_13_1 - y_8_1 >= -1
#
# _C915: x_13_8 + x_8_13 - y_13_2 - y_8_2 >= -1
#
# _C916: x_14_8 + x_8_14 - y_14_0 - y_8_0 >= -1
#
# _C917: x_14_8 + x_8_14 - y_14_1 - y_8_1 >= -1
#
# _C918: x_14_8 + x_8_14 - y_14_2 - y_8_2 >= -1
#
# _C919: x_15_8 + x_8_15 - y_15_0 - y_8_0 >= -1
#
# _C920: x_15_8 + x_8_15 - y_15_1 - y_8_1 >= -1
#
# _C921: x_15_8 + x_8_15 - y_15_2 - y_8_2 >= -1
#
# _C922: x_16_8 + x_8_16 - y_16_0 - y_8_0 >= -1
#
# _C923: x_16_8 + x_8_16 - y_16_1 - y_8_1 >= -1
#
# _C924: x_16_8 + x_8_16 - y_16_2 - y_8_2 >= -1
#
# _C925: x_17_8 + x_8_17 - y_17_0 - y_8_0 >= -1
#
# _C926: x_17_8 + x_8_17 - y_17_1 - y_8_1 >= -1
#
# _C927: x_17_8 + x_8_17 - y_17_2 - y_8_2 >= -1
#
# _C928: x_18_8 + x_8_18 - y_18_0 - y_8_0 >= -1
#
# _C929: x_18_8 + x_8_18 - y_18_1 - y_8_1 >= -1
#
# _C930: x_18_8 + x_8_18 - y_18_2 - y_8_2 >= -1
#
# _C931: x_19_8 + x_8_19 - y_19_0 - y_8_0 >= -1
#
# _C932: x_19_8 + x_8_19 - y_19_1 - y_8_1 >= -1
#
# _C933: x_19_8 + x_8_19 - y_19_2 - y_8_2 >= -1
#
# _C934: x_0_9 + x_9_0 - y_0_0 - y_9_0 >= -1
#
# _C935: x_0_9 + x_9_0 - y_0_1 - y_9_1 >= -1
#
# _C936: x_0_9 + x_9_0 - y_0_2 - y_9_2 >= -1
#
# _C937: x_1_9 + x_9_1 - y_1_0 - y_9_0 >= -1
#
# _C938: x_1_9 + x_9_1 - y_1_1 - y_9_1 >= -1
#
# _C939: x_1_9 + x_9_1 - y_1_2 - y_9_2 >= -1
#
# _C940: x_2_9 + x_9_2 - y_2_0 - y_9_0 >= -1
#
# _C941: x_2_9 + x_9_2 - y_2_1 - y_9_1 >= -1
#
# _C942: x_2_9 + x_9_2 - y_2_2 - y_9_2 >= -1
#
# _C943: x_3_9 + x_9_3 - y_3_0 - y_9_0 >= -1
#
# _C944: x_3_9 + x_9_3 - y_3_1 - y_9_1 >= -1
#
# _C945: x_3_9 + x_9_3 - y_3_2 - y_9_2 >= -1
#
# _C946: x_4_9 + x_9_4 - y_4_0 - y_9_0 >= -1
#
# _C947: x_4_9 + x_9_4 - y_4_1 - y_9_1 >= -1
#
# _C948: x_4_9 + x_9_4 - y_4_2 - y_9_2 >= -1
#
# _C949: x_5_9 + x_9_5 - y_5_0 - y_9_0 >= -1
#
# _C950: x_5_9 + x_9_5 - y_5_1 - y_9_1 >= -1
#
# _C951: x_5_9 + x_9_5 - y_5_2 - y_9_2 >= -1
#
# _C952: x_6_9 + x_9_6 - y_6_0 - y_9_0 >= -1
#
# _C953: x_6_9 + x_9_6 - y_6_1 - y_9_1 >= -1
#
# _C954: x_6_9 + x_9_6 - y_6_2 - y_9_2 >= -1
#
# _C955: x_7_9 + x_9_7 - y_7_0 - y_9_0 >= -1
#
# _C956: x_7_9 + x_9_7 - y_7_1 - y_9_1 >= -1
#
# _C957: x_7_9 + x_9_7 - y_7_2 - y_9_2 >= -1
#
# _C958: x_8_9 + x_9_8 - y_8_0 - y_9_0 >= -1
#
# _C959: x_8_9 + x_9_8 - y_8_1 - y_9_1 >= -1
#
# _C960: x_8_9 + x_9_8 - y_8_2 - y_9_2 >= -1
#
# _C961: x_10_9 + x_9_10 - y_10_0 - y_9_0 >= -1
#
# _C962: x_10_9 + x_9_10 - y_10_1 - y_9_1 >= -1
#
# _C963: x_10_9 + x_9_10 - y_10_2 - y_9_2 >= -1
#
# _C964: x_11_9 + x_9_11 - y_11_0 - y_9_0 >= -1
#
# _C965: x_11_9 + x_9_11 - y_11_1 - y_9_1 >= -1
#
# _C966: x_11_9 + x_9_11 - y_11_2 - y_9_2 >= -1
#
# _C967: x_12_9 + x_9_12 - y_12_0 - y_9_0 >= -1
#
# _C968: x_12_9 + x_9_12 - y_12_1 - y_9_1 >= -1
#
# _C969: x_12_9 + x_9_12 - y_12_2 - y_9_2 >= -1
#
# _C970: x_13_9 + x_9_13 - y_13_0 - y_9_0 >= -1
#
# _C971: x_13_9 + x_9_13 - y_13_1 - y_9_1 >= -1
#
# _C972: x_13_9 + x_9_13 - y_13_2 - y_9_2 >= -1
#
# _C973: x_14_9 + x_9_14 - y_14_0 - y_9_0 >= -1
#
# _C974: x_14_9 + x_9_14 - y_14_1 - y_9_1 >= -1
#
# _C975: x_14_9 + x_9_14 - y_14_2 - y_9_2 >= -1
#
# _C976: x_15_9 + x_9_15 - y_15_0 - y_9_0 >= -1
#
# _C977: x_15_9 + x_9_15 - y_15_1 - y_9_1 >= -1
#
# _C978: x_15_9 + x_9_15 - y_15_2 - y_9_2 >= -1
#
# _C979: x_16_9 + x_9_16 - y_16_0 - y_9_0 >= -1
#
# _C980: x_16_9 + x_9_16 - y_16_1 - y_9_1 >= -1
#
# _C981: x_16_9 + x_9_16 - y_16_2 - y_9_2 >= -1
#
# _C982: x_17_9 + x_9_17 - y_17_0 - y_9_0 >= -1
#
# _C983: x_17_9 + x_9_17 - y_17_1 - y_9_1 >= -1
#
# _C984: x_17_9 + x_9_17 - y_17_2 - y_9_2 >= -1
#
# _C985: x_18_9 + x_9_18 - y_18_0 - y_9_0 >= -1
#
# _C986: x_18_9 + x_9_18 - y_18_1 - y_9_1 >= -1
#
# _C987: x_18_9 + x_9_18 - y_18_2 - y_9_2 >= -1
#
# _C988: x_19_9 + x_9_19 - y_19_0 - y_9_0 >= -1
#
# _C989: x_19_9 + x_9_19 - y_19_1 - y_9_1 >= -1
#
# _C990: x_19_9 + x_9_19 - y_19_2 - y_9_2 >= -1
#
# _C991: x_0_10 + x_10_0 - y_0_0 - y_10_0 >= -1
#
# _C992: x_0_10 + x_10_0 - y_0_1 - y_10_1 >= -1
#
# _C993: x_0_10 + x_10_0 - y_0_2 - y_10_2 >= -1
#
# _C994: x_10_1 + x_1_10 - y_10_0 - y_1_0 >= -1
#
# _C995: x_10_1 + x_1_10 - y_10_1 - y_1_1 >= -1
#
# _C996: x_10_1 + x_1_10 - y_10_2 - y_1_2 >= -1
#
# _C997: x_10_2 + x_2_10 - y_10_0 - y_2_0 >= -1
#
# _C998: x_10_2 + x_2_10 - y_10_1 - y_2_1 >= -1
#
# _C999: x_10_2 + x_2_10 - y_10_2 - y_2_2 >= -1
#
# _C1000: x_10_3 + x_3_10 - y_10_0 - y_3_0 >= -1
#
# _C1001: x_10_3 + x_3_10 - y_10_1 - y_3_1 >= -1
#
# _C1002: x_10_3 + x_3_10 - y_10_2 - y_3_2 >= -1
#
# _C1003: x_10_4 + x_4_10 - y_10_0 - y_4_0 >= -1
#
# _C1004: x_10_4 + x_4_10 - y_10_1 - y_4_1 >= -1
#
# _C1005: x_10_4 + x_4_10 - y_10_2 - y_4_2 >= -1
#
# _C1006: x_10_5 + x_5_10 - y_10_0 - y_5_0 >= -1
#
# _C1007: x_10_5 + x_5_10 - y_10_1 - y_5_1 >= -1
#
# _C1008: x_10_5 + x_5_10 - y_10_2 - y_5_2 >= -1
#
# _C1009: x_10_6 + x_6_10 - y_10_0 - y_6_0 >= -1
#
# _C1010: x_10_6 + x_6_10 - y_10_1 - y_6_1 >= -1
#
# _C1011: x_10_6 + x_6_10 - y_10_2 - y_6_2 >= -1
#
# _C1012: x_10_7 + x_7_10 - y_10_0 - y_7_0 >= -1
#
# _C1013: x_10_7 + x_7_10 - y_10_1 - y_7_1 >= -1
#
# _C1014: x_10_7 + x_7_10 - y_10_2 - y_7_2 >= -1
#
# _C1015: x_10_8 + x_8_10 - y_10_0 - y_8_0 >= -1
#
# _C1016: x_10_8 + x_8_10 - y_10_1 - y_8_1 >= -1
#
# _C1017: x_10_8 + x_8_10 - y_10_2 - y_8_2 >= -1
#
# _C1018: x_10_9 + x_9_10 - y_10_0 - y_9_0 >= -1
#
# _C1019: x_10_9 + x_9_10 - y_10_1 - y_9_1 >= -1
#
# _C1020: x_10_9 + x_9_10 - y_10_2 - y_9_2 >= -1
#
# _C1021: x_10_11 + x_11_10 - y_10_0 - y_11_0 >= -1
#
# _C1022: x_10_11 + x_11_10 - y_10_1 - y_11_1 >= -1
#
# _C1023: x_10_11 + x_11_10 - y_10_2 - y_11_2 >= -1
#
# _C1024: x_10_12 + x_12_10 - y_10_0 - y_12_0 >= -1
#
# _C1025: x_10_12 + x_12_10 - y_10_1 - y_12_1 >= -1
#
# _C1026: x_10_12 + x_12_10 - y_10_2 - y_12_2 >= -1
#
# _C1027: x_10_13 + x_13_10 - y_10_0 - y_13_0 >= -1
#
# _C1028: x_10_13 + x_13_10 - y_10_1 - y_13_1 >= -1
#
# _C1029: x_10_13 + x_13_10 - y_10_2 - y_13_2 >= -1
#
# _C1030: x_10_14 + x_14_10 - y_10_0 - y_14_0 >= -1
#
# _C1031: x_10_14 + x_14_10 - y_10_1 - y_14_1 >= -1
#
# _C1032: x_10_14 + x_14_10 - y_10_2 - y_14_2 >= -1
#
# _C1033: x_10_15 + x_15_10 - y_10_0 - y_15_0 >= -1
#
# _C1034: x_10_15 + x_15_10 - y_10_1 - y_15_1 >= -1
#
# _C1035: x_10_15 + x_15_10 - y_10_2 - y_15_2 >= -1
#
# _C1036: x_10_16 + x_16_10 - y_10_0 - y_16_0 >= -1
#
# _C1037: x_10_16 + x_16_10 - y_10_1 - y_16_1 >= -1
#
# _C1038: x_10_16 + x_16_10 - y_10_2 - y_16_2 >= -1
#
# _C1039: x_10_17 + x_17_10 - y_10_0 - y_17_0 >= -1
#
# _C1040: x_10_17 + x_17_10 - y_10_1 - y_17_1 >= -1
#
# _C1041: x_10_17 + x_17_10 - y_10_2 - y_17_2 >= -1
#
# _C1042: x_10_18 + x_18_10 - y_10_0 - y_18_0 >= -1
#
# _C1043: x_10_18 + x_18_10 - y_10_1 - y_18_1 >= -1
#
# _C1044: x_10_18 + x_18_10 - y_10_2 - y_18_2 >= -1
#
# _C1045: x_10_19 + x_19_10 - y_10_0 - y_19_0 >= -1
#
# _C1046: x_10_19 + x_19_10 - y_10_1 - y_19_1 >= -1
#
# _C1047: x_10_19 + x_19_10 - y_10_2 - y_19_2 >= -1
#
# _C1048: x_0_11 + x_11_0 - y_0_0 - y_11_0 >= -1
#
# _C1049: x_0_11 + x_11_0 - y_0_1 - y_11_1 >= -1
#
# _C1050: x_0_11 + x_11_0 - y_0_2 - y_11_2 >= -1
#
# _C1051: x_11_1 + x_1_11 - y_11_0 - y_1_0 >= -1
#
# _C1052: x_11_1 + x_1_11 - y_11_1 - y_1_1 >= -1
#
# _C1053: x_11_1 + x_1_11 - y_11_2 - y_1_2 >= -1
#
# _C1054: x_11_2 + x_2_11 - y_11_0 - y_2_0 >= -1
#
# _C1055: x_11_2 + x_2_11 - y_11_1 - y_2_1 >= -1
#
# _C1056: x_11_2 + x_2_11 - y_11_2 - y_2_2 >= -1
#
# _C1057: x_11_3 + x_3_11 - y_11_0 - y_3_0 >= -1
#
# _C1058: x_11_3 + x_3_11 - y_11_1 - y_3_1 >= -1
#
# _C1059: x_11_3 + x_3_11 - y_11_2 - y_3_2 >= -1
#
# _C1060: x_11_4 + x_4_11 - y_11_0 - y_4_0 >= -1
#
# _C1061: x_11_4 + x_4_11 - y_11_1 - y_4_1 >= -1
#
# _C1062: x_11_4 + x_4_11 - y_11_2 - y_4_2 >= -1
#
# _C1063: x_11_5 + x_5_11 - y_11_0 - y_5_0 >= -1
#
# _C1064: x_11_5 + x_5_11 - y_11_1 - y_5_1 >= -1
#
# _C1065: x_11_5 + x_5_11 - y_11_2 - y_5_2 >= -1
#
# _C1066: x_11_6 + x_6_11 - y_11_0 - y_6_0 >= -1
#
# _C1067: x_11_6 + x_6_11 - y_11_1 - y_6_1 >= -1
#
# _C1068: x_11_6 + x_6_11 - y_11_2 - y_6_2 >= -1
#
# _C1069: x_11_7 + x_7_11 - y_11_0 - y_7_0 >= -1
#
# _C1070: x_11_7 + x_7_11 - y_11_1 - y_7_1 >= -1
#
# _C1071: x_11_7 + x_7_11 - y_11_2 - y_7_2 >= -1
#
# _C1072: x_11_8 + x_8_11 - y_11_0 - y_8_0 >= -1
#
# _C1073: x_11_8 + x_8_11 - y_11_1 - y_8_1 >= -1
#
# _C1074: x_11_8 + x_8_11 - y_11_2 - y_8_2 >= -1
#
# _C1075: x_11_9 + x_9_11 - y_11_0 - y_9_0 >= -1
#
# _C1076: x_11_9 + x_9_11 - y_11_1 - y_9_1 >= -1
#
# _C1077: x_11_9 + x_9_11 - y_11_2 - y_9_2 >= -1
#
# _C1078: x_10_11 + x_11_10 - y_10_0 - y_11_0 >= -1
#
# _C1079: x_10_11 + x_11_10 - y_10_1 - y_11_1 >= -1
#
# _C1080: x_10_11 + x_11_10 - y_10_2 - y_11_2 >= -1
#
# _C1081: x_11_12 + x_12_11 - y_11_0 - y_12_0 >= -1
#
# _C1082: x_11_12 + x_12_11 - y_11_1 - y_12_1 >= -1
#
# _C1083: x_11_12 + x_12_11 - y_11_2 - y_12_2 >= -1
#
# _C1084: x_11_13 + x_13_11 - y_11_0 - y_13_0 >= -1
#
# _C1085: x_11_13 + x_13_11 - y_11_1 - y_13_1 >= -1
#
# _C1086: x_11_13 + x_13_11 - y_11_2 - y_13_2 >= -1
#
# _C1087: x_11_14 + x_14_11 - y_11_0 - y_14_0 >= -1
#
# _C1088: x_11_14 + x_14_11 - y_11_1 - y_14_1 >= -1
#
# _C1089: x_11_14 + x_14_11 - y_11_2 - y_14_2 >= -1
#
# _C1090: x_11_15 + x_15_11 - y_11_0 - y_15_0 >= -1
#
# ...
#
# _C1499: x_17_18 + x_18_17 - y_17_1 - y_18_1 >= -1
#
# _C1500: x_17_18 + x_18_17 - y_17_2 - y_18_2 >= -1
#
# _C1501: x_18_19 + x_19_18 - y_18_0 - y_19_0 >= -1
#
# _C1502: x_18_19 + x_19_18 - y_18_1 - y_19_1 >= -1
#
# _C1503: x_18_19 + x_19_18 - y_18_2 - y_19_2 >= -1
#
# _C1504: x_0_19 + x_19_0 - y_0_0 - y_19_0 >= -1
#
# _C1505: x_0_19 + x_19_0 - y_0_1 - y_19_1 >= -1
#
# _C1506: x_0_19 + x_19_0 - y_0_2 - y_19_2 >= -1
#
# _C1507: x_19_1 + x_1_19 - y_19_0 - y_1_0 >= -1
#
# _C1508: x_19_1 + x_1_19 - y_19_1 - y_1_1 >= -1
#
# _C1509: x_19_1 + x_1_19 - y_19_2 - y_1_2 >= -1
#
# _C1510: x_19_2 + x_2_19 - y_19_0 - y_2_0 >= -1
#
# _C1511: x_19_2 + x_2_19 - y_19_1 - y_2_1 >= -1
#
# _C1512: x_19_2 + x_2_19 - y_19_2 - y_2_2 >= -1
#
# _C1513: x_19_3 + x_3_19 - y_19_0 - y_3_0 >= -1
#
# _C1514: x_19_3 + x_3_19 - y_19_1 - y_3_1 >= -1
#
# _C1515: x_19_3 + x_3_19 - y_19_2 - y_3_2 >= -1
#
# _C1516: x_19_4 + x_4_19 - y_19_0 - y_4_0 >= -1
#
# _C1517: x_19_4 + x_4_19 - y_19_1 - y_4_1 >= -1
#
# _C1518: x_19_4 + x_4_19 - y_19_2 - y_4_2 >= -1
#
# _C1519: x_19_5 + x_5_19 - y_19_0 - y_5_0 >= -1
#
# _C1520: x_19_5 + x_5_19 - y_19_1 - y_5_1 >= -1
#
# _C1521: x_19_5 + x_5_19 - y_19_2 - y_5_2 >= -1
#
# _C1522: x_19_6 + x_6_19 - y_19_0 - y_6_0 >= -1
#
# _C1523: x_19_6 + x_6_19 - y_19_1 - y_6_1 >= -1
#
# _C1524: x_19_6 + x_6_19 - y_19_2 - y_6_2 >= -1
#
# _C1525: x_19_7 + x_7_19 - y_19_0 - y_7_0 >= -1
#
# _C1526: x_19_7 + x_7_19 - y_19_1 - y_7_1 >= -1
#
# _C1527: x_19_7 + x_7_19 - y_19_2 - y_7_2 >= -1
#
# _C1528: x_19_8 + x_8_19 - y_19_0 - y_8_0 >= -1
#
# _C1529: x_19_8 + x_8_19 - y_19_1 - y_8_1 >= -1
#
# _C1530: x_19_8 + x_8_19 - y_19_2 - y_8_2 >= -1
#
# _C1531: x_19_9 + x_9_19 - y_19_0 - y_9_0 >= -1
#
# _C1532: x_19_9 + x_9_19 - y_19_1 - y_9_1 >= -1
#
# _C1533: x_19_9 + x_9_19 - y_19_2 - y_9_2 >= -1
#
# _C1534: x_10_19 + x_19_10 - y_10_0 - y_19_0 >= -1
#
# _C1535: x_10_19 + x_19_10 - y_10_1 - y_19_1 >= -1
#
# _C1536: x_10_19 + x_19_10 - y_10_2 - y_19_2 >= -1
#
# _C1537: x_11_19 + x_19_11 - y_11_0 - y_19_0 >= -1
#
# _C1538: x_11_19 + x_19_11 - y_11_1 - y_19_1 >= -1
#
# _C1539: x_11_19 + x_19_11 - y_11_2 - y_19_2 >= -1
#
# _C1540: x_12_19 + x_19_12 - y_12_0 - y_19_0 >= -1
#
# _C1541: x_12_19 + x_19_12 - y_12_1 - y_19_1 >= -1
#
# _C1542: x_12_19 + x_19_12 - y_12_2 - y_19_2 >= -1
#
# _C1543: x_13_19 + x_19_13 - y_13_0 - y_19_0 >= -1
#
# _C1544: x_13_19 + x_19_13 - y_13_1 - y_19_1 >= -1
#
# _C1545: x_13_19 + x_19_13 - y_13_2 - y_19_2 >= -1
#
# _C1546: x_14_19 + x_19_14 - y_14_0 - y_19_0 >= -1
#
# _C1547: x_14_19 + x_19_14 - y_14_1 - y_19_1 >= -1
#
# _C1548: x_14_19 + x_19_14 - y_14_2 - y_19_2 >= -1
#
# _C1549: x_15_19 + x_19_15 - y_15_0 - y_19_0 >= -1
#
# _C1550: x_15_19 + x_19_15 - y_15_1 - y_19_1 >= -1
#
# _C1551: x_15_19 + x_19_15 - y_15_2 - y_19_2 >= -1
#
# _C1552: x_16_19 + x_19_16 - y_16_0 - y_19_0 >= -1
#
# _C1553: x_16_19 + x_19_16 - y_16_1 - y_19_1 >= -1
#
# _C1554: x_16_19 + x_19_16 - y_16_2 - y_19_2 >= -1
#
# _C1555: x_17_19 + x_19_17 - y_17_0 - y_19_0 >= -1
#
# _C1556: x_17_19 + x_19_17 - y_17_1 - y_19_1 >= -1
#
# _C1557: x_17_19 + x_19_17 - y_17_2 - y_19_2 >= -1
#
# _C1558: x_18_19 + x_19_18 - y_18_0 - y_19_0 >= -1
#
# _C1559: x_18_19 + x_19_18 - y_18_1 - y_19_1 >= -1
#
# _C1560: x_18_19 + x_19_18 - y_18_2 - y_19_2 >= -1
#
# _C1561: y_0_0 + y_0_1 + y_0_2 = 1
#
# _C1562: y_1_0 + y_1_1 + y_1_2 = 1
#
# _C1563: y_2_0 + y_2_1 + y_2_2 = 1
#
# _C1564: y_3_0 + y_3_1 + y_3_2 = 1
#
# _C1565: y_4_0 + y_4_1 + y_4_2 = 1
#
# _C1566: y_5_0 + y_5_1 + y_5_2 = 1
#
# _C1567: y_6_0 + y_6_1 + y_6_2 = 1
#
# _C1568: y_7_0 + y_7_1 + y_7_2 = 1
#
# _C1569: y_8_0 + y_8_1 + y_8_2 = 1
#
# _C1570: y_9_0 + y_9_1 + y_9_2 = 1
#
# _C1571: y_10_0 + y_10_1 + y_10_2 = 1
#
# _C1572: y_11_0 + y_11_1 + y_11_2 = 1
#
# _C1573: y_12_0 + y_12_1 + y_12_2 = 1
#
# _C1574: y_13_0 + y_13_1 + y_13_2 = 1
#
# _C1575: y_14_0 + y_14_1 + y_14_2 = 1
#
# _C1576: y_15_0 + y_15_1 + y_15_2 = 1
#
# _C1577: y_16_0 + y_16_1 + y_16_2 = 1
#
# _C1578: y_17_0 + y_17_1 + y_17_2 = 1
#
# _C1579: y_18_0 + y_18_1 + y_18_2 = 1
#
# _C1580: y_19_0 + y_19_1 + y_19_2 = 1
#
# VARIABLES
# E_0 Continuous
# E_1 Continuous
# E_10 Continuous
# E_11 Continuous
# E_12 Continuous
# E_13 Continuous
# E_14 Continuous
# E_15 Continuous
# E_16 Continuous
# E_17 Continuous
# E_18 Continuous
# E_19 Continuous
# E_2 Continuous
# E_3 Continuous
# E_4 Continuous
# E_5 Continuous
# E_6 Continuous
# E_7 Continuous
# E_8 Continuous
# E_9 Continuous
# L_0 Continuous
# L_1 Continuous
# L_10 Continuous
# L_11 Continuous
# L_12 Continuous
# L_13 Continuous
# L_14 Continuous
# L_15 Continuous
# L_16 Continuous
# L_17 Continuous
# L_18 Continuous
# L_19 Continuous
# L_2 Continuous
# L_3 Continuous
# L_4 Continuous
# L_5 Continuous
# L_6 Continuous
# L_7 Continuous
# L_8 Continuous
# L_9 Continuous
# 75 <= T_0 <= 486 Continuous
# 157 <= T_1 <= 628 Continuous
# 132 <= T_10 <= 615 Continuous
# 114 <= T_11 <= 551 Continuous
# 261 <= T_12 <= 834 Continuous
# 250 <= T_13 <= 790 Continuous
# 214 <= T_14 <= 688 Continuous
# 310 <= T_15 <= 967 Continuous
# 269 <= T_16 <= 818 Continuous
# 237 <= T_17 <= 726 Continuous
# 144 <= T_18 <= 607 Continuous
# 151 <= T_19 <= 624 Continuous
# 134 <= T_2 <= 561 Continuous
# 103 <= T_3 <= 565 Continuous
# 201 <= T_4 <= 735 Continuous
# 95 <= T_5 <= 524 Continuous
# 185 <= T_6 <= 664 Continuous
# 98 <= T_7 <= 523 Continuous
# 117 <= T_8 <= 578 Continuous
# 117 <= T_9 <= 569 Continuous
# 0 <= x_0_1 <= 1 Integer
# 0 <= x_0_10 <= 1 Integer
# 0 <= x_0_11 <= 1 Integer
# 0 <= x_0_12 <= 1 Integer
# 0 <= x_0_13 <= 1 Integer
# 0 <= x_0_14 <= 1 Integer
# 0 <= x_0_15 <= 1 Integer
# 0 <= x_0_16 <= 1 Integer
# 0 <= x_0_17 <= 1 Integer
# 0 <= x_0_18 <= 1 Integer
# 0 <= x_0_19 <= 1 Integer
# 0 <= x_0_2 <= 1 Integer
# 0 <= x_0_3 <= 1 Integer
# 0 <= x_0_4 <= 1 Integer
# 0 <= x_0_5 <= 1 Integer
# 0 <= x_0_6 <= 1 Integer
# 0 <= x_0_7 <= 1 Integer
# 0 <= x_0_8 <= 1 Integer
# 0 <= x_0_9 <= 1 Integer
# 0 <= x_10_0 <= 1 Integer
# 0 <= x_10_1 <= 1 Integer
# 0 <= x_10_11 <= 1 Integer
# 0 <= x_10_12 <= 1 Integer
# 0 <= x_10_13 <= 1 Integer
# 0 <= x_10_14 <= 1 Integer
# 0 <= x_10_15 <= 1 Integer
# 0 <= x_10_16 <= 1 Integer
# 0 <= x_10_17 <= 1 Integer
# 0 <= x_10_18 <= 1 Integer
# 0 <= x_10_19 <= 1 Integer
# 0 <= x_10_2 <= 1 Integer
# 0 <= x_10_3 <= 1 Integer
# 0 <= x_10_4 <= 1 Integer
# 0 <= x_10_5 <= 1 Integer
# 0 <= x_10_6 <= 1 Integer
# 0 <= x_10_7 <= 1 Integer
# 0 <= x_10_8 <= 1 Integer
# 0 <= x_10_9 <= 1 Integer
# 0 <= x_11_0 <= 1 Integer
# 0 <= x_11_1 <= 1 Integer
# 0 <= x_11_10 <= 1 Integer
# 0 <= x_11_12 <= 1 Integer
# 0 <= x_11_13 <= 1 Integer
# 0 <= x_11_14 <= 1 Integer
# 0 <= x_11_15 <= 1 Integer
# 0 <= x_11_16 <= 1 Integer
# 0 <= x_11_17 <= 1 Integer
# 0 <= x_11_18 <= 1 Integer
# 0 <= x_11_19 <= 1 Integer
# 0 <= x_11_2 <= 1 Integer
# 0 <= x_11_3 <= 1 Integer
# 0 <= x_11_4 <= 1 Integer
# 0 <= x_11_5 <= 1 Integer
# 0 <= x_11_6 <= 1 Integer
# 0 <= x_11_7 <= 1 Integer
# 0 <= x_11_8 <= 1 Integer
# 0 <= x_11_9 <= 1 Integer
# 0 <= x_12_0 <= 1 Integer
# 0 <= x_12_1 <= 1 Integer
# 0 <= x_12_10 <= 1 Integer
# 0 <= x_12_11 <= 1 Integer
# 0 <= x_12_13 <= 1 Integer
# 0 <= x_12_14 <= 1 Integer
# 0 <= x_12_15 <= 1 Integer
# 0 <= x_12_16 <= 1 Integer
# 0 <= x_12_17 <= 1 Integer
# 0 <= x_12_18 <= 1 Integer
# 0 <= x_12_19 <= 1 Integer
# 0 <= x_12_2 <= 1 Integer
# 0 <= x_12_3 <= 1 Integer
# 0 <= x_12_4 <= 1 Integer
# 0 <= x_12_5 <= 1 Integer
# 0 <= x_12_6 <= 1 Integer
# 0 <= x_12_7 <= 1 Integer
# 0 <= x_12_8 <= 1 Integer
# 0 <= x_12_9 <= 1 Integer
# 0 <= x_13_0 <= 1 Integer
# 0 <= x_13_1 <= 1 Integer
# 0 <= x_13_10 <= 1 Integer
# 0 <= x_13_11 <= 1 Integer
# 0 <= x_13_12 <= 1 Integer
# 0 <= x_13_14 <= 1 Integer
# 0 <= x_13_15 <= 1 Integer
# 0 <= x_13_16 <= 1 Integer
# 0 <= x_13_17 <= 1 Integer
# 0 <= x_13_18 <= 1 Integer
# 0 <= x_13_19 <= 1 Integer
# 0 <= x_13_2 <= 1 Integer
# 0 <= x_13_3 <= 1 Integer
# 0 <= x_13_4 <= 1 Integer
# 0 <= x_13_5 <= 1 Integer
# 0 <= x_13_6 <= 1 Integer
# 0 <= x_13_7 <= 1 Integer
# 0 <= x_13_8 <= 1 Integer
# 0 <= x_13_9 <= 1 Integer
# 0 <= x_14_0 <= 1 Integer
# 0 <= x_14_1 <= 1 Integer
# 0 <= x_14_10 <= 1 Integer
# 0 <= x_14_11 <= 1 Integer
# 0 <= x_14_12 <= 1 Integer
# 0 <= x_14_13 <= 1 Integer
# 0 <= x_14_15 <= 1 Integer
# 0 <= x_14_16 <= 1 Integer
# 0 <= x_14_17 <= 1 Integer
# 0 <= x_14_18 <= 1 Integer
# 0 <= x_14_19 <= 1 Integer
# 0 <= x_14_2 <= 1 Integer
# 0 <= x_14_3 <= 1 Integer
# 0 <= x_14_4 <= 1 Integer
# 0 <= x_14_5 <= 1 Integer
# 0 <= x_14_6 <= 1 Integer
# 0 <= x_14_7 <= 1 Integer
# 0 <= x_14_8 <= 1 Integer
# 0 <= x_14_9 <= 1 Integer
# 0 <= x_15_0 <= 1 Integer
# 0 <= x_15_1 <= 1 Integer
# 0 <= x_15_10 <= 1 Integer
# 0 <= x_15_11 <= 1 Integer
# 0 <= x_15_12 <= 1 Integer
# 0 <= x_15_13 <= 1 Integer
# 0 <= x_15_14 <= 1 Integer
# 0 <= x_15_16 <= 1 Integer
# 0 <= x_15_17 <= 1 Integer
# 0 <= x_15_18 <= 1 Integer
# 0 <= x_15_19 <= 1 Integer
# 0 <= x_15_2 <= 1 Integer
# 0 <= x_15_3 <= 1 Integer
# 0 <= x_15_4 <= 1 Integer
# 0 <= x_15_5 <= 1 Integer
# 0 <= x_15_6 <= 1 Integer
# 0 <= x_15_7 <= 1 Integer
# 0 <= x_15_8 <= 1 Integer
# 0 <= x_15_9 <= 1 Integer
# 0 <= x_16_0 <= 1 Integer
# 0 <= x_16_1 <= 1 Integer
# 0 <= x_16_10 <= 1 Integer
# 0 <= x_16_11 <= 1 Integer
# 0 <= x_16_12 <= 1 Integer
# 0 <= x_16_13 <= 1 Integer
# 0 <= x_16_14 <= 1 Integer
# 0 <= x_16_15 <= 1 Integer
# 0 <= x_16_17 <= 1 Integer
# 0 <= x_16_18 <= 1 Integer
# 0 <= x_16_19 <= 1 Integer
# 0 <= x_16_2 <= 1 Integer
# 0 <= x_16_3 <= 1 Integer
# 0 <= x_16_4 <= 1 Integer
# 0 <= x_16_5 <= 1 Integer
# 0 <= x_16_6 <= 1 Integer
# 0 <= x_16_7 <= 1 Integer
# 0 <= x_16_8 <= 1 Integer
# 0 <= x_16_9 <= 1 Integer
# 0 <= x_17_0 <= 1 Integer
# 0 <= x_17_1 <= 1 Integer
# 0 <= x_17_10 <= 1 Integer
# 0 <= x_17_11 <= 1 Integer
# 0 <= x_17_12 <= 1 Integer
# 0 <= x_17_13 <= 1 Integer
# 0 <= x_17_14 <= 1 Integer
# 0 <= x_17_15 <= 1 Integer
# 0 <= x_17_16 <= 1 Integer
# 0 <= x_17_18 <= 1 Integer
# 0 <= x_17_19 <= 1 Integer
# 0 <= x_17_2 <= 1 Integer
# 0 <= x_17_3 <= 1 Integer
# 0 <= x_17_4 <= 1 Integer
# 0 <= x_17_5 <= 1 Integer
# 0 <= x_17_6 <= 1 Integer
# 0 <= x_17_7 <= 1 Integer
# 0 <= x_17_8 <= 1 Integer
# 0 <= x_17_9 <= 1 Integer
# 0 <= x_18_0 <= 1 Integer
# 0 <= x_18_1 <= 1 Integer
# 0 <= x_18_10 <= 1 Integer
# 0 <= x_18_11 <= 1 Integer
# 0 <= x_18_12 <= 1 Integer
# 0 <= x_18_13 <= 1 Integer
# 0 <= x_18_14 <= 1 Integer
# 0 <= x_18_15 <= 1 Integer
# 0 <= x_18_16 <= 1 Integer
# 0 <= x_18_17 <= 1 Integer
# 0 <= x_18_19 <= 1 Integer
# 0 <= x_18_2 <= 1 Integer
# 0 <= x_18_3 <= 1 Integer
# 0 <= x_18_4 <= 1 Integer
# 0 <= x_18_5 <= 1 Integer
# 0 <= x_18_6 <= 1 Integer
# 0 <= x_18_7 <= 1 Integer
# 0 <= x_18_8 <= 1 Integer
# 0 <= x_18_9 <= 1 Integer
# 0 <= x_19_0 <= 1 Integer
# 0 <= x_19_1 <= 1 Integer
# 0 <= x_19_10 <= 1 Integer
# 0 <= x_19_11 <= 1 Integer
# 0 <= x_19_12 <= 1 Integer
# 0 <= x_19_13 <= 1 Integer
# 0 <= x_19_14 <= 1 Integer
# 0 <= x_19_15 <= 1 Integer
# 0 <= x_19_16 <= 1 Integer
# 0 <= x_19_17 <= 1 Integer
# 0 <= x_19_18 <= 1 Integer
# 0 <= x_19_2 <= 1 Integer
# 0 <= x_19_3 <= 1 Integer
# 0 <= x_19_4 <= 1 Integer
# 0 <= x_19_5 <= 1 Integer
# 0 <= x_19_6 <= 1 Integer
# 0 <= x_19_7 <= 1 Integer
# 0 <= x_19_8 <= 1 Integer
# 0 <= x_19_9 <= 1 Integer
# 0 <= x_1_0 <= 1 Integer
# 0 <= x_1_10 <= 1 Integer
# 0 <= x_1_11 <= 1 Integer
# 0 <= x_1_12 <= 1 Integer
# 0 <= x_1_13 <= 1 Integer
# 0 <= x_1_14 <= 1 Integer
# 0 <= x_1_15 <= 1 Integer
# 0 <= x_1_16 <= 1 Integer
# 0 <= x_1_17 <= 1 Integer
# 0 <= x_1_18 <= 1 Integer
# 0 <= x_1_19 <= 1 Integer
# 0 <= x_1_2 <= 1 Integer
# 0 <= x_1_3 <= 1 Integer
# 0 <= x_1_4 <= 1 Integer
# 0 <= x_1_5 <= 1 Integer
# 0 <= x_1_6 <= 1 Integer
# 0 <= x_1_7 <= 1 Integer
# 0 <= x_1_8 <= 1 Integer
# 0 <= x_1_9 <= 1 Integer
# 0 <= x_2_0 <= 1 Integer
# 0 <= x_2_1 <= 1 Integer
# 0 <= x_2_10 <= 1 Integer
# 0 <= x_2_11 <= 1 Integer
# 0 <= x_2_12 <= 1 Integer
# 0 <= x_2_13 <= 1 Integer
# 0 <= x_2_14 <= 1 Integer
# 0 <= x_2_15 <= 1 Integer
# 0 <= x_2_16 <= 1 Integer
# 0 <= x_2_17 <= 1 Integer
# 0 <= x_2_18 <= 1 Integer
# 0 <= x_2_19 <= 1 Integer
# 0 <= x_2_3 <= 1 Integer
# 0 <= x_2_4 <= 1 Integer
# 0 <= x_2_5 <= 1 Integer
# 0 <= x_2_6 <= 1 Integer
# 0 <= x_2_7 <= 1 Integer
# 0 <= x_2_8 <= 1 Integer
# 0 <= x_2_9 <= 1 Integer
# 0 <= x_3_0 <= 1 Integer
# 0 <= x_3_1 <= 1 Integer
# 0 <= x_3_10 <= 1 Integer
# 0 <= x_3_11 <= 1 Integer
# 0 <= x_3_12 <= 1 Integer
# 0 <= x_3_13 <= 1 Integer
# 0 <= x_3_14 <= 1 Integer
# 0 <= x_3_15 <= 1 Integer
# 0 <= x_3_16 <= 1 Integer
# 0 <= x_3_17 <= 1 Integer
# 0 <= x_3_18 <= 1 Integer
# 0 <= x_3_19 <= 1 Integer
# 0 <= x_3_2 <= 1 Integer
# 0 <= x_3_4 <= 1 Integer
# 0 <= x_3_5 <= 1 Integer
# 0 <= x_3_6 <= 1 Integer
# 0 <= x_3_7 <= 1 Integer
# 0 <= x_3_8 <= 1 Integer
# 0 <= x_3_9 <= 1 Integer
# 0 <= x_4_0 <= 1 Integer
# 0 <= x_4_1 <= 1 Integer
# 0 <= x_4_10 <= 1 Integer
# 0 <= x_4_11 <= 1 Integer
# 0 <= x_4_12 <= 1 Integer
# 0 <= x_4_13 <= 1 Integer
# 0 <= x_4_14 <= 1 Integer
# 0 <= x_4_15 <= 1 Integer
# 0 <= x_4_16 <= 1 Integer
# 0 <= x_4_17 <= 1 Integer
# 0 <= x_4_18 <= 1 Integer
# 0 <= x_4_19 <= 1 Integer
# 0 <= x_4_2 <= 1 Integer
# 0 <= x_4_3 <= 1 Integer
# 0 <= x_4_5 <= 1 Integer
# 0 <= x_4_6 <= 1 Integer
# 0 <= x_4_7 <= 1 Integer
# 0 <= x_4_8 <= 1 Integer
# 0 <= x_4_9 <= 1 Integer
# 0 <= x_5_0 <= 1 Integer
# 0 <= x_5_1 <= 1 Integer
# 0 <= x_5_10 <= 1 Integer
# 0 <= x_5_11 <= 1 Integer
# 0 <= x_5_12 <= 1 Integer
# 0 <= x_5_13 <= 1 Integer
# 0 <= x_5_14 <= 1 Integer
# 0 <= x_5_15 <= 1 Integer
# 0 <= x_5_16 <= 1 Integer
# 0 <= x_5_17 <= 1 Integer
# 0 <= x_5_18 <= 1 Integer
# 0 <= x_5_19 <= 1 Integer
# 0 <= x_5_2 <= 1 Integer
# 0 <= x_5_3 <= 1 Integer
# 0 <= x_5_4 <= 1 Integer
# 0 <= x_5_6 <= 1 Integer
# 0 <= x_5_7 <= 1 Integer
# 0 <= x_5_8 <= 1 Integer
# 0 <= x_5_9 <= 1 Integer
# 0 <= x_6_0 <= 1 Integer
# 0 <= x_6_1 <= 1 Integer
# 0 <= x_6_10 <= 1 Integer
# 0 <= x_6_11 <= 1 Integer
# 0 <= x_6_12 <= 1 Integer
# 0 <= x_6_13 <= 1 Integer
# 0 <= x_6_14 <= 1 Integer
# 0 <= x_6_15 <= 1 Integer
# 0 <= x_6_16 <= 1 Integer
# 0 <= x_6_17 <= 1 Integer
# 0 <= x_6_18 <= 1 Integer
# 0 <= x_6_19 <= 1 Integer
# 0 <= x_6_2 <= 1 Integer
# 0 <= x_6_3 <= 1 Integer
# 0 <= x_6_4 <= 1 Integer
# 0 <= x_6_5 <= 1 Integer
# 0 <= x_6_7 <= 1 Integer
# 0 <= x_6_8 <= 1 Integer
# 0 <= x_6_9 <= 1 Integer
# 0 <= x_7_0 <= 1 Integer
# 0 <= x_7_1 <= 1 Integer
# 0 <= x_7_10 <= 1 Integer
# 0 <= x_7_11 <= 1 Integer
# 0 <= x_7_12 <= 1 Integer
# 0 <= x_7_13 <= 1 Integer
# 0 <= x_7_14 <= 1 Integer
# 0 <= x_7_15 <= 1 Integer
# 0 <= x_7_16 <= 1 Integer
# 0 <= x_7_17 <= 1 Integer
# 0 <= x_7_18 <= 1 Integer
# 0 <= x_7_19 <= 1 Integer
# 0 <= x_7_2 <= 1 Integer
# 0 <= x_7_3 <= 1 Integer
# 0 <= x_7_4 <= 1 Integer
# 0 <= x_7_5 <= 1 Integer
# 0 <= x_7_6 <= 1 Integer
# 0 <= x_7_8 <= 1 Integer
# 0 <= x_7_9 <= 1 Integer
# 0 <= x_8_0 <= 1 Integer
# 0 <= x_8_1 <= 1 Integer
# 0 <= x_8_10 <= 1 Integer
# 0 <= x_8_11 <= 1 Integer
# 0 <= x_8_12 <= 1 Integer
# 0 <= x_8_13 <= 1 Integer
# 0 <= x_8_14 <= 1 Integer
# 0 <= x_8_15 <= 1 Integer
# 0 <= x_8_16 <= 1 Integer
# 0 <= x_8_17 <= 1 Integer
# 0 <= x_8_18 <= 1 Integer
# 0 <= x_8_19 <= 1 Integer
# 0 <= x_8_2 <= 1 Integer
# 0 <= x_8_3 <= 1 Integer
# 0 <= x_8_4 <= 1 Integer
# 0 <= x_8_5 <= 1 Integer
# 0 <= x_8_6 <= 1 Integer
# 0 <= x_8_7 <= 1 Integer
# 0 <= x_8_9 <= 1 Integer
# 0 <= x_9_0 <= 1 Integer
# 0 <= x_9_1 <= 1 Integer
# 0 <= x_9_10 <= 1 Integer
# 0 <= x_9_11 <= 1 Integer
# 0 <= x_9_12 <= 1 Integer
# 0 <= x_9_13 <= 1 Integer
# 0 <= x_9_14 <= 1 Integer
# 0 <= x_9_15 <= 1 Integer
# 0 <= x_9_16 <= 1 Integer
# 0 <= x_9_17 <= 1 Integer
# 0 <= x_9_18 <= 1 Integer
# 0 <= x_9_19 <= 1 Integer
# 0 <= x_9_2 <= 1 Integer
# 0 <= x_9_3 <= 1 Integer
# 0 <= x_9_4 <= 1 Integer
# 0 <= x_9_5 <= 1 Integer
# 0 <= x_9_6 <= 1 Integer
# 0 <= x_9_7 <= 1 Integer
# 0 <= x_9_8 <= 1 Integer
# 0 <= y_0_0 <= 1 Integer
# 0 <= y_0_1 <= 1 Integer
# 0 <= y_0_2 <= 1 Integer
# 0 <= y_10_0 <= 1 Integer
# 0 <= y_10_1 <= 1 Integer
# 0 <= y_10_2 <= 1 Integer
# 0 <= y_11_0 <= 1 Integer
# 0 <= y_11_1 <= 1 Integer
# 0 <= y_11_2 <= 1 Integer
# 0 <= y_12_0 <= 1 Integer
# 0 <= y_12_1 <= 1 Integer
# 0 <= y_12_2 <= 1 Integer
# 0 <= y_13_0 <= 1 Integer
# 0 <= y_13_1 <= 1 Integer
# 0 <= y_13_2 <= 1 Integer
# 0 <= y_14_0 <= 1 Integer
# 0 <= y_14_1 <= 1 Integer
# 0 <= y_14_2 <= 1 Integer
# 0 <= y_15_0 <= 1 Integer
# 0 <= y_15_1 <= 1 Integer
# 0 <= y_15_2 <= 1 Integer
# 0 <= y_16_0 <= 1 Integer
# 0 <= y_16_1 <= 1 Integer
# 0 <= y_16_2 <= 1 Integer
# 0 <= y_17_0 <= 1 Integer
# 0 <= y_17_1 <= 1 Integer
# 0 <= y_17_2 <= 1 Integer
# 0 <= y_18_0 <= 1 Integer
# 0 <= y_18_1 <= 1 Integer
# 0 <= y_18_2 <= 1 Integer
# 0 <= y_19_0 <= 1 Integer
# 0 <= y_19_1 <= 1 Integer
# 0 <= y_19_2 <= 1 Integer
# 0 <= y_1_0 <= 1 Integer
# 0 <= y_1_1 <= 1 Integer
# 0 <= y_1_2 <= 1 Integer
# 0 <= y_2_0 <= 1 Integer
# 0 <= y_2_1 <= 1 Integer
# 0 <= y_2_2 <= 1 Integer
# 0 <= y_3_0 <= 1 Integer
# 0 <= y_3_1 <= 1 Integer
# 0 <= y_3_2 <= 1 Integer
# 0 <= y_4_0 <= 1 Integer
# 0 <= y_4_1 <= 1 Integer
# 0 <= y_4_2 <= 1 Integer
# 0 <= y_5_0 <= 1 Integer
# 0 <= y_5_1 <= 1 Integer
# 0 <= y_5_2 <= 1 Integer
# 0 <= y_6_0 <= 1 Integer
# 0 <= y_6_1 <= 1 Integer
# 0 <= y_6_2 <= 1 Integer
# 0 <= y_7_0 <= 1 Integer
# 0 <= y_7_1 <= 1 Integer
# 0 <= y_7_2 <= 1 Integer
# 0 <= y_8_0 <= 1 Integer
# 0 <= y_8_1 <= 1 Integer
# 0 <= y_8_2 <= 1 Integer
# 0 <= y_9_0 <= 1 Integer
# 0 <= y_9_1 <= 1 Integer
# 0 <= y_9_2 <= 1 Integer

# %% [markdown]
# Affichage de l'instance, du statut de résolution et de l'objectif obtenu :

# %%
print('Instance "{}"{}: {} planes'.format(
    instance_name.split(os.sep)[1][:-4], '', len(P)))
print('Status: ', LpStatus[problem.status])
# utiliser cela pour nouvelles versions pulp :
# print('Status: ', LpStatus[problem.getSolutionStatus()])

print('Objective: ', problem.objective.value())
print()
# Out:
# Instance "airland3": 20 planes
# Status:  Optimal
# Objective:  0.0

# %% [markdown]
# Récupération des valeurs des variables de décision et affichage de la solution :

# %%
vars = problem.variablesDict()
# dates de début
t = [round(vars['T_'+str(i)].value()) for i in P]
Q = None
#affectations aux pistes
y = []
y = []
for i in P:
    for r in R:
        if vars['y_{}_{}'.format(i, r)].roundedValue():
            y.append(r)
# Affichage

for i in P:
    print('  Plane {} appearing at {}, landing at t={} on runway {} '
          '({}, [{}, {}]).'.format(P[i], A[i], t[i], y[i], T[i],
                                   E[i], L[i]))
# Out:
#   Plane 0 appearing at 0, landing at t=82 on runway 2 (82, [75, 486]).
#   Plane 1 appearing at 82, landing at t=197 on runway 1 (197, [157, 628]).
#   Plane 2 appearing at 59, landing at t=160 on runway 1 (160, [134, 561]).
#   Plane 3 appearing at 28, landing at t=117 on runway 2 (117, [103, 565]).
#   Plane 4 appearing at 126, landing at t=261 on runway 1 (261, [201, 735]).
#   Plane 5 appearing at 20, landing at t=106 on runway 1 (106, [95, 524]).
#   Plane 6 appearing at 110, landing at t=229 on runway 2 (229, [185, 664]).
#   Plane 7 appearing at 23, landing at t=108 on runway 0 (108, [98, 523]).
#   Plane 8 appearing at 42, landing at t=132 on runway 1 (132, [117, 578]).
#   Plane 9 appearing at 42, landing at t=130 on runway 2 (130, [117, 569]).
#   Plane 10 appearing at 57, landing at t=149 on runway 0 (149, [132, 615]).
#   Plane 11 appearing at 39, landing at t=126 on runway 0 (126, [114, 551]).
#   Plane 12 appearing at 186, landing at t=336 on runway 0 (336, [261, 834]).
#   Plane 13 appearing at 175, landing at t=316 on runway 2 (316, [250, 790]).
#   Plane 14 appearing at 139, landing at t=258 on runway 1 (258, [214, 688]).
#   Plane 15 appearing at 235, landing at t=409 on runway 0 (409, [310, 967]).
#   Plane 16 appearing at 194, landing at t=338 on runway 1 (338, [269, 818]).
#   Plane 17 appearing at 162, landing at t=287 on runway 0 (287, [237, 726]).
#   Plane 18 appearing at 69, landing at t=160 on runway 2 (160, [144, 607]).
#   Plane 19 appearing at 76, landing at t=169 on runway 2 (169, [151, 624]).

# %% [markdown]
# Il est possible de vérifier la faisabilité de la solution en appelant la fonction <tt>verifier.verify</tt>

# %%
p, w = verifier.verify(t, y, E, T, L, S, G, H)
print('Ok (obj. = {}).'.format(w) if p else w)
# Out:
# i=0 diff=0
# i=1 diff=0
# i=2 diff=0
# i=3 diff=0
# i=4 diff=0
# i=5 diff=0
# i=6 diff=0
# i=7 diff=0
# i=8 diff=0
# i=9 diff=0
# i=10 diff=0
# i=11 diff=0
# i=12 diff=0
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=0
# i=18 diff=0
# i=19 diff=0
# Ok (obj. = 0.0).

# %% [markdown]
# ## 2. Le problème stochastique
#
#
# Les dates d'arrivée au plus tôt, au plus tard et préférentielles $e_i$, $d_i$ et $t_i$ des avions sont maintenant incertaines et remplacées par des variables aléatoires $\tilde e_i$, $\tilde t_i$, $\tilde d_i$ suivant des scénarios discrets. On a donc un ensemble de scénarios $S$ tel qu'un scénario $s\in S$ fournit les dates  $(r_{is})_{i\in P}$, $(d_{is})_{i\in P}$ et $(t_{is})_{i\in P}$ avec une probabilité $\pi_s\geq 0$ avec $\sum_{s\in S}\pi_{s}=100\%$.
# L'ensemble des scénarios fournis en séance est tel que le premier scénario correspond aux données initiales des instances <tt>airland1</tt>,..., <tt>airand13</tt>.
# On considère ici que les contraintes de planification imposent de définir l'affectation des avions aux pistes et l'ordre d'atterrissage des avions avant de connaitre précisément leurs dates d'arrivée. Les dates d'atterrissage effectives seront décalées en fonction du scénario réalisé.
#
# <i>Exemple : Dans le cours 1, on donne les dates d'atterrissages obtenues par une séquence sur deux scénarios (ou seules les dates d'arrivée au plus tôt sont incertaines) pour le problème <tt>airland1</tt>, de coût moyen 1444.</i>
#
# Dans la cellule ci-dessous on relit un fichier d'instance et on choisit un fichier de scénarios.
# Il y a 3 fichiers de scénarios différents pour chacune instances <tt>airland1</tt>, <tt>airland2</tt> et <tt>airland3</tt>. Chaque fichier de scénarios contient un jeu de trois scénarios. A ces trois scénarios s'ajoutent celui correspondant aux données initiales de l'instance associée. Chaque fichier de scénarios permet donc de considérer un ensemble de quatre scénarios. Vous pouvez  choisir un des trois fichiers de scénarios via leur numéro respectif 1, 2 ou 3 à travers la variable <tt>scenario_id</tt>. L'exécution de la cellule suivante permet d'afficher les caractéristiques des quatres scénarios associés à ce fichier avec les dates d'atterrissage au plus tôt, au plus tard et préférentielles.

# %%
# lecture d'un fichier d'instance et initialisation du nombre de pistes
instance_id = 'airland3'
instance_name='instances/'+instance_id+'.txt'
instance = open(instance_name)

runways = 3

P, F, A, E, L, T, S, G, H = read_instance(instance)
P = range(P)
R = range(runways)

# lecture d'un fichier de scenario venant compléter le scenario nominal donne par le fichier d'instance
scenario_id='3'
scenario_set_name = 'scenarios/'+instance_id+'_'+scenario_id+'.txt'
scenario_set = open(scenario_set_name)

bE, bT, bL = E, T, L  # Base value
P2, p, E, T, L = read_scenarios(scenario_set)
if P2 != len(P):
    print('Error: Number of planes in scenarios and instance files '
            'do not match.')
    exit(1)

p.append(1 - sum(p)) # calcul de la probabilite du scenario nominal (celui du fichier de l'instance)
for i in P:
    E[i].append(bE[i])
    T[i].append(bT[i])
    L[i].append(bL[i])

# ajout des informations sur les scénarios et les probabilités dans les arguments de la finction de définition du problème
kargs = {'P': P, 'R': R, 'e': E, 'd': L, 't': T, 's': S, 'g': G, 'h': H}
kargs['S'] = range(len(p))
kargs['p'] = p

# affichage des scenarios:
print ('nb scenarios='+str(len(p)))
print()
print('probabilités p='+str(p))
print()
print('Scénarios des dates d\'atterrissage au plus tôt:')
for k in range(len(p)):
    print('E[.]['+str(k)+']=',end="")
    for i in P:
        print(E[i][k], end =" ")
    print()
print()
print('Scénarios des dates d\'atterrissage au plus tard:')
for k in range(len(p)):
    print('L[.]['+str(k)+']=',end="")
    for i in P:
        print(L[i][k], end =" ")
    print()
print()
print('Scénarios des dates d\'atterrissage préférentielles:')
for k in range(len(p)):
    print('T[.]['+str(k)+']=',end="")
    for i in P:
        print(T[i][k], end =" ")
# Out:
# nb scenarios=4
#
# probabilités p=[0.1, 0.5, 0.2, 0.19999999999999996]
#
# Scénarios des dates d'atterrissage au plus tôt:
# E[.][0]=79 150 146 97 204 103 176 103 126 120 127 125 260 273 214 336 293 232 151 158
# E[.][1]=72 154 122 107 218 103 201 106 121 123 139 104 250 242 232 325 284 218 137 154
# E[.][2]=76 171 139 95 218 100 190 92 118 126 123 117 251 251 224 313 286 220 152 161
# E[.][3]=75 157 134 103 201 95 185 98 117 117 132 114 261 250 214 310 269 237 144 151
#
# Scénarios des dates d'atterrissage au plus tard:
# L[.][0]=354 732 701 430 867 471 756 500 628 600 568 622 1139 1333 882 1371 1296 966 740 729
# L[.][1]=345 646 507 457 1077 436 943 490 544 588 647 490 1030 988 1010 1440 1332 1067 628 766
# L[.][2]=363 696 657 474 1008 495 950 445 582 527 582 523 1240 1037 923 1315 1305 913 715 764
# L[.][3]=486 628 561 565 735 524 664 523 578 569 615 551 834 790 688 967 818 726 607 624
#
# Scénarios des dates d'atterrissage préférentielles:
# T[.][0]=94 168 173 115 241 117 205 116 147 144 153 138 305 323 236 394 340 277 182 190 T[.][1]=82 178 143 124 256 119 242 121 146 144 153 115 285 274 270 384 324 251 165 181 T[.][2]=86 204 165 107 262 116 219 104 135 149 146 135 279 294 265 373 318 251 175 184 T[.][3]=82 197 160 117 261 106 229 108 132 130 149 126 336 316 258 409 338 287 160 169

# %% [markdown]
# ### Question 2.1
#
# <i> Transformer le PLNE obtenue à la question 1.3 en un **programme stochastique à deux niveaux** pour minimiser l'espérance du coût. Justifier votre modélisation.</i>
#
#
#
#
#
# ### Question 2.2
#
# <i>Programmer votre nouveau PLNE dans la fonction <tt>get_problem_q2</tt> et tester le sur les trois premières instances fournies en utilisant les scénarios fournis. Faire un tableau pour chacune des instances comparant les différentes exécutions sur différents scénarios, nombre de pistes d'aterrissage, temps de calcul et la comparaison avec la solution sur le scénario nominal.

# %%
def get_problem_q2(**kargs):

    P = kargs['P']  # Liste d'avions (0, 1, 2, ..., N)
    R = kargs['R']  # Pistes d'atterrissage (0, 1, 2, ..., M)
    S = kargs['S']  # Liste de scénarios
    p = kargs['p']  # Probabilité de chaque scénario
    e = kargs['e']  # Dates d'atterrissage au plus tôt
    d = kargs['d']  # Dates d'atterrissage au plus tard
    t = kargs['t']  # Dates d'atterrissage préférentielles
    s = kargs['s']  # Délais de séparation
    g = kargs['g']  # Coûts unitaires de retard
    h = kargs['h']  # Coûts unitaires d'avance

    # -- Calcul des bigs M à faire
    M = [[[d[i][k] - e[j][k]for k in S] for j in P]for i in P]
    

    # -- Création du problème
    problem = LpProblem("Ordonnancement des atterrissages - Le problème stochastique",
                        LpMinimize)

    # -- Création des variables, on vous donne T, trouver E, L, X, y

    # T - Date d'atterrissage
    T = [[LpVariable('T_{}_{}'.format(i, k), e[i][k], d[i][k]) for k in S] for i in P]

    # E - Avance de l'avion
    E = [[LpVariable('E_{}_{}'.format(i,k), 0) for k in S] for i in P]

    # L - Retard de l'avion
    L = [[LpVariable('L_{}_{}'.format(i,k), 0) for k in S] for i in P]

    # x
    x = [[LpVariable('x_{}_{}'.format(i, j), cat=LpBinary) for j in P] for i in P]
    
    # y  
    y = [[LpVariable('y_{}_{}'.format(i, r), cat=LpBinary) for r in R] for i in P]

    # -- Création de l'objectif à faire

    problem += lpSum((p[k] * (E[i][k]*h[i]+L[i][k]*g[i])for i in P) for k in S)



    # -- Création des contraintes à faire

    # Contraintes (4)
    for k in S:
        for i in P:
            for j in filter(lambda x: x != i, P):
                problem += T[j][k] >= T[i][k] + s[i][j] * x[i][j] - M[i][j][k] * (1 - x[i][j])
            
    # Contraintes (5) et (6)
    for k in S: 
        for i in P:
            problem += L[i][k] >= T[i][k] - t[i][k]
            problem += E[i][k] >= t[i][k] - T[i][k]
            
    
    # Contraintes de sequensement des avions !
    for i in P:
        for j in filter(lambda x: x != i, P):
            for r in R:
                problem += x[i][j] + x[j][i] >= y[i][r] + y[j][r] - 1

    # Contraintes d'affectation des avions aux pistes
    for i in P:
        problem += lpSum(y[i][r] for r in R) == 1
    
    #print(problem)

    return problem

# %% [markdown]
# Définition du nouveau problème et résolution.

# %%
problem = get_problem_q2(**kargs)
status = problem.solve(pulp.PULP_CBC_CMD(msg=False,maxSeconds=60))

# %% [markdown]
# Affichage du résultat de l'optimisation

# %%
sc = ' (scenarios "{}")'.format(scenario_set_name.split(os.sep)[1][:-4])
print('Instance "{}"{}: {} planes'.format(
    instance_name.split(os.sep)[1][:-4], sc, len(P)))
print('Status: ', LpStatus[problem.status])
print('Objective: ', problem.objective.value())
# Out:
# Instance "airland3" (scenarios "airland3_3"): 20 planes
# Status:  Optimal
# Objective:  1137.0

# %% [markdown]
# Récupération des valeurs des variables et affichage de la solution

# %%
print('Affectations: ')
vars = problem.variablesDict()
y = []
for i in P:
    for r in R:
        if vars['y_{}_{}'.format(i, r)].roundedValue():
            y.append(r)
Q = range(len(p))
t = [[round(vars['T_{}_{}'.format(i, s)].value()) for s in Q] for i in P]
for q in Q:
    print('  Scenario {}: '.format(q))
    for i in P:
        print('    Plane {} appearing at {}, landing at t={} on runway {} '
                '({}, [{}, {}]).'.format(P[i], A[i], t[i][q], y[i],
                                        T[i][q], E[i][q], L[i][q]))
# Out:
# Affectations:
#   Scenario 0:
#     Plane 0 appearing at 0, landing at t=94 on runway 2 (94, [79, 354]).
#     Plane 1 appearing at 82, landing at t=168 on runway 2 (168, [150, 732]).
#     Plane 2 appearing at 59, landing at t=173 on runway 1 (173, [146, 701]).
#     Plane 3 appearing at 28, landing at t=115 on runway 2 (115, [97, 430]).
#     Plane 4 appearing at 126, landing at t=241 on runway 1 (241, [204, 867]).
#     Plane 5 appearing at 20, landing at t=117 on runway 0 (117, [103, 471]).
#     Plane 6 appearing at 110, landing at t=205 on runway 2 (205, [176, 756]).
#     Plane 7 appearing at 23, landing at t=107 on runway 2 (116, [103, 500]).
#     Plane 8 appearing at 42, landing at t=147 on runway 0 (147, [126, 628]).
#     Plane 9 appearing at 42, landing at t=182 on runway 0 (144, [120, 600]).
#     Plane 10 appearing at 57, landing at t=153 on runway 2 (153, [127, 568]).
#     Plane 11 appearing at 39, landing at t=138 on runway 1 (138, [125, 622]).
#     Plane 12 appearing at 186, landing at t=305 on runway 2 (305, [260, 1139]).
#     Plane 13 appearing at 175, landing at t=323 on runway 1 (323, [273, 1333]).
#     Plane 14 appearing at 139, landing at t=236 on runway 2 (236, [214, 882]).
#     Plane 15 appearing at 235, landing at t=394 on runway 1 (394, [336, 1371]).
#     Plane 16 appearing at 194, landing at t=340 on runway 0 (340, [293, 1296]).
#     Plane 17 appearing at 162, landing at t=277 on runway 0 (277, [232, 966]).
#     Plane 18 appearing at 69, landing at t=174 on runway 0 (182, [151, 740]).
#     Plane 19 appearing at 76, landing at t=190 on runway 0 (190, [158, 729]).
#   Scenario 1:
#     Plane 0 appearing at 0, landing at t=82 on runway 2 (82, [72, 345]).
#     Plane 1 appearing at 82, landing at t=178 on runway 2 (178, [154, 646]).
#     Plane 2 appearing at 59, landing at t=143 on runway 1 (143, [122, 507]).
#     Plane 3 appearing at 28, landing at t=124 on runway 2 (124, [107, 457]).
#     Plane 4 appearing at 126, landing at t=256 on runway 1 (256, [218, 1077]).
#     Plane 5 appearing at 20, landing at t=119 on runway 0 (119, [103, 436]).
#     Plane 6 appearing at 110, landing at t=242 on runway 2 (242, [201, 943]).
#     Plane 7 appearing at 23, landing at t=116 on runway 2 (121, [106, 490]).
#     Plane 8 appearing at 42, landing at t=146 on runway 0 (146, [121, 544]).
#     Plane 9 appearing at 42, landing at t=173 on runway 0 (144, [123, 588]).
#     Plane 10 appearing at 57, landing at t=153 on runway 2 (153, [139, 647]).
#     Plane 11 appearing at 39, landing at t=115 on runway 1 (115, [104, 490]).
#     Plane 12 appearing at 186, landing at t=285 on runway 2 (285, [250, 1030]).
#     Plane 13 appearing at 175, landing at t=274 on runway 1 (274, [242, 988]).
#     Plane 14 appearing at 139, landing at t=270 on runway 2 (270, [232, 1010]).
#     Plane 15 appearing at 235, landing at t=384 on runway 1 (384, [325, 1440]).
#     Plane 16 appearing at 194, landing at t=324 on runway 0 (324, [284, 1332]).
#     Plane 17 appearing at 162, landing at t=251 on runway 0 (251, [218, 1067]).
#     Plane 18 appearing at 69, landing at t=165 on runway 0 (165, [137, 628]).
#     Plane 19 appearing at 76, landing at t=181 on runway 0 (181, [154, 766]).
#   Scenario 2:
#     Plane 0 appearing at 0, landing at t=86 on runway 2 (86, [76, 363]).
#     Plane 1 appearing at 82, landing at t=204 on runway 2 (204, [171, 696]).
#     Plane 2 appearing at 59, landing at t=165 on runway 1 (165, [139, 657]).
#     Plane 3 appearing at 28, landing at t=107 on runway 2 (107, [95, 474]).
#     Plane 4 appearing at 126, landing at t=262 on runway 1 (262, [218, 1008]).
#     Plane 5 appearing at 20, landing at t=116 on runway 0 (116, [100, 495]).
#     Plane 6 appearing at 110, landing at t=219 on runway 2 (219, [190, 950]).
#     Plane 7 appearing at 23, landing at t=99 on runway 2 (104, [92, 445]).
#     Plane 8 appearing at 42, landing at t=135 on runway 0 (135, [118, 582]).
#     Plane 9 appearing at 42, landing at t=176 on runway 0 (149, [126, 527]).
#     Plane 10 appearing at 57, landing at t=146 on runway 2 (146, [123, 582]).
#     Plane 11 appearing at 39, landing at t=135 on runway 1 (135, [117, 523]).
#     Plane 12 appearing at 186, landing at t=279 on runway 2 (279, [251, 1240]).
#     Plane 13 appearing at 175, landing at t=294 on runway 1 (294, [251, 1037]).
#     Plane 14 appearing at 139, landing at t=265 on runway 2 (265, [224, 923]).
#     Plane 15 appearing at 235, landing at t=373 on runway 1 (373, [313, 1315]).
#     Plane 16 appearing at 194, landing at t=318 on runway 0 (318, [286, 1305]).
#     Plane 17 appearing at 162, landing at t=251 on runway 0 (251, [220, 913]).
#     Plane 18 appearing at 69, landing at t=168 on runway 0 (175, [152, 715]).
#     Plane 19 appearing at 76, landing at t=184 on runway 0 (184, [161, 764]).
#   Scenario 3:
#     Plane 0 appearing at 0, landing at t=82 on runway 2 (82, [75, 486]).
#     Plane 1 appearing at 82, landing at t=197 on runway 2 (197, [157, 628]).
#     Plane 2 appearing at 59, landing at t=160 on runway 1 (160, [134, 561]).
#     Plane 3 appearing at 28, landing at t=117 on runway 2 (117, [103, 565]).
#     Plane 4 appearing at 126, landing at t=261 on runway 1 (261, [201, 735]).
#     Plane 5 appearing at 20, landing at t=106 on runway 0 (106, [95, 524]).
#     Plane 6 appearing at 110, landing at t=229 on runway 2 (229, [185, 664]).
#     Plane 7 appearing at 23, landing at t=108 on runway 2 (108, [98, 523]).
#     Plane 8 appearing at 42, landing at t=132 on runway 0 (132, [117, 578]).
#     Plane 9 appearing at 42, landing at t=161 on runway 0 (130, [117, 569]).
#     Plane 10 appearing at 57, landing at t=149 on runway 2 (149, [132, 615]).
#     Plane 11 appearing at 39, landing at t=126 on runway 1 (126, [114, 551]).
#     Plane 12 appearing at 186, landing at t=336 on runway 2 (336, [261, 834]).
#     Plane 13 appearing at 175, landing at t=316 on runway 1 (316, [250, 790]).
#     Plane 14 appearing at 139, landing at t=258 on runway 2 (258, [214, 688]).
#     Plane 15 appearing at 235, landing at t=409 on runway 1 (409, [310, 967]).
#     Plane 16 appearing at 194, landing at t=338 on runway 0 (338, [269, 818]).
#     Plane 17 appearing at 162, landing at t=287 on runway 0 (287, [237, 726]).
#     Plane 18 appearing at 69, landing at t=153 on runway 0 (160, [144, 607]).
#     Plane 19 appearing at 76, landing at t=169 on runway 0 (169, [151, 624]).

# %% [markdown]
# Il est également possible de vérifier la validité de solution et d'avoir la valeur de l'objectif pour chaque scénario

# %%
# Verify for each scenario:
verif = True
for q in Q:
    u = ' (p = {:.2f})'.format(p[q])
    c, w = verifier.verify(t, y, E, T, L, S, G, H, q)
    print('Scenario {}{}: '.format(q, u), end='')
    print('Ok (obj. = {})'.format(w) if c else w)
    verif = verif and c
# Out:
# i=0 diff=0
# i=1 diff=0
# i=2 diff=0
# i=3 diff=0
# i=4 diff=0
# i=5 diff=0
# i=6 diff=0
# i=7 diff=-9
# i=8 diff=0
# i=9 diff=38
# i=10 diff=0
# i=11 diff=0
# i=12 diff=0
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=0
# i=18 diff=-8
# i=19 diff=0
# Scenario 0 (p = 0.10): Ok (obj. = 1650.0)
# i=0 diff=0
# i=1 diff=0
# i=2 diff=0
# i=3 diff=0
# i=4 diff=0
# i=5 diff=0
# i=6 diff=0
# i=7 diff=-5
# i=8 diff=0
# i=9 diff=29
# i=10 diff=0
# i=11 diff=0
# i=12 diff=0
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=0
# i=18 diff=0
# i=19 diff=0
# Scenario 1 (p = 0.50): Ok (obj. = 1020.0)
# i=0 diff=0
# i=1 diff=0
# i=2 diff=0
# i=3 diff=0
# i=4 diff=0
# i=5 diff=0
# i=6 diff=0
# i=7 diff=-5
# i=8 diff=0
# i=9 diff=27
# i=10 diff=0
# i=11 diff=0
# i=12 diff=0
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=0
# i=18 diff=-7
# i=19 diff=0
# Scenario 2 (p = 0.20): Ok (obj. = 1170.0)
# i=0 diff=0
# i=1 diff=0
# i=2 diff=0
# i=3 diff=0
# i=4 diff=0
# i=5 diff=0
# i=6 diff=0
# i=7 diff=0
# i=8 diff=0
# i=9 diff=31
# i=10 diff=0
# i=11 diff=0
# i=12 diff=0
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=0
# i=18 diff=-7
# i=19 diff=0
# Scenario 3 (p = 0.20): Ok (obj. = 1140.0)

# %% [markdown]
# ## 3. Le problème robuste
#
# On considère le cas où on dispose des mêmes scénarios de dates d'arrivée des avions que pour le problème stochastique mais où on ne peut les associer à aucune probabilité.
#
# <i> Exemple : Dans le cours 1, on montre les dates d'atterrissages obtenue par une séquence sur les mêmes scénarios pour le problème <tt>airland1</tt>, de coût maximal 1610.</i>
#
# ### Question 3.1
#
# <i>Transformer le PLNE obtenue à la question 1.3 pour minimiser le coût dans le pire scénario. Justifier votre modélisation.</i>
#
#
#
#
#
# ### Question 3.2
#
# <i>Programmer votre nouveau PLNE dans la fonction et comparer les solutions obtenues par les PLNE statique, stochastique et robuste sur les trois premières instances et leurs scénarios.</i>

# %%
def get_problem_q3(**kargs):

    P = kargs['P']  # Liste d'avions (0, 1, 2, ..., N)
    R = kargs['R']  # Pistes d'atterrissage (0, 1, 2, ..., M)
    S = kargs['S']  # Liste de scénarios
    e = kargs['e']  # Dates d'atterrissage au plus tôt
    d = kargs['d']  # Dates d'atterrissage au plus tard
    t = kargs['t']  # Dates d'atterrissage préférentielles
    s = kargs['s']  # Délais de séparation
    g = kargs['g']  # Coûts unitaires de retard
    h = kargs['h']  # Coûts unitaires d'avance

    # -- Calcul des bigs M a faire
    M = [[[d[i][k] - e[j][k]for k in S] for j in P]for i in P]


    # -- Création du problème
    problem = LpProblem("Ordonnancement des atterrissages - Le problème robuste",
                        LpMinimize)

    # -- Création des variables on vous donne la variable T ... créer les autres (E, L, x, y)

    # T - Date d'atterrissage
    T = [[LpVariable('T_{}_{}'.format(i, k), e[i][k], d[i][k]) for k in S] for i in P]

    # E - Avance de l'avion
    E = [[LpVariable('E_{}_{}'.format(i, k), 0) for k in S] for i in P]
    
    # L - Retard de l'avion
    L = [[LpVariable('L_{}_{}'.format(i, k), 0) for k in S] for i in P]

    # x
    x = [[LpVariable('x_{}_{}'.format(i, j), cat=LpBinary) for j in P] for i in P]
    
    # y  
    y = [[LpVariable('y_{}_{}'.format(i, r), cat=LpBinary) for r in R] for i in P]
    
    z = LpVariable('z')    
     

    # -- Création de l'objectif à faire
    
    problem += z
    
    # -- Création des contraintes à faire
    for k in S:
        problem += z >= lpSum([g[i]*L[i][k] + h[i]*E[i][k] for i in P])
    
    for k in S:
        for i in P:
            for j in filter(lambda x: x != i, P):
                problem += T[j][k] >= T[i][k] + s[i][j] * x[i][j] - M[i][j][k] * (1 - x[i][j])
    
    
    for i in P:
        for j in filter(lambda x: x != i, P):
            for r in R:
                problem += x[i][j] + x[j][i] >= y[i][r] + y[j][r] - 1
                
    
    
    for k in S:
        for i in P:
            problem += L[i][k] >= T[i][k] - t[i][k]
            problem += E[i][k] >= t[i][k] - T[i][k]
            
    for i in P:
        problem += lpSum([y[i][r] for r in R]) == 1 
    

    print(problem)
    return problem

# %% [markdown]
# Définition du nouveau problème et résolution.

# %%
problem = get_problem_q3(**kargs)
status = problem.solve(pulp.PULP_CBC_CMD(msg=True,maxSeconds=60))
# Out:
# Ordonnancement_des_atterrissages_-_Le_problème_robuste:
# MINIMIZE
# 1*z + 0
# SUBJECT TO
# _C1: - 30 E_0_0 - 30 E_10_0 - 30 E_11_0 - 10 E_12_0 - 10 E_13_0 - 10 E_14_0
#  - 10 E_15_0 - 10 E_16_0 - 10 E_17_0 - 30 E_18_0 - 30 E_19_0 - 10 E_1_0
#  - 10 E_2_0 - 30 E_3_0 - 10 E_4_0 - 30 E_5_0 - 10 E_6_0 - 30 E_7_0 - 30 E_8_0
#  - 30 E_9_0 - 30 L_0_0 - 30 L_10_0 - 30 L_11_0 - 10 L_12_0 - 10 L_13_0
#  - 10 L_14_0 - 10 L_15_0 - 10 L_16_0 - 10 L_17_0 - 30 L_18_0 - 30 L_19_0
#  - 10 L_1_0 - 10 L_2_0 - 30 L_3_0 - 10 L_4_0 - 30 L_5_0 - 10 L_6_0 - 30 L_7_0
#  - 30 L_8_0 - 30 L_9_0 + z >= 0
#
# _C2: - 30 E_0_1 - 30 E_10_1 - 30 E_11_1 - 10 E_12_1 - 10 E_13_1 - 10 E_14_1
#  - 10 E_15_1 - 10 E_16_1 - 10 E_17_1 - 30 E_18_1 - 30 E_19_1 - 10 E_1_1
#  - 10 E_2_1 - 30 E_3_1 - 10 E_4_1 - 30 E_5_1 - 10 E_6_1 - 30 E_7_1 - 30 E_8_1
#  - 30 E_9_1 - 30 L_0_1 - 30 L_10_1 - 30 L_11_1 - 10 L_12_1 - 10 L_13_1
#  - 10 L_14_1 - 10 L_15_1 - 10 L_16_1 - 10 L_17_1 - 30 L_18_1 - 30 L_19_1
#  - 10 L_1_1 - 10 L_2_1 - 30 L_3_1 - 10 L_4_1 - 30 L_5_1 - 10 L_6_1 - 30 L_7_1
#  - 30 L_8_1 - 30 L_9_1 + z >= 0
#
# _C3: - 30 E_0_2 - 30 E_10_2 - 30 E_11_2 - 10 E_12_2 - 10 E_13_2 - 10 E_14_2
#  - 10 E_15_2 - 10 E_16_2 - 10 E_17_2 - 30 E_18_2 - 30 E_19_2 - 10 E_1_2
#  - 10 E_2_2 - 30 E_3_2 - 10 E_4_2 - 30 E_5_2 - 10 E_6_2 - 30 E_7_2 - 30 E_8_2
#  - 30 E_9_2 - 30 L_0_2 - 30 L_10_2 - 30 L_11_2 - 10 L_12_2 - 10 L_13_2
#  - 10 L_14_2 - 10 L_15_2 - 10 L_16_2 - 10 L_17_2 - 30 L_18_2 - 30 L_19_2
#  - 10 L_1_2 - 10 L_2_2 - 30 L_3_2 - 10 L_4_2 - 30 L_5_2 - 10 L_6_2 - 30 L_7_2
#  - 30 L_8_2 - 30 L_9_2 + z >= 0
#
# _C4: - 30 E_0_3 - 30 E_10_3 - 30 E_11_3 - 10 E_12_3 - 10 E_13_3 - 10 E_14_3
#  - 10 E_15_3 - 10 E_16_3 - 10 E_17_3 - 30 E_18_3 - 30 E_19_3 - 10 E_1_3
#  - 10 E_2_3 - 30 E_3_3 - 10 E_4_3 - 30 E_5_3 - 10 E_6_3 - 30 E_7_3 - 30 E_8_3
#  - 30 E_9_3 - 30 L_0_3 - 30 L_10_3 - 30 L_11_3 - 10 L_12_3 - 10 L_13_3
#  - 10 L_14_3 - 10 L_15_3 - 10 L_16_3 - 10 L_17_3 - 30 L_18_3 - 30 L_19_3
#  - 10 L_1_3 - 10 L_2_3 - 30 L_3_3 - 10 L_4_3 - 30 L_5_3 - 10 L_6_3 - 30 L_7_3
#  - 30 L_8_3 - 30 L_9_3 + z >= 0
#
# _C5: - T_0_0 + T_1_0 - 219 x_0_1 >= -204
#
# _C6: - T_0_0 + T_2_0 - 223 x_0_2 >= -208
#
# _C7: - T_0_0 + T_3_0 - 265 x_0_3 >= -257
#
# _C8: - T_0_0 + T_4_0 - 165 x_0_4 >= -150
#
# _C9: - T_0_0 + T_5_0 - 259 x_0_5 >= -251
#
# _C10: - T_0_0 + T_6_0 - 193 x_0_6 >= -178
#
# _C11: - T_0_0 + T_7_0 - 259 x_0_7 >= -251
#
# _C12: - T_0_0 + T_8_0 - 236 x_0_8 >= -228
#
# _C13: - T_0_0 + T_9_0 - 242 x_0_9 >= -234
#
# _C14: - T_0_0 + T_10_0 - 235 x_0_10 >= -227
#
# _C15: - T_0_0 + T_11_0 - 237 x_0_11 >= -229
#
# _C16: - T_0_0 + T_12_0 - 109 x_0_12 >= -94
#
# _C17: - T_0_0 + T_13_0 - 96 x_0_13 >= -81
#
# _C18: - T_0_0 + T_14_0 - 155 x_0_14 >= -140
#
# _C19: - T_0_0 + T_15_0 - 33 x_0_15 >= -18
#
# _C20: - T_0_0 + T_16_0 - 76 x_0_16 >= -61
#
# _C21: - T_0_0 + T_17_0 - 137 x_0_17 >= -122
#
# _C22: - T_0_0 + T_18_0 - 211 x_0_18 >= -203
#
# _C23: - T_0_0 + T_19_0 - 204 x_0_19 >= -196
#
# _C24: T_0_0 - T_1_0 - 668 x_1_0 >= -653
#
# _C25: - T_1_0 + T_2_0 - 589 x_1_2 >= -586
#
# _C26: - T_1_0 + T_3_0 - 650 x_1_3 >= -635
#
# _C27: - T_1_0 + T_4_0 - 531 x_1_4 >= -528
#
# _C28: - T_1_0 + T_5_0 - 644 x_1_5 >= -629
#
# _C29: - T_1_0 + T_6_0 - 559 x_1_6 >= -556
#
# _C30: - T_1_0 + T_7_0 - 644 x_1_7 >= -629
#
# _C31: - T_1_0 + T_8_0 - 621 x_1_8 >= -606
#
# _C32: - T_1_0 + T_9_0 - 627 x_1_9 >= -612
#
# _C33: T_10_0 - T_1_0 - 620 x_1_10 >= -605
#
# _C34: T_11_0 - T_1_0 - 622 x_1_11 >= -607
#
# _C35: T_12_0 - T_1_0 - 475 x_1_12 >= -472
#
# _C36: T_13_0 - T_1_0 - 462 x_1_13 >= -459
#
# _C37: T_14_0 - T_1_0 - 521 x_1_14 >= -518
#
# _C38: T_15_0 - T_1_0 - 399 x_1_15 >= -396
#
# _C39: T_16_0 - T_1_0 - 442 x_1_16 >= -439
#
# _C40: T_17_0 - T_1_0 - 503 x_1_17 >= -500
#
# _C41: T_18_0 - T_1_0 - 596 x_1_18 >= -581
#
# _C42: T_19_0 - T_1_0 - 589 x_1_19 >= -574
#
# _C43: T_0_0 - T_2_0 - 637 x_2_0 >= -622
#
# _C44: T_1_0 - T_2_0 - 554 x_2_1 >= -551
#
# _C45: - T_2_0 + T_3_0 - 619 x_2_3 >= -604
#
# _C46: - T_2_0 + T_4_0 - 500 x_2_4 >= -497
#
# _C47: - T_2_0 + T_5_0 - 613 x_2_5 >= -598
#
# _C48: - T_2_0 + T_6_0 - 528 x_2_6 >= -525
#
# _C49: - T_2_0 + T_7_0 - 613 x_2_7 >= -598
#
# _C50: - T_2_0 + T_8_0 - 590 x_2_8 >= -575
#
# _C51: - T_2_0 + T_9_0 - 596 x_2_9 >= -581
#
# _C52: T_10_0 - T_2_0 - 589 x_2_10 >= -574
#
# _C53: T_11_0 - T_2_0 - 591 x_2_11 >= -576
#
# _C54: T_12_0 - T_2_0 - 444 x_2_12 >= -441
#
# _C55: T_13_0 - T_2_0 - 431 x_2_13 >= -428
#
# _C56: T_14_0 - T_2_0 - 490 x_2_14 >= -487
#
# _C57: T_15_0 - T_2_0 - 368 x_2_15 >= -365
#
# _C58: T_16_0 - T_2_0 - 411 x_2_16 >= -408
#
# _C59: T_17_0 - T_2_0 - 472 x_2_17 >= -469
#
# _C60: T_18_0 - T_2_0 - 565 x_2_18 >= -550
#
# _C61: T_19_0 - T_2_0 - 558 x_2_19 >= -543
#
# _C62: T_0_0 - T_3_0 - 359 x_3_0 >= -351
#
# _C63: T_1_0 - T_3_0 - 295 x_3_1 >= -280
#
# _C64: T_2_0 - T_3_0 - 299 x_3_2 >= -284
#
# _C65: - T_3_0 + T_4_0 - 241 x_3_4 >= -226
#
# _C66: - T_3_0 + T_5_0 - 335 x_3_5 >= -327
#
# _C67: - T_3_0 + T_6_0 - 269 x_3_6 >= -254
#
# _C68: - T_3_0 + T_7_0 - 335 x_3_7 >= -327
#
# _C69: - T_3_0 + T_8_0 - 312 x_3_8 >= -304
#
# _C70: - T_3_0 + T_9_0 - 318 x_3_9 >= -310
#
# _C71: T_10_0 - T_3_0 - 311 x_3_10 >= -303
#
# _C72: T_11_0 - T_3_0 - 313 x_3_11 >= -305
#
# _C73: T_12_0 - T_3_0 - 185 x_3_12 >= -170
#
# _C74: T_13_0 - T_3_0 - 172 x_3_13 >= -157
#
# _C75: T_14_0 - T_3_0 - 231 x_3_14 >= -216
#
# _C76: T_15_0 - T_3_0 - 109 x_3_15 >= -94
#
# _C77: T_16_0 - T_3_0 - 152 x_3_16 >= -137
#
# _C78: T_17_0 - T_3_0 - 213 x_3_17 >= -198
#
# _C79: T_18_0 - T_3_0 - 287 x_3_18 >= -279
#
# _C80: T_19_0 - T_3_0 - 280 x_3_19 >= -272
#
# _C81: T_0_0 - T_4_0 - 803 x_4_0 >= -788
#
# _C82: T_1_0 - T_4_0 - 720 x_4_1 >= -717
#
# _C83: T_2_0 - T_4_0 - 724 x_4_2 >= -721
#
# _C84: T_3_0 - T_4_0 - 785 x_4_3 >= -770
#
# _C85: - T_4_0 + T_5_0 - 779 x_4_5 >= -764
#
# _C86: - T_4_0 + T_6_0 - 694 x_4_6 >= -691
#
# _C87: - T_4_0 + T_7_0 - 779 x_4_7 >= -764
#
# _C88: - T_4_0 + T_8_0 - 756 x_4_8 >= -741
#
# _C89: - T_4_0 + T_9_0 - 762 x_4_9 >= -747
#
# _C90: T_10_0 - T_4_0 - 755 x_4_10 >= -740
#
# _C91: T_11_0 - T_4_0 - 757 x_4_11 >= -742
#
# _C92: T_12_0 - T_4_0 - 610 x_4_12 >= -607
#
# _C93: T_13_0 - T_4_0 - 597 x_4_13 >= -594
#
# _C94: T_14_0 - T_4_0 - 656 x_4_14 >= -653
#
# _C95: T_15_0 - T_4_0 - 534 x_4_15 >= -531
#
# _C96: T_16_0 - T_4_0 - 577 x_4_16 >= -574
#
# _C97: T_17_0 - T_4_0 - 638 x_4_17 >= -635
#
# _C98: T_18_0 - T_4_0 - 731 x_4_18 >= -716
#
# _C99: T_19_0 - T_4_0 - 724 x_4_19 >= -709
#
# _C100: T_0_0 - T_5_0 - 400 x_5_0 >= -392
#
# _C101: T_1_0 - T_5_0 - 336 x_5_1 >= -321
#
# _C102: T_2_0 - T_5_0 - 340 x_5_2 >= -325
#
# _C103: T_3_0 - T_5_0 - 382 x_5_3 >= -374
#
# _C104: T_4_0 - T_5_0 - 282 x_5_4 >= -267
#
# _C105: - T_5_0 + T_6_0 - 310 x_5_6 >= -295
#
# _C106: - T_5_0 + T_7_0 - 376 x_5_7 >= -368
#
# _C107: - T_5_0 + T_8_0 - 353 x_5_8 >= -345
#
# _C108: - T_5_0 + T_9_0 - 359 x_5_9 >= -351
#
# _C109: T_10_0 - T_5_0 - 352 x_5_10 >= -344
#
# _C110: T_11_0 - T_5_0 - 354 x_5_11 >= -346
#
# _C111: T_12_0 - T_5_0 - 226 x_5_12 >= -211
#
# _C112: T_13_0 - T_5_0 - 213 x_5_13 >= -198
#
# _C113: T_14_0 - T_5_0 - 272 x_5_14 >= -257
#
# _C114: T_15_0 - T_5_0 - 150 x_5_15 >= -135
#
# _C115: T_16_0 - T_5_0 - 193 x_5_16 >= -178
#
# _C116: T_17_0 - T_5_0 - 254 x_5_17 >= -239
#
# _C117: T_18_0 - T_5_0 - 328 x_5_18 >= -320
#
# _C118: T_19_0 - T_5_0 - 321 x_5_19 >= -313
#
# _C119: T_0_0 - T_6_0 - 692 x_6_0 >= -677
#
# _C120: T_1_0 - T_6_0 - 609 x_6_1 >= -606
#
# _C121: T_2_0 - T_6_0 - 613 x_6_2 >= -610
#
# _C122: T_3_0 - T_6_0 - 674 x_6_3 >= -659
#
# _C123: T_4_0 - T_6_0 - 555 x_6_4 >= -552
#
# _C124: T_5_0 - T_6_0 - 668 x_6_5 >= -653
#
# _C125: - T_6_0 + T_7_0 - 668 x_6_7 >= -653
#
# _C126: - T_6_0 + T_8_0 - 645 x_6_8 >= -630
#
# _C127: - T_6_0 + T_9_0 - 651 x_6_9 >= -636
#
# _C128: T_10_0 - T_6_0 - 644 x_6_10 >= -629
#
# _C129: T_11_0 - T_6_0 - 646 x_6_11 >= -631
#
# _C130: T_12_0 - T_6_0 - 499 x_6_12 >= -496
#
# _C131: T_13_0 - T_6_0 - 486 x_6_13 >= -483
#
# _C132: T_14_0 - T_6_0 - 545 x_6_14 >= -542
#
# _C133: T_15_0 - T_6_0 - 423 x_6_15 >= -420
#
# _C134: T_16_0 - T_6_0 - 466 x_6_16 >= -463
#
# _C135: T_17_0 - T_6_0 - 527 x_6_17 >= -524
#
# _C136: T_18_0 - T_6_0 - 620 x_6_18 >= -605
#
# _C137: T_19_0 - T_6_0 - 613 x_6_19 >= -598
#
# _C138: T_0_0 - T_7_0 - 429 x_7_0 >= -421
#
# _C139: T_1_0 - T_7_0 - 365 x_7_1 >= -350
#
# _C140: T_2_0 - T_7_0 - 369 x_7_2 >= -354
#
# _C141: T_3_0 - T_7_0 - 411 x_7_3 >= -403
#
# _C142: T_4_0 - T_7_0 - 311 x_7_4 >= -296
#
# _C143: T_5_0 - T_7_0 - 405 x_7_5 >= -397
#
# _C144: T_6_0 - T_7_0 - 339 x_7_6 >= -324
#
# _C145: - T_7_0 + T_8_0 - 382 x_7_8 >= -374
#
# _C146: - T_7_0 + T_9_0 - 388 x_7_9 >= -380
#
# _C147: T_10_0 - T_7_0 - 381 x_7_10 >= -373
#
# _C148: T_11_0 - T_7_0 - 383 x_7_11 >= -375
#
# _C149: T_12_0 - T_7_0 - 255 x_7_12 >= -240
#
# _C150: T_13_0 - T_7_0 - 242 x_7_13 >= -227
#
# _C151: T_14_0 - T_7_0 - 301 x_7_14 >= -286
#
# _C152: T_15_0 - T_7_0 - 179 x_7_15 >= -164
#
# _C153: T_16_0 - T_7_0 - 222 x_7_16 >= -207
#
# _C154: T_17_0 - T_7_0 - 283 x_7_17 >= -268
#
# _C155: T_18_0 - T_7_0 - 357 x_7_18 >= -349
#
# _C156: T_19_0 - T_7_0 - 350 x_7_19 >= -342
#
# _C157: T_0_0 - T_8_0 - 557 x_8_0 >= -549
#
# _C158: T_1_0 - T_8_0 - 493 x_8_1 >= -478
#
# _C159: T_2_0 - T_8_0 - 497 x_8_2 >= -482
#
# _C160: T_3_0 - T_8_0 - 539 x_8_3 >= -531
#
# _C161: T_4_0 - T_8_0 - 439 x_8_4 >= -424
#
# _C162: T_5_0 - T_8_0 - 533 x_8_5 >= -525
#
# _C163: T_6_0 - T_8_0 - 467 x_8_6 >= -452
#
# _C164: T_7_0 - T_8_0 - 533 x_8_7 >= -525
#
# _C165: - T_8_0 + T_9_0 - 516 x_8_9 >= -508
#
# _C166: T_10_0 - T_8_0 - 509 x_8_10 >= -501
#
# _C167: T_11_0 - T_8_0 - 511 x_8_11 >= -503
#
# _C168: T_12_0 - T_8_0 - 383 x_8_12 >= -368
#
# _C169: T_13_0 - T_8_0 - 370 x_8_13 >= -355
#
# _C170: T_14_0 - T_8_0 - 429 x_8_14 >= -414
#
# _C171: T_15_0 - T_8_0 - 307 x_8_15 >= -292
#
# _C172: T_16_0 - T_8_0 - 350 x_8_16 >= -335
#
# _C173: T_17_0 - T_8_0 - 411 x_8_17 >= -396
#
# _C174: T_18_0 - T_8_0 - 485 x_8_18 >= -477
#
# _C175: T_19_0 - T_8_0 - 478 x_8_19 >= -470
#
# _C176: T_0_0 - T_9_0 - 529 x_9_0 >= -521
#
# _C177: T_1_0 - T_9_0 - 465 x_9_1 >= -450
#
# _C178: T_2_0 - T_9_0 - 469 x_9_2 >= -454
#
# _C179: T_3_0 - T_9_0 - 511 x_9_3 >= -503
#
# _C180: T_4_0 - T_9_0 - 411 x_9_4 >= -396
#
# _C181: T_5_0 - T_9_0 - 505 x_9_5 >= -497
#
# _C182: T_6_0 - T_9_0 - 439 x_9_6 >= -424
#
# _C183: T_7_0 - T_9_0 - 505 x_9_7 >= -497
#
# _C184: T_8_0 - T_9_0 - 482 x_9_8 >= -474
#
# _C185: T_10_0 - T_9_0 - 481 x_9_10 >= -473
#
# _C186: T_11_0 - T_9_0 - 483 x_9_11 >= -475
#
# _C187: T_12_0 - T_9_0 - 355 x_9_12 >= -340
#
# _C188: T_13_0 - T_9_0 - 342 x_9_13 >= -327
#
# _C189: T_14_0 - T_9_0 - 401 x_9_14 >= -386
#
# _C190: T_15_0 - T_9_0 - 279 x_9_15 >= -264
#
# _C191: T_16_0 - T_9_0 - 322 x_9_16 >= -307
#
# _C192: T_17_0 - T_9_0 - 383 x_9_17 >= -368
#
# _C193: T_18_0 - T_9_0 - 457 x_9_18 >= -449
#
# _C194: T_19_0 - T_9_0 - 450 x_9_19 >= -442
#
# _C195: T_0_0 - T_10_0 - 497 x_10_0 >= -489
#
# _C196: - T_10_0 + T_1_0 - 433 x_10_1 >= -418
#
# _C197: - T_10_0 + T_2_0 - 437 x_10_2 >= -422
#
# _C198: - T_10_0 + T_3_0 - 479 x_10_3 >= -471
#
# _C199: - T_10_0 + T_4_0 - 379 x_10_4 >= -364
#
# _C200: - T_10_0 + T_5_0 - 473 x_10_5 >= -465
#
# _C201: - T_10_0 + T_6_0 - 407 x_10_6 >= -392
#
# _C202: - T_10_0 + T_7_0 - 473 x_10_7 >= -465
#
# _C203: - T_10_0 + T_8_0 - 450 x_10_8 >= -442
#
# _C204: - T_10_0 + T_9_0 - 456 x_10_9 >= -448
#
# _C205: - T_10_0 + T_11_0 - 451 x_10_11 >= -443
#
# _C206: - T_10_0 + T_12_0 - 323 x_10_12 >= -308
#
# _C207: - T_10_0 + T_13_0 - 310 x_10_13 >= -295
#
# _C208: - T_10_0 + T_14_0 - 369 x_10_14 >= -354
#
# _C209: - T_10_0 + T_15_0 - 247 x_10_15 >= -232
#
# _C210: - T_10_0 + T_16_0 - 290 x_10_16 >= -275
#
# _C211: - T_10_0 + T_17_0 - 351 x_10_17 >= -336
#
# _C212: - T_10_0 + T_18_0 - 425 x_10_18 >= -417
#
# _C213: - T_10_0 + T_19_0 - 418 x_10_19 >= -410
#
# _C214: T_0_0 - T_11_0 - 551 x_11_0 >= -543
#
# _C215: - T_11_0 + T_1_0 - 487 x_11_1 >= -472
#
# _C216: - T_11_0 + T_2_0 - 491 x_11_2 >= -476
#
# _C217: - T_11_0 + T_3_0 - 533 x_11_3 >= -525
#
# _C218: - T_11_0 + T_4_0 - 433 x_11_4 >= -418
#
# _C219: - T_11_0 + T_5_0 - 527 x_11_5 >= -519
#
# _C220: - T_11_0 + T_6_0 - 461 x_11_6 >= -446
#
# _C221: - T_11_0 + T_7_0 - 527 x_11_7 >= -519
#
# _C222: - T_11_0 + T_8_0 - 504 x_11_8 >= -496
#
# _C223: - T_11_0 + T_9_0 - 510 x_11_9 >= -502
#
# _C224: T_10_0 - T_11_0 - 503 x_11_10 >= -495
#
# _C225: - T_11_0 + T_12_0 - 377 x_11_12 >= -362
#
# _C226: - T_11_0 + T_13_0 - 364 x_11_13 >= -349
#
# _C227: - T_11_0 + T_14_0 - 423 x_11_14 >= -408
#
# _C228: - T_11_0 + T_15_0 - 301 x_11_15 >= -286
#
# _C229: - T_11_0 + T_16_0 - 344 x_11_16 >= -329
#
# _C230: - T_11_0 + T_17_0 - 405 x_11_17 >= -390
#
# _C231: - T_11_0 + T_18_0 - 479 x_11_18 >= -471
#
# _C232: - T_11_0 + T_19_0 - 472 x_11_19 >= -464
#
# _C233: T_0_0 - T_12_0 - 1075 x_12_0 >= -1060
#
# _C234: - T_12_0 + T_1_0 - 992 x_12_1 >= -989
#
# _C235: - T_12_0 + T_2_0 - 996 x_12_2 >= -993
#
# _C236: - T_12_0 + T_3_0 - 1057 x_12_3 >= -1042
#
# _C237: - T_12_0 + T_4_0 - 938 x_12_4 >= -935
#
# _C238: - T_12_0 + T_5_0 - 1051 x_12_5 >= -1036
#
# _C239: - T_12_0 + T_6_0 - 966 x_12_6 >= -963
#
# _C240: - T_12_0 + T_7_0 - 1051 x_12_7 >= -1036
#
# _C241: - T_12_0 + T_8_0 - 1028 x_12_8 >= -1013
#
# _C242: - T_12_0 + T_9_0 - 1034 x_12_9 >= -1019
#
# _C243: T_10_0 - T_12_0 - 1027 x_12_10 >= -1012
#
# _C244: T_11_0 - T_12_0 - 1029 x_12_11 >= -1014
#
# _C245: - T_12_0 + T_13_0 - 869 x_12_13 >= -866
#
# _C246: - T_12_0 + T_14_0 - 928 x_12_14 >= -925
#
# _C247: - T_12_0 + T_15_0 - 806 x_12_15 >= -803
#
# _C248: - T_12_0 + T_16_0 - 849 x_12_16 >= -846
#
# _C249: - T_12_0 + T_17_0 - 910 x_12_17 >= -907
#
# _C250: - T_12_0 + T_18_0 - 1003 x_12_18 >= -988
#
# _C251: - T_12_0 + T_19_0 - 996 x_12_19 >= -981
#
# _C252: T_0_0 - T_13_0 - 1269 x_13_0 >= -1254
#
# _C253: - T_13_0 + T_1_0 - 1186 x_13_1 >= -1183
#
# _C254: - T_13_0 + T_2_0 - 1190 x_13_2 >= -1187
#
# _C255: - T_13_0 + T_3_0 - 1251 x_13_3 >= -1236
#
# _C256: - T_13_0 + T_4_0 - 1132 x_13_4 >= -1129
#
# _C257: - T_13_0 + T_5_0 - 1245 x_13_5 >= -1230
#
# _C258: - T_13_0 + T_6_0 - 1160 x_13_6 >= -1157
#
# _C259: - T_13_0 + T_7_0 - 1245 x_13_7 >= -1230
#
# _C260: - T_13_0 + T_8_0 - 1222 x_13_8 >= -1207
#
# _C261: - T_13_0 + T_9_0 - 1228 x_13_9 >= -1213
#
# _C262: T_10_0 - T_13_0 - 1221 x_13_10 >= -1206
#
# _C263: T_11_0 - T_13_0 - 1223 x_13_11 >= -1208
#
# _C264: T_12_0 - T_13_0 - 1076 x_13_12 >= -1073
#
# _C265: - T_13_0 + T_14_0 - 1122 x_13_14 >= -1119
#
# _C266: - T_13_0 + T_15_0 - 1000 x_13_15 >= -997
#
# _C267: - T_13_0 + T_16_0 - 1043 x_13_16 >= -1040
#
# _C268: - T_13_0 + T_17_0 - 1104 x_13_17 >= -1101
#
# _C269: - T_13_0 + T_18_0 - 1197 x_13_18 >= -1182
#
# _C270: - T_13_0 + T_19_0 - 1190 x_13_19 >= -1175
#
# _C271: T_0_0 - T_14_0 - 818 x_14_0 >= -803
#
# _C272: - T_14_0 + T_1_0 - 735 x_14_1 >= -732
#
# _C273: - T_14_0 + T_2_0 - 739 x_14_2 >= -736
#
# _C274: - T_14_0 + T_3_0 - 800 x_14_3 >= -785
#
# _C275: - T_14_0 + T_4_0 - 681 x_14_4 >= -678
#
# _C276: - T_14_0 + T_5_0 - 794 x_14_5 >= -779
#
# _C277: - T_14_0 + T_6_0 - 709 x_14_6 >= -706
#
# _C278: - T_14_0 + T_7_0 - 794 x_14_7 >= -779
#
# _C279: - T_14_0 + T_8_0 - 771 x_14_8 >= -756
#
# _C280: - T_14_0 + T_9_0 - 777 x_14_9 >= -762
#
# _C281: T_10_0 - T_14_0 - 770 x_14_10 >= -755
#
# _C282: T_11_0 - T_14_0 - 772 x_14_11 >= -757
#
# _C283: T_12_0 - T_14_0 - 625 x_14_12 >= -622
#
# _C284: T_13_0 - T_14_0 - 612 x_14_13 >= -609
#
# _C285: - T_14_0 + T_15_0 - 549 x_14_15 >= -546
#
# _C286: - T_14_0 + T_16_0 - 592 x_14_16 >= -589
#
# _C287: - T_14_0 + T_17_0 - 653 x_14_17 >= -650
#
# _C288: - T_14_0 + T_18_0 - 746 x_14_18 >= -731
#
# _C289: - T_14_0 + T_19_0 - 739 x_14_19 >= -724
#
# _C290: T_0_0 - T_15_0 - 1307 x_15_0 >= -1292
#
# _C291: - T_15_0 + T_1_0 - 1224 x_15_1 >= -1221
#
# _C292: - T_15_0 + T_2_0 - 1228 x_15_2 >= -1225
#
# _C293: - T_15_0 + T_3_0 - 1289 x_15_3 >= -1274
#
# _C294: - T_15_0 + T_4_0 - 1170 x_15_4 >= -1167
#
# _C295: - T_15_0 + T_5_0 - 1283 x_15_5 >= -1268
#
# _C296: - T_15_0 + T_6_0 - 1198 x_15_6 >= -1195
#
# _C297: - T_15_0 + T_7_0 - 1283 x_15_7 >= -1268
#
# _C298: - T_15_0 + T_8_0 - 1260 x_15_8 >= -1245
#
# _C299: - T_15_0 + T_9_0 - 1266 x_15_9 >= -1251
#
# _C300: T_10_0 - T_15_0 - 1259 x_15_10 >= -1244
#
# _C301: T_11_0 - T_15_0 - 1261 x_15_11 >= -1246
#
# _C302: T_12_0 - T_15_0 - 1114 x_15_12 >= -1111
#
# _C303: T_13_0 - T_15_0 - 1101 x_15_13 >= -1098
#
# _C304: T_14_0 - T_15_0 - 1160 x_15_14 >= -1157
#
# _C305: - T_15_0 + T_16_0 - 1081 x_15_16 >= -1078
#
# _C306: - T_15_0 + T_17_0 - 1142 x_15_17 >= -1139
#
# _C307: - T_15_0 + T_18_0 - 1235 x_15_18 >= -1220
#
# _C308: - T_15_0 + T_19_0 - 1228 x_15_19 >= -1213
#
# _C309: T_0_0 - T_16_0 - 1232 x_16_0 >= -1217
#
# _C310: - T_16_0 + T_1_0 - 1149 x_16_1 >= -1146
#
# _C311: - T_16_0 + T_2_0 - 1153 x_16_2 >= -1150
#
# _C312: - T_16_0 + T_3_0 - 1214 x_16_3 >= -1199
#
# _C313: - T_16_0 + T_4_0 - 1095 x_16_4 >= -1092
#
# _C314: - T_16_0 + T_5_0 - 1208 x_16_5 >= -1193
#
# _C315: - T_16_0 + T_6_0 - 1123 x_16_6 >= -1120
#
# _C316: - T_16_0 + T_7_0 - 1208 x_16_7 >= -1193
#
# _C317: - T_16_0 + T_8_0 - 1185 x_16_8 >= -1170
#
# _C318: - T_16_0 + T_9_0 - 1191 x_16_9 >= -1176
#
# _C319: T_10_0 - T_16_0 - 1184 x_16_10 >= -1169
#
# _C320: T_11_0 - T_16_0 - 1186 x_16_11 >= -1171
#
# _C321: T_12_0 - T_16_0 - 1039 x_16_12 >= -1036
#
# _C322: T_13_0 - T_16_0 - 1026 x_16_13 >= -1023
#
# _C323: T_14_0 - T_16_0 - 1085 x_16_14 >= -1082
#
# _C324: T_15_0 - T_16_0 - 963 x_16_15 >= -960
#
# _C325: - T_16_0 + T_17_0 - 1067 x_16_17 >= -1064
#
# _C326: - T_16_0 + T_18_0 - 1160 x_16_18 >= -1145
#
# _C327: - T_16_0 + T_19_0 - 1153 x_16_19 >= -1138
#
# _C328: T_0_0 - T_17_0 - 902 x_17_0 >= -887
#
# _C329: - T_17_0 + T_1_0 - 819 x_17_1 >= -816
#
# _C330: - T_17_0 + T_2_0 - 823 x_17_2 >= -820
#
# _C331: - T_17_0 + T_3_0 - 884 x_17_3 >= -869
#
# _C332: - T_17_0 + T_4_0 - 765 x_17_4 >= -762
#
# _C333: - T_17_0 + T_5_0 - 878 x_17_5 >= -863
#
# _C334: - T_17_0 + T_6_0 - 793 x_17_6 >= -790
#
# _C335: - T_17_0 + T_7_0 - 878 x_17_7 >= -863
#
# _C336: - T_17_0 + T_8_0 - 855 x_17_8 >= -840
#
# _C337: - T_17_0 + T_9_0 - 861 x_17_9 >= -846
#
# _C338: T_10_0 - T_17_0 - 854 x_17_10 >= -839
#
# _C339: T_11_0 - T_17_0 - 856 x_17_11 >= -841
#
# _C340: T_12_0 - T_17_0 - 709 x_17_12 >= -706
#
# _C341: T_13_0 - T_17_0 - 696 x_17_13 >= -693
#
# _C342: T_14_0 - T_17_0 - 755 x_17_14 >= -752
#
# _C343: T_15_0 - T_17_0 - 633 x_17_15 >= -630
#
# _C344: T_16_0 - T_17_0 - 676 x_17_16 >= -673
#
# _C345: - T_17_0 + T_18_0 - 830 x_17_18 >= -815
#
# _C346: - T_17_0 + T_19_0 - 823 x_17_19 >= -808
#
# _C347: T_0_0 - T_18_0 - 669 x_18_0 >= -661
#
# _C348: - T_18_0 + T_1_0 - 605 x_18_1 >= -590
#
# _C349: - T_18_0 + T_2_0 - 609 x_18_2 >= -594
#
# _C350: - T_18_0 + T_3_0 - 651 x_18_3 >= -643
#
# _C351: - T_18_0 + T_4_0 - 551 x_18_4 >= -536
#
# _C352: - T_18_0 + T_5_0 - 645 x_18_5 >= -637
#
# _C353: - T_18_0 + T_6_0 - 579 x_18_6 >= -564
#
# _C354: - T_18_0 + T_7_0 - 645 x_18_7 >= -637
#
# _C355: - T_18_0 + T_8_0 - 622 x_18_8 >= -614
#
# _C356: - T_18_0 + T_9_0 - 628 x_18_9 >= -620
#
# _C357: T_10_0 - T_18_0 - 621 x_18_10 >= -613
#
# _C358: T_11_0 - T_18_0 - 623 x_18_11 >= -615
#
# _C359: T_12_0 - T_18_0 - 495 x_18_12 >= -480
#
# _C360: T_13_0 - T_18_0 - 482 x_18_13 >= -467
#
# _C361: T_14_0 - T_18_0 - 541 x_18_14 >= -526
#
# _C362: T_15_0 - T_18_0 - 419 x_18_15 >= -404
#
# _C363: T_16_0 - T_18_0 - 462 x_18_16 >= -447
#
# _C364: T_17_0 - T_18_0 - 523 x_18_17 >= -508
#
# _C365: - T_18_0 + T_19_0 - 590 x_18_19 >= -582
#
# _C366: T_0_0 - T_19_0 - 658 x_19_0 >= -650
#
# _C367: - T_19_0 + T_1_0 - 594 x_19_1 >= -579
#
# _C368: - T_19_0 + T_2_0 - 598 x_19_2 >= -583
#
# _C369: - T_19_0 + T_3_0 - 640 x_19_3 >= -632
#
# _C370: - T_19_0 + T_4_0 - 540 x_19_4 >= -525
#
# _C371: - T_19_0 + T_5_0 - 634 x_19_5 >= -626
#
# _C372: - T_19_0 + T_6_0 - 568 x_19_6 >= -553
#
# _C373: - T_19_0 + T_7_0 - 634 x_19_7 >= -626
#
# _C374: - T_19_0 + T_8_0 - 611 x_19_8 >= -603
#
# _C375: - T_19_0 + T_9_0 - 617 x_19_9 >= -609
#
# _C376: T_10_0 - T_19_0 - 610 x_19_10 >= -602
#
# _C377: T_11_0 - T_19_0 - 612 x_19_11 >= -604
#
# _C378: T_12_0 - T_19_0 - 484 x_19_12 >= -469
#
# _C379: T_13_0 - T_19_0 - 471 x_19_13 >= -456
#
# _C380: T_14_0 - T_19_0 - 530 x_19_14 >= -515
#
# _C381: T_15_0 - T_19_0 - 408 x_19_15 >= -393
#
# _C382: T_16_0 - T_19_0 - 451 x_19_16 >= -436
#
# _C383: T_17_0 - T_19_0 - 512 x_19_17 >= -497
#
# _C384: T_18_0 - T_19_0 - 586 x_19_18 >= -578
#
# _C385: - T_0_1 + T_1_1 - 206 x_0_1 >= -191
#
# _C386: - T_0_1 + T_2_1 - 238 x_0_2 >= -223
#
# _C387: - T_0_1 + T_3_1 - 246 x_0_3 >= -238
#
# _C388: - T_0_1 + T_4_1 - 142 x_0_4 >= -127
#
# _C389: - T_0_1 + T_5_1 - 250 x_0_5 >= -242
#
# _C390: - T_0_1 + T_6_1 - 159 x_0_6 >= -144
#
# _C391: - T_0_1 + T_7_1 - 247 x_0_7 >= -239
#
# _C392: - T_0_1 + T_8_1 - 232 x_0_8 >= -224
#
# _C393: - T_0_1 + T_9_1 - 230 x_0_9 >= -222
#
# _C394: - T_0_1 + T_10_1 - 214 x_0_10 >= -206
#
# _C395: - T_0_1 + T_11_1 - 249 x_0_11 >= -241
#
# _C396: - T_0_1 + T_12_1 - 110 x_0_12 >= -95
#
# _C397: - T_0_1 + T_13_1 - 118 x_0_13 >= -103
#
# _C398: - T_0_1 + T_14_1 - 128 x_0_14 >= -113
#
# _C399: - T_0_1 + T_15_1 - 35 x_0_15 >= -20
#
# _C400: - T_0_1 + T_16_1 - 76 x_0_16 >= -61
#
# _C401: - T_0_1 + T_17_1 - 142 x_0_17 >= -127
#
# _C402: - T_0_1 + T_18_1 - 216 x_0_18 >= -208
#
# _C403: - T_0_1 + T_19_1 - 199 x_0_19 >= -191
#
# _C404: T_0_1 - T_1_1 - 589 x_1_0 >= -574
#
# _C405: - T_1_1 + T_2_1 - 527 x_1_2 >= -524
#
# _C406: - T_1_1 + T_3_1 - 554 x_1_3 >= -539
#
# _C407: - T_1_1 + T_4_1 - 431 x_1_4 >= -428
#
# _C408: - T_1_1 + T_5_1 - 558 x_1_5 >= -543
#
# _C409: - T_1_1 + T_6_1 - 448 x_1_6 >= -445
#
# _C410: - T_1_1 + T_7_1 - 555 x_1_7 >= -540
#
# _C411: - T_1_1 + T_8_1 - 540 x_1_8 >= -525
#
# _C412: - T_1_1 + T_9_1 - 538 x_1_9 >= -523
#
# _C413: T_10_1 - T_1_1 - 522 x_1_10 >= -507
#
# _C414: T_11_1 - T_1_1 - 557 x_1_11 >= -542
#
# _C415: T_12_1 - T_1_1 - 399 x_1_12 >= -396
#
# _C416: T_13_1 - T_1_1 - 407 x_1_13 >= -404
#
# _C417: T_14_1 - T_1_1 - 417 x_1_14 >= -414
#
# _C418: T_15_1 - T_1_1 - 324 x_1_15 >= -321
#
# _C419: T_16_1 - T_1_1 - 365 x_1_16 >= -362
#
# _C420: T_17_1 - T_1_1 - 431 x_1_17 >= -428
#
# _C421: T_18_1 - T_1_1 - 524 x_1_18 >= -509
#
# _C422: T_19_1 - T_1_1 - 507 x_1_19 >= -492
#
# _C423: T_0_1 - T_2_1 - 450 x_2_0 >= -435
#
# _C424: T_1_1 - T_2_1 - 356 x_2_1 >= -353
#
# _C425: - T_2_1 + T_3_1 - 415 x_2_3 >= -400
#
# _C426: - T_2_1 + T_4_1 - 292 x_2_4 >= -289
#
# _C427: - T_2_1 + T_5_1 - 419 x_2_5 >= -404
#
# _C428: - T_2_1 + T_6_1 - 309 x_2_6 >= -306
#
# _C429: - T_2_1 + T_7_1 - 416 x_2_7 >= -401
#
# _C430: - T_2_1 + T_8_1 - 401 x_2_8 >= -386
#
# _C431: - T_2_1 + T_9_1 - 399 x_2_9 >= -384
#
# _C432: T_10_1 - T_2_1 - 383 x_2_10 >= -368
#
# _C433: T_11_1 - T_2_1 - 418 x_2_11 >= -403
#
# _C434: T_12_1 - T_2_1 - 260 x_2_12 >= -257
#
# _C435: T_13_1 - T_2_1 - 268 x_2_13 >= -265
#
# _C436: T_14_1 - T_2_1 - 278 x_2_14 >= -275
#
# _C437: T_15_1 - T_2_1 - 185 x_2_15 >= -182
#
# _C438: T_16_1 - T_2_1 - 226 x_2_16 >= -223
#
# _C439: T_17_1 - T_2_1 - 292 x_2_17 >= -289
#
# _C440: T_18_1 - T_2_1 - 385 x_2_18 >= -370
#
# _C441: T_19_1 - T_2_1 - 368 x_2_19 >= -353
#
# _C442: T_0_1 - T_3_1 - 393 x_3_0 >= -385
#
# _C443: T_1_1 - T_3_1 - 318 x_3_1 >= -303
#
# _C444: T_2_1 - T_3_1 - 350 x_3_2 >= -335
#
# _C445: - T_3_1 + T_4_1 - 254 x_3_4 >= -239
#
# _C446: - T_3_1 + T_5_1 - 362 x_3_5 >= -354
#
# _C447: - T_3_1 + T_6_1 - 271 x_3_6 >= -256
#
# _C448: - T_3_1 + T_7_1 - 359 x_3_7 >= -351
#
# _C449: - T_3_1 + T_8_1 - 344 x_3_8 >= -336
#
# _C450: - T_3_1 + T_9_1 - 342 x_3_9 >= -334
#
# _C451: T_10_1 - T_3_1 - 326 x_3_10 >= -318
#
# _C452: T_11_1 - T_3_1 - 361 x_3_11 >= -353
#
# _C453: T_12_1 - T_3_1 - 222 x_3_12 >= -207
#
# _C454: T_13_1 - T_3_1 - 230 x_3_13 >= -215
#
# _C455: T_14_1 - T_3_1 - 240 x_3_14 >= -225
#
# _C456: T_15_1 - T_3_1 - 147 x_3_15 >= -132
#
# _C457: T_16_1 - T_3_1 - 188 x_3_16 >= -173
#
# _C458: T_17_1 - T_3_1 - 254 x_3_17 >= -239
#
# _C459: T_18_1 - T_3_1 - 328 x_3_18 >= -320
#
# _C460: T_19_1 - T_3_1 - 311 x_3_19 >= -303
#
# _C461: T_0_1 - T_4_1 - 1020 x_4_0 >= -1005
#
# _C462: T_1_1 - T_4_1 - 926 x_4_1 >= -923
#
# _C463: T_2_1 - T_4_1 - 958 x_4_2 >= -955
#
# _C464: T_3_1 - T_4_1 - 985 x_4_3 >= -970
#
# _C465: - T_4_1 + T_5_1 - 989 x_4_5 >= -974
#
# _C466: - T_4_1 + T_6_1 - 879 x_4_6 >= -876
#
# _C467: - T_4_1 + T_7_1 - 986 x_4_7 >= -971
#
# _C468: - T_4_1 + T_8_1 - 971 x_4_8 >= -956
#
# _C469: - T_4_1 + T_9_1 - 969 x_4_9 >= -954
#
# _C470: T_10_1 - T_4_1 - 953 x_4_10 >= -938
#
# _C471: T_11_1 - T_4_1 - 988 x_4_11 >= -973
#
# _C472: T_12_1 - T_4_1 - 830 x_4_12 >= -827
#
# _C473: T_13_1 - T_4_1 - 838 x_4_13 >= -835
#
# _C474: T_14_1 - T_4_1 - 848 x_4_14 >= -845
#
# _C475: T_15_1 - T_4_1 - 755 x_4_15 >= -752
#
# _C476: T_16_1 - T_4_1 - 796 x_4_16 >= -793
#
# _C477: T_17_1 - T_4_1 - 862 x_4_17 >= -859
#
# _C478: T_18_1 - T_4_1 - 955 x_4_18 >= -940
#
# _C479: T_19_1 - T_4_1 - 938 x_4_19 >= -923
#
# _C480: T_0_1 - T_5_1 - 372 x_5_0 >= -364
#
# _C481: T_1_1 - T_5_1 - 297 x_5_1 >= -282
#
# _C482: T_2_1 - T_5_1 - 329 x_5_2 >= -314
#
# _C483: T_3_1 - T_5_1 - 337 x_5_3 >= -329
#
# _C484: T_4_1 - T_5_1 - 233 x_5_4 >= -218
#
# _C485: - T_5_1 + T_6_1 - 250 x_5_6 >= -235
#
# _C486: - T_5_1 + T_7_1 - 338 x_5_7 >= -330
#
# _C487: - T_5_1 + T_8_1 - 323 x_5_8 >= -315
#
# _C488: - T_5_1 + T_9_1 - 321 x_5_9 >= -313
#
# _C489: T_10_1 - T_5_1 - 305 x_5_10 >= -297
#
# _C490: T_11_1 - T_5_1 - 340 x_5_11 >= -332
#
# _C491: T_12_1 - T_5_1 - 201 x_5_12 >= -186
#
# _C492: T_13_1 - T_5_1 - 209 x_5_13 >= -194
#
# _C493: T_14_1 - T_5_1 - 219 x_5_14 >= -204
#
# _C494: T_15_1 - T_5_1 - 126 x_5_15 >= -111
#
# _C495: T_16_1 - T_5_1 - 167 x_5_16 >= -152
#
# _C496: T_17_1 - T_5_1 - 233 x_5_17 >= -218
#
# _C497: T_18_1 - T_5_1 - 307 x_5_18 >= -299
#
# _C498: T_19_1 - T_5_1 - 290 x_5_19 >= -282
#
# _C499: T_0_1 - T_6_1 - 886 x_6_0 >= -871
#
# _C500: T_1_1 - T_6_1 - 792 x_6_1 >= -789
#
# _C501: T_2_1 - T_6_1 - 824 x_6_2 >= -821
#
# _C502: T_3_1 - T_6_1 - 851 x_6_3 >= -836
#
# _C503: T_4_1 - T_6_1 - 728 x_6_4 >= -725
#
# _C504: T_5_1 - T_6_1 - 855 x_6_5 >= -840
#
# _C505: - T_6_1 + T_7_1 - 852 x_6_7 >= -837
#
# _C506: - T_6_1 + T_8_1 - 837 x_6_8 >= -822
#
# _C507: - T_6_1 + T_9_1 - 835 x_6_9 >= -820
#
# _C508: T_10_1 - T_6_1 - 819 x_6_10 >= -804
#
# _C509: T_11_1 - T_6_1 - 854 x_6_11 >= -839
#
# _C510: T_12_1 - T_6_1 - 696 x_6_12 >= -693
#
# _C511: T_13_1 - T_6_1 - 704 x_6_13 >= -701
#
# _C512: T_14_1 - T_6_1 - 714 x_6_14 >= -711
#
# _C513: T_15_1 - T_6_1 - 621 x_6_15 >= -618
#
# _C514: T_16_1 - T_6_1 - 662 x_6_16 >= -659
#
# _C515: T_17_1 - T_6_1 - 728 x_6_17 >= -725
#
# _C516: T_18_1 - T_6_1 - 821 x_6_18 >= -806
#
# _C517: T_19_1 - T_6_1 - 804 x_6_19 >= -789
#
# _C518: T_0_1 - T_7_1 - 426 x_7_0 >= -418
#
# _C519: T_1_1 - T_7_1 - 351 x_7_1 >= -336
#
# _C520: T_2_1 - T_7_1 - 383 x_7_2 >= -368
#
# _C521: T_3_1 - T_7_1 - 391 x_7_3 >= -383
#
# _C522: T_4_1 - T_7_1 - 287 x_7_4 >= -272
#
# _C523: T_5_1 - T_7_1 - 395 x_7_5 >= -387
#
# _C524: T_6_1 - T_7_1 - 304 x_7_6 >= -289
#
# _C525: - T_7_1 + T_8_1 - 377 x_7_8 >= -369
#
# _C526: - T_7_1 + T_9_1 - 375 x_7_9 >= -367
#
# _C527: T_10_1 - T_7_1 - 359 x_7_10 >= -351
#
# _C528: T_11_1 - T_7_1 - 394 x_7_11 >= -386
#
# _C529: T_12_1 - T_7_1 - 255 x_7_12 >= -240
#
# _C530: T_13_1 - T_7_1 - 263 x_7_13 >= -248
#
# _C531: T_14_1 - T_7_1 - 273 x_7_14 >= -258
#
# _C532: T_15_1 - T_7_1 - 180 x_7_15 >= -165
#
# _C533: T_16_1 - T_7_1 - 221 x_7_16 >= -206
#
# _C534: T_17_1 - T_7_1 - 287 x_7_17 >= -272
#
# _C535: T_18_1 - T_7_1 - 361 x_7_18 >= -353
#
# _C536: T_19_1 - T_7_1 - 344 x_7_19 >= -336
#
# _C537: T_0_1 - T_8_1 - 480 x_8_0 >= -472
#
# _C538: T_1_1 - T_8_1 - 405 x_8_1 >= -390
#
# _C539: T_2_1 - T_8_1 - 437 x_8_2 >= -422
#
# _C540: T_3_1 - T_8_1 - 445 x_8_3 >= -437
#
# _C541: T_4_1 - T_8_1 - 341 x_8_4 >= -326
#
# _C542: T_5_1 - T_8_1 - 449 x_8_5 >= -441
#
# _C543: T_6_1 - T_8_1 - 358 x_8_6 >= -343
#
# _C544: T_7_1 - T_8_1 - 446 x_8_7 >= -438
#
# _C545: - T_8_1 + T_9_1 - 429 x_8_9 >= -421
#
# _C546: T_10_1 - T_8_1 - 413 x_8_10 >= -405
#
# _C547: T_11_1 - T_8_1 - 448 x_8_11 >= -440
#
# _C548: T_12_1 - T_8_1 - 309 x_8_12 >= -294
#
# _C549: T_13_1 - T_8_1 - 317 x_8_13 >= -302
#
# _C550: T_14_1 - T_8_1 - 327 x_8_14 >= -312
#
# _C551: T_15_1 - T_8_1 - 234 x_8_15 >= -219
#
# _C552: T_16_1 - T_8_1 - 275 x_8_16 >= -260
#
# _C553: T_17_1 - T_8_1 - 341 x_8_17 >= -326
#
# _C554: T_18_1 - T_8_1 - 415 x_8_18 >= -407
#
# _C555: T_19_1 - T_8_1 - 398 x_8_19 >= -390
#
# _C556: T_0_1 - T_9_1 - 524 x_9_0 >= -516
#
# _C557: T_1_1 - T_9_1 - 449 x_9_1 >= -434
#
# _C558: T_2_1 - T_9_1 - 481 x_9_2 >= -466
#
# _C559: T_3_1 - T_9_1 - 489 x_9_3 >= -481
#
# _C560: T_4_1 - T_9_1 - 385 x_9_4 >= -370
#
# _C561: T_5_1 - T_9_1 - 493 x_9_5 >= -485
#
# _C562: T_6_1 - T_9_1 - 402 x_9_6 >= -387
#
# _C563: T_7_1 - T_9_1 - 490 x_9_7 >= -482
#
# _C564: T_8_1 - T_9_1 - 475 x_9_8 >= -467
#
# _C565: T_10_1 - T_9_1 - 457 x_9_10 >= -449
#
# _C566: T_11_1 - T_9_1 - 492 x_9_11 >= -484
#
# _C567: T_12_1 - T_9_1 - 353 x_9_12 >= -338
#
# _C568: T_13_1 - T_9_1 - 361 x_9_13 >= -346
#
# _C569: T_14_1 - T_9_1 - 371 x_9_14 >= -356
#
# _C570: T_15_1 - T_9_1 - 278 x_9_15 >= -263
#
# _C571: T_16_1 - T_9_1 - 319 x_9_16 >= -304
#
# _C572: T_17_1 - T_9_1 - 385 x_9_17 >= -370
#
# _C573: T_18_1 - T_9_1 - 459 x_9_18 >= -451
#
# _C574: T_19_1 - T_9_1 - 442 x_9_19 >= -434
#
# _C575: T_0_1 - T_10_1 - 583 x_10_0 >= -575
#
# _C576: - T_10_1 + T_1_1 - 508 x_10_1 >= -493
#
# _C577: - T_10_1 + T_2_1 - 540 x_10_2 >= -525
#
# _C578: - T_10_1 + T_3_1 - 548 x_10_3 >= -540
#
# _C579: - T_10_1 + T_4_1 - 444 x_10_4 >= -429
#
# _C580: - T_10_1 + T_5_1 - 552 x_10_5 >= -544
#
# _C581: - T_10_1 + T_6_1 - 461 x_10_6 >= -446
#
# _C582: - T_10_1 + T_7_1 - 549 x_10_7 >= -541
#
# _C583: - T_10_1 + T_8_1 - 534 x_10_8 >= -526
#
# _C584: - T_10_1 + T_9_1 - 532 x_10_9 >= -524
#
# _C585: - T_10_1 + T_11_1 - 551 x_10_11 >= -543
#
# _C586: - T_10_1 + T_12_1 - 412 x_10_12 >= -397
#
# _C587: - T_10_1 + T_13_1 - 420 x_10_13 >= -405
#
# _C588: - T_10_1 + T_14_1 - 430 x_10_14 >= -415
#
# _C589: - T_10_1 + T_15_1 - 337 x_10_15 >= -322
#
# _C590: - T_10_1 + T_16_1 - 378 x_10_16 >= -363
#
# _C591: - T_10_1 + T_17_1 - 444 x_10_17 >= -429
#
# _C592: - T_10_1 + T_18_1 - 518 x_10_18 >= -510
#
# _C593: - T_10_1 + T_19_1 - 501 x_10_19 >= -493
#
# _C594: T_0_1 - T_11_1 - 426 x_11_0 >= -418
#
# _C595: - T_11_1 + T_1_1 - 351 x_11_1 >= -336
#
# _C596: - T_11_1 + T_2_1 - 383 x_11_2 >= -368
#
# _C597: - T_11_1 + T_3_1 - 391 x_11_3 >= -383
#
# _C598: - T_11_1 + T_4_1 - 287 x_11_4 >= -272
#
# _C599: - T_11_1 + T_5_1 - 395 x_11_5 >= -387
#
# _C600: - T_11_1 + T_6_1 - 304 x_11_6 >= -289
#
# _C601: - T_11_1 + T_7_1 - 392 x_11_7 >= -384
#
# _C602: - T_11_1 + T_8_1 - 377 x_11_8 >= -369
#
# _C603: - T_11_1 + T_9_1 - 375 x_11_9 >= -367
#
# _C604: T_10_1 - T_11_1 - 359 x_11_10 >= -351
#
# _C605: - T_11_1 + T_12_1 - 255 x_11_12 >= -240
#
# _C606: - T_11_1 + T_13_1 - 263 x_11_13 >= -248
#
# _C607: - T_11_1 + T_14_1 - 273 x_11_14 >= -258
#
# _C608: - T_11_1 + T_15_1 - 180 x_11_15 >= -165
#
# _C609: - T_11_1 + T_16_1 - 221 x_11_16 >= -206
#
# _C610: - T_11_1 + T_17_1 - 287 x_11_17 >= -272
#
# _C611: - T_11_1 + T_18_1 - 361 x_11_18 >= -353
#
# _C612: - T_11_1 + T_19_1 - 344 x_11_19 >= -336
#
# _C613: T_0_1 - T_12_1 - 973 x_12_0 >= -958
#
# _C614: - T_12_1 + T_1_1 - 879 x_12_1 >= -876
#
# _C615: - T_12_1 + T_2_1 - 911 x_12_2 >= -908
#
# _C616: - T_12_1 + T_3_1 - 938 x_12_3 >= -923
#
# _C617: - T_12_1 + T_4_1 - 815 x_12_4 >= -812
#
# _C618: - T_12_1 + T_5_1 - 942 x_12_5 >= -927
#
# _C619: - T_12_1 + T_6_1 - 832 x_12_6 >= -829
#
# _C620: - T_12_1 + T_7_1 - 939 x_12_7 >= -924
#
# _C621: - T_12_1 + T_8_1 - 924 x_12_8 >= -909
#
# _C622: - T_12_1 + T_9_1 - 922 x_12_9 >= -907
#
# _C623: T_10_1 - T_12_1 - 906 x_12_10 >= -891
#
# _C624: T_11_1 - T_12_1 - 941 x_12_11 >= -926
#
# _C625: - T_12_1 + T_13_1 - 791 x_12_13 >= -788
#
# _C626: - T_12_1 + T_14_1 - 801 x_12_14 >= -798
#
# _C627: - T_12_1 + T_15_1 - 708 x_12_15 >= -705
#
# _C628: - T_12_1 + T_16_1 - 749 x_12_16 >= -746
#
# _C629: - T_12_1 + T_17_1 - 815 x_12_17 >= -812
#
# _C630: - T_12_1 + T_18_1 - 908 x_12_18 >= -893
#
# _C631: - T_12_1 + T_19_1 - 891 x_12_19 >= -876
#
# _C632: T_0_1 - T_13_1 - 931 x_13_0 >= -916
#
# _C633: - T_13_1 + T_1_1 - 837 x_13_1 >= -834
#
# _C634: - T_13_1 + T_2_1 - 869 x_13_2 >= -866
#
# _C635: - T_13_1 + T_3_1 - 896 x_13_3 >= -881
#
# _C636: - T_13_1 + T_4_1 - 773 x_13_4 >= -770
#
# _C637: - T_13_1 + T_5_1 - 900 x_13_5 >= -885
#
# _C638: - T_13_1 + T_6_1 - 790 x_13_6 >= -787
#
# _C639: - T_13_1 + T_7_1 - 897 x_13_7 >= -882
#
# _C640: - T_13_1 + T_8_1 - 882 x_13_8 >= -867
#
# _C641: - T_13_1 + T_9_1 - 880 x_13_9 >= -865
#
# _C642: T_10_1 - T_13_1 - 864 x_13_10 >= -849
#
# _C643: T_11_1 - T_13_1 - 899 x_13_11 >= -884
#
# _C644: T_12_1 - T_13_1 - 741 x_13_12 >= -738
#
# _C645: - T_13_1 + T_14_1 - 759 x_13_14 >= -756
#
# _C646: - T_13_1 + T_15_1 - 666 x_13_15 >= -663
#
# _C647: - T_13_1 + T_16_1 - 707 x_13_16 >= -704
#
# _C648: - T_13_1 + T_17_1 - 773 x_13_17 >= -770
#
# _C649: - T_13_1 + T_18_1 - 866 x_13_18 >= -851
#
# _C650: - T_13_1 + T_19_1 - 849 x_13_19 >= -834
#
# _C651: T_0_1 - T_14_1 - 953 x_14_0 >= -938
#
# _C652: - T_14_1 + T_1_1 - 859 x_14_1 >= -856
#
# _C653: - T_14_1 + T_2_1 - 891 x_14_2 >= -888
#
# _C654: - T_14_1 + T_3_1 - 918 x_14_3 >= -903
#
# _C655: - T_14_1 + T_4_1 - 795 x_14_4 >= -792
#
# _C656: - T_14_1 + T_5_1 - 922 x_14_5 >= -907
#
# _C657: - T_14_1 + T_6_1 - 812 x_14_6 >= -809
#
# _C658: - T_14_1 + T_7_1 - 919 x_14_7 >= -904
#
# _C659: - T_14_1 + T_8_1 - 904 x_14_8 >= -889
#
# _C660: - T_14_1 + T_9_1 - 902 x_14_9 >= -887
#
# _C661: T_10_1 - T_14_1 - 886 x_14_10 >= -871
#
# _C662: T_11_1 - T_14_1 - 921 x_14_11 >= -906
#
# _C663: T_12_1 - T_14_1 - 763 x_14_12 >= -760
#
# _C664: T_13_1 - T_14_1 - 771 x_14_13 >= -768
#
# _C665: - T_14_1 + T_15_1 - 688 x_14_15 >= -685
#
# _C666: - T_14_1 + T_16_1 - 729 x_14_16 >= -726
#
# _C667: - T_14_1 + T_17_1 - 795 x_14_17 >= -792
#
# _C668: - T_14_1 + T_18_1 - 888 x_14_18 >= -873
#
# _C669: - T_14_1 + T_19_1 - 871 x_14_19 >= -856
#
# _C670: T_0_1 - T_15_1 - 1383 x_15_0 >= -1368
#
# _C671: - T_15_1 + T_1_1 - 1289 x_15_1 >= -1286
#
# _C672: - T_15_1 + T_2_1 - 1321 x_15_2 >= -1318
#
# _C673: - T_15_1 + T_3_1 - 1348 x_15_3 >= -1333
#
# _C674: - T_15_1 + T_4_1 - 1225 x_15_4 >= -1222
#
# _C675: - T_15_1 + T_5_1 - 1352 x_15_5 >= -1337
#
# _C676: - T_15_1 + T_6_1 - 1242 x_15_6 >= -1239
#
# _C677: - T_15_1 + T_7_1 - 1349 x_15_7 >= -1334
#
# _C678: - T_15_1 + T_8_1 - 1334 x_15_8 >= -1319
#
# _C679: - T_15_1 + T_9_1 - 1332 x_15_9 >= -1317
#
# _C680: T_10_1 - T_15_1 - 1316 x_15_10 >= -1301
#
# _C681: T_11_1 - T_15_1 - 1351 x_15_11 >= -1336
#
# _C682: T_12_1 - T_15_1 - 1193 x_15_12 >= -1190
#
# _C683: T_13_1 - T_15_1 - 1201 x_15_13 >= -1198
#
# _C684: T_14_1 - T_15_1 - 1211 x_15_14 >= -1208
#
# _C685: - T_15_1 + T_16_1 - 1159 x_15_16 >= -1156
#
# _C686: - T_15_1 + T_17_1 - 1225 x_15_17 >= -1222
#
# _C687: - T_15_1 + T_18_1 - 1318 x_15_18 >= -1303
#
# _C688: - T_15_1 + T_19_1 - 1301 x_15_19 >= -1286
#
# _C689: T_0_1 - T_16_1 - 1275 x_16_0 >= -1260
#
# _C690: - T_16_1 + T_1_1 - 1181 x_16_1 >= -1178
#
# _C691: - T_16_1 + T_2_1 - 1213 x_16_2 >= -1210
#
# _C692: - T_16_1 + T_3_1 - 1240 x_16_3 >= -1225
#
# _C693: - T_16_1 + T_4_1 - 1117 x_16_4 >= -1114
#
# _C694: - T_16_1 + T_5_1 - 1244 x_16_5 >= -1229
#
# _C695: - T_16_1 + T_6_1 - 1134 x_16_6 >= -1131
#
# _C696: - T_16_1 + T_7_1 - 1241 x_16_7 >= -1226
#
# _C697: - T_16_1 + T_8_1 - 1226 x_16_8 >= -1211
#
# _C698: - T_16_1 + T_9_1 - 1224 x_16_9 >= -1209
#
# _C699: T_10_1 - T_16_1 - 1208 x_16_10 >= -1193
#
# _C700: T_11_1 - T_16_1 - 1243 x_16_11 >= -1228
#
# _C701: T_12_1 - T_16_1 - 1085 x_16_12 >= -1082
#
# _C702: T_13_1 - T_16_1 - 1093 x_16_13 >= -1090
#
# _C703: T_14_1 - T_16_1 - 1103 x_16_14 >= -1100
#
# _C704: T_15_1 - T_16_1 - 1010 x_16_15 >= -1007
#
# _C705: - T_16_1 + T_17_1 - 1117 x_16_17 >= -1114
#
# _C706: - T_16_1 + T_18_1 - 1210 x_16_18 >= -1195
#
# _C707: - T_16_1 + T_19_1 - 1193 x_16_19 >= -1178
#
# _C708: T_0_1 - T_17_1 - 1010 x_17_0 >= -995
#
# _C709: - T_17_1 + T_1_1 - 916 x_17_1 >= -913
#
# _C710: - T_17_1 + T_2_1 - 948 x_17_2 >= -945
#
# _C711: - T_17_1 + T_3_1 - 975 x_17_3 >= -960
#
# _C712: - T_17_1 + T_4_1 - 852 x_17_4 >= -849
#
# _C713: - T_17_1 + T_5_1 - 979 x_17_5 >= -964
#
# _C714: - T_17_1 + T_6_1 - 869 x_17_6 >= -866
#
# _C715: - T_17_1 + T_7_1 - 976 x_17_7 >= -961
#
# _C716: - T_17_1 + T_8_1 - 961 x_17_8 >= -946
#
# _C717: - T_17_1 + T_9_1 - 959 x_17_9 >= -944
#
# _C718: T_10_1 - T_17_1 - 943 x_17_10 >= -928
#
# _C719: T_11_1 - T_17_1 - 978 x_17_11 >= -963
#
# _C720: T_12_1 - T_17_1 - 820 x_17_12 >= -817
#
# _C721: T_13_1 - T_17_1 - 828 x_17_13 >= -825
#
# _C722: T_14_1 - T_17_1 - 838 x_17_14 >= -835
#
# _C723: T_15_1 - T_17_1 - 745 x_17_15 >= -742
#
# _C724: T_16_1 - T_17_1 - 786 x_17_16 >= -783
#
# _C725: - T_17_1 + T_18_1 - 945 x_17_18 >= -930
#
# _C726: - T_17_1 + T_19_1 - 928 x_17_19 >= -913
#
# _C727: T_0_1 - T_18_1 - 564 x_18_0 >= -556
#
# _C728: - T_18_1 + T_1_1 - 489 x_18_1 >= -474
#
# _C729: - T_18_1 + T_2_1 - 521 x_18_2 >= -506
#
# _C730: - T_18_1 + T_3_1 - 529 x_18_3 >= -521
#
# _C731: - T_18_1 + T_4_1 - 425 x_18_4 >= -410
#
# _C732: - T_18_1 + T_5_1 - 533 x_18_5 >= -525
#
# _C733: - T_18_1 + T_6_1 - 442 x_18_6 >= -427
#
# _C734: - T_18_1 + T_7_1 - 530 x_18_7 >= -522
#
# _C735: - T_18_1 + T_8_1 - 515 x_18_8 >= -507
#
# _C736: - T_18_1 + T_9_1 - 513 x_18_9 >= -505
#
# _C737: T_10_1 - T_18_1 - 497 x_18_10 >= -489
#
# _C738: T_11_1 - T_18_1 - 532 x_18_11 >= -524
#
# _C739: T_12_1 - T_18_1 - 393 x_18_12 >= -378
#
# _C740: T_13_1 - T_18_1 - 401 x_18_13 >= -386
#
# _C741: T_14_1 - T_18_1 - 411 x_18_14 >= -396
#
# _C742: T_15_1 - T_18_1 - 318 x_18_15 >= -303
#
# _C743: T_16_1 - T_18_1 - 359 x_18_16 >= -344
#
# _C744: T_17_1 - T_18_1 - 425 x_18_17 >= -410
#
# _C745: - T_18_1 + T_19_1 - 482 x_18_19 >= -474
#
# _C746: T_0_1 - T_19_1 - 702 x_19_0 >= -694
#
# _C747: - T_19_1 + T_1_1 - 627 x_19_1 >= -612
#
# _C748: - T_19_1 + T_2_1 - 659 x_19_2 >= -644
#
# _C749: - T_19_1 + T_3_1 - 667 x_19_3 >= -659
#
# _C750: - T_19_1 + T_4_1 - 563 x_19_4 >= -548
#
# _C751: - T_19_1 + T_5_1 - 671 x_19_5 >= -663
#
# _C752: - T_19_1 + T_6_1 - 580 x_19_6 >= -565
#
# _C753: - T_19_1 + T_7_1 - 668 x_19_7 >= -660
#
# _C754: - T_19_1 + T_8_1 - 653 x_19_8 >= -645
#
# _C755: - T_19_1 + T_9_1 - 651 x_19_9 >= -643
#
# _C756: T_10_1 - T_19_1 - 635 x_19_10 >= -627
#
# _C757: T_11_1 - T_19_1 - 670 x_19_11 >= -662
#
# _C758: T_12_1 - T_19_1 - 531 x_19_12 >= -516
#
# _C759: T_13_1 - T_19_1 - 539 x_19_13 >= -524
#
# _C760: T_14_1 - T_19_1 - 549 x_19_14 >= -534
#
# _C761: T_15_1 - T_19_1 - 456 x_19_15 >= -441
#
# _C762: T_16_1 - T_19_1 - 497 x_19_16 >= -482
#
# _C763: T_17_1 - T_19_1 - 563 x_19_17 >= -548
#
# _C764: T_18_1 - T_19_1 - 637 x_19_18 >= -629
#
# _C765: - T_0_2 + T_1_2 - 207 x_0_1 >= -192
#
# _C766: - T_0_2 + T_2_2 - 239 x_0_2 >= -224
#
# _C767: - T_0_2 + T_3_2 - 276 x_0_3 >= -268
#
# _C768: - T_0_2 + T_4_2 - 160 x_0_4 >= -145
#
# _C769: - T_0_2 + T_5_2 - 271 x_0_5 >= -263
#
# _C770: - T_0_2 + T_6_2 - 188 x_0_6 >= -173
#
# _C771: - T_0_2 + T_7_2 - 279 x_0_7 >= -271
#
# _C772: - T_0_2 + T_8_2 - 253 x_0_8 >= -245
#
# _C773: - T_0_2 + T_9_2 - 245 x_0_9 >= -237
#
# _C774: - T_0_2 + T_10_2 - 248 x_0_10 >= -240
#
# _C775: - T_0_2 + T_11_2 - 254 x_0_11 >= -246
#
# _C776: - T_0_2 + T_12_2 - 127 x_0_12 >= -112
#
# _C777: - T_0_2 + T_13_2 - 127 x_0_13 >= -112
#
# _C778: - T_0_2 + T_14_2 - 154 x_0_14 >= -139
#
# _C779: - T_0_2 + T_15_2 - 65 x_0_15 >= -50
#
# _C780: - T_0_2 + T_16_2 - 92 x_0_16 >= -77
#
# _C781: - T_0_2 + T_17_2 - 158 x_0_17 >= -143
#
# _C782: - T_0_2 + T_18_2 - 219 x_0_18 >= -211
#
# _C783: - T_0_2 + T_19_2 - 210 x_0_19 >= -202
#
# _C784: T_0_2 - T_1_2 - 635 x_1_0 >= -620
#
# _C785: - T_1_2 + T_2_2 - 560 x_1_2 >= -557
#
# _C786: - T_1_2 + T_3_2 - 616 x_1_3 >= -601
#
# _C787: - T_1_2 + T_4_2 - 481 x_1_4 >= -478
#
# _C788: - T_1_2 + T_5_2 - 611 x_1_5 >= -596
#
# _C789: - T_1_2 + T_6_2 - 509 x_1_6 >= -506
#
# _C790: - T_1_2 + T_7_2 - 619 x_1_7 >= -604
#
# _C791: - T_1_2 + T_8_2 - 593 x_1_8 >= -578
#
# _C792: - T_1_2 + T_9_2 - 585 x_1_9 >= -570
#
# _C793: T_10_2 - T_1_2 - 588 x_1_10 >= -573
#
# _C794: T_11_2 - T_1_2 - 594 x_1_11 >= -579
#
# _C795: T_12_2 - T_1_2 - 448 x_1_12 >= -445
#
# _C796: T_13_2 - T_1_2 - 448 x_1_13 >= -445
#
# _C797: T_14_2 - T_1_2 - 475 x_1_14 >= -472
#
# _C798: T_15_2 - T_1_2 - 386 x_1_15 >= -383
#
# _C799: T_16_2 - T_1_2 - 413 x_1_16 >= -410
#
# _C800: T_17_2 - T_1_2 - 479 x_1_17 >= -476
#
# _C801: T_18_2 - T_1_2 - 559 x_1_18 >= -544
#
# _C802: T_19_2 - T_1_2 - 550 x_1_19 >= -535
#
# _C803: T_0_2 - T_2_2 - 596 x_2_0 >= -581
#
# _C804: T_1_2 - T_2_2 - 489 x_2_1 >= -486
#
# _C805: - T_2_2 + T_3_2 - 577 x_2_3 >= -562
#
# _C806: - T_2_2 + T_4_2 - 442 x_2_4 >= -439
#
# _C807: - T_2_2 + T_5_2 - 572 x_2_5 >= -557
#
# _C808: - T_2_2 + T_6_2 - 470 x_2_6 >= -467
#
# _C809: - T_2_2 + T_7_2 - 580 x_2_7 >= -565
#
# _C810: - T_2_2 + T_8_2 - 554 x_2_8 >= -539
#
# _C811: - T_2_2 + T_9_2 - 546 x_2_9 >= -531
#
# _C812: T_10_2 - T_2_2 - 549 x_2_10 >= -534
#
# _C813: T_11_2 - T_2_2 - 555 x_2_11 >= -540
#
# _C814: T_12_2 - T_2_2 - 409 x_2_12 >= -406
#
# _C815: T_13_2 - T_2_2 - 409 x_2_13 >= -406
#
# _C816: T_14_2 - T_2_2 - 436 x_2_14 >= -433
#
# _C817: T_15_2 - T_2_2 - 347 x_2_15 >= -344
#
# _C818: T_16_2 - T_2_2 - 374 x_2_16 >= -371
#
# _C819: T_17_2 - T_2_2 - 440 x_2_17 >= -437
#
# _C820: T_18_2 - T_2_2 - 520 x_2_18 >= -505
#
# _C821: T_19_2 - T_2_2 - 511 x_2_19 >= -496
#
# _C822: T_0_2 - T_3_2 - 406 x_3_0 >= -398
#
# _C823: T_1_2 - T_3_2 - 318 x_3_1 >= -303
#
# _C824: T_2_2 - T_3_2 - 350 x_3_2 >= -335
#
# _C825: - T_3_2 + T_4_2 - 271 x_3_4 >= -256
#
# _C826: - T_3_2 + T_5_2 - 382 x_3_5 >= -374
#
# _C827: - T_3_2 + T_6_2 - 299 x_3_6 >= -284
#
# _C828: - T_3_2 + T_7_2 - 390 x_3_7 >= -382
#
# _C829: - T_3_2 + T_8_2 - 364 x_3_8 >= -356
#
# _C830: - T_3_2 + T_9_2 - 356 x_3_9 >= -348
#
# _C831: T_10_2 - T_3_2 - 359 x_3_10 >= -351
#
# _C832: T_11_2 - T_3_2 - 365 x_3_11 >= -357
#
# _C833: T_12_2 - T_3_2 - 238 x_3_12 >= -223
#
# _C834: T_13_2 - T_3_2 - 238 x_3_13 >= -223
#
# _C835: T_14_2 - T_3_2 - 265 x_3_14 >= -250
#
# _C836: T_15_2 - T_3_2 - 176 x_3_15 >= -161
#
# _C837: T_16_2 - T_3_2 - 203 x_3_16 >= -188
#
# _C838: T_17_2 - T_3_2 - 269 x_3_17 >= -254
#
# _C839: T_18_2 - T_3_2 - 330 x_3_18 >= -322
#
# _C840: T_19_2 - T_3_2 - 321 x_3_19 >= -313
#
# _C841: T_0_2 - T_4_2 - 947 x_4_0 >= -932
#
# _C842: T_1_2 - T_4_2 - 840 x_4_1 >= -837
#
# _C843: T_2_2 - T_4_2 - 872 x_4_2 >= -869
#
# _C844: T_3_2 - T_4_2 - 928 x_4_3 >= -913
#
# _C845: - T_4_2 + T_5_2 - 923 x_4_5 >= -908
#
# _C846: - T_4_2 + T_6_2 - 821 x_4_6 >= -818
#
# _C847: - T_4_2 + T_7_2 - 931 x_4_7 >= -916
#
# _C848: - T_4_2 + T_8_2 - 905 x_4_8 >= -890
#
# _C849: - T_4_2 + T_9_2 - 897 x_4_9 >= -882
#
# _C850: T_10_2 - T_4_2 - 900 x_4_10 >= -885
#
# _C851: T_11_2 - T_4_2 - 906 x_4_11 >= -891
#
# _C852: T_12_2 - T_4_2 - 760 x_4_12 >= -757
#
# _C853: T_13_2 - T_4_2 - 760 x_4_13 >= -757
#
# _C854: T_14_2 - T_4_2 - 787 x_4_14 >= -784
#
# _C855: T_15_2 - T_4_2 - 698 x_4_15 >= -695
#
# _C856: T_16_2 - T_4_2 - 725 x_4_16 >= -722
#
# _C857: T_17_2 - T_4_2 - 791 x_4_17 >= -788
#
# _C858: T_18_2 - T_4_2 - 871 x_4_18 >= -856
#
# _C859: T_19_2 - T_4_2 - 862 x_4_19 >= -847
#
# _C860: T_0_2 - T_5_2 - 427 x_5_0 >= -419
#
# _C861: T_1_2 - T_5_2 - 339 x_5_1 >= -324
#
# _C862: T_2_2 - T_5_2 - 371 x_5_2 >= -356
#
# _C863: T_3_2 - T_5_2 - 408 x_5_3 >= -400
#
# _C864: T_4_2 - T_5_2 - 292 x_5_4 >= -277
#
# _C865: - T_5_2 + T_6_2 - 320 x_5_6 >= -305
#
# _C866: - T_5_2 + T_7_2 - 411 x_5_7 >= -403
#
# _C867: - T_5_2 + T_8_2 - 385 x_5_8 >= -377
#
# _C868: - T_5_2 + T_9_2 - 377 x_5_9 >= -369
#
# _C869: T_10_2 - T_5_2 - 380 x_5_10 >= -372
#
# _C870: T_11_2 - T_5_2 - 386 x_5_11 >= -378
#
# _C871: T_12_2 - T_5_2 - 259 x_5_12 >= -244
#
# _C872: T_13_2 - T_5_2 - 259 x_5_13 >= -244
#
# _C873: T_14_2 - T_5_2 - 286 x_5_14 >= -271
#
# _C874: T_15_2 - T_5_2 - 197 x_5_15 >= -182
#
# _C875: T_16_2 - T_5_2 - 224 x_5_16 >= -209
#
# _C876: T_17_2 - T_5_2 - 290 x_5_17 >= -275
#
# _C877: T_18_2 - T_5_2 - 351 x_5_18 >= -343
#
# _C878: T_19_2 - T_5_2 - 342 x_5_19 >= -334
#
# _C879: T_0_2 - T_6_2 - 889 x_6_0 >= -874
#
# _C880: T_1_2 - T_6_2 - 782 x_6_1 >= -779
#
# _C881: T_2_2 - T_6_2 - 814 x_6_2 >= -811
#
# _C882: T_3_2 - T_6_2 - 870 x_6_3 >= -855
#
# _C883: T_4_2 - T_6_2 - 735 x_6_4 >= -732
#
# _C884: T_5_2 - T_6_2 - 865 x_6_5 >= -850
#
# _C885: - T_6_2 + T_7_2 - 873 x_6_7 >= -858
#
# _C886: - T_6_2 + T_8_2 - 847 x_6_8 >= -832
#
# _C887: - T_6_2 + T_9_2 - 839 x_6_9 >= -824
#
# _C888: T_10_2 - T_6_2 - 842 x_6_10 >= -827
#
# _C889: T_11_2 - T_6_2 - 848 x_6_11 >= -833
#
# _C890: T_12_2 - T_6_2 - 702 x_6_12 >= -699
#
# _C891: T_13_2 - T_6_2 - 702 x_6_13 >= -699
#
# _C892: T_14_2 - T_6_2 - 729 x_6_14 >= -726
#
# _C893: T_15_2 - T_6_2 - 640 x_6_15 >= -637
#
# _C894: T_16_2 - T_6_2 - 667 x_6_16 >= -664
#
# _C895: T_17_2 - T_6_2 - 733 x_6_17 >= -730
#
# _C896: T_18_2 - T_6_2 - 813 x_6_18 >= -798
#
# _C897: T_19_2 - T_6_2 - 804 x_6_19 >= -789
#
# _C898: T_0_2 - T_7_2 - 377 x_7_0 >= -369
#
# _C899: T_1_2 - T_7_2 - 289 x_7_1 >= -274
#
# _C900: T_2_2 - T_7_2 - 321 x_7_2 >= -306
#
# _C901: T_3_2 - T_7_2 - 358 x_7_3 >= -350
#
# _C902: T_4_2 - T_7_2 - 242 x_7_4 >= -227
#
# _C903: T_5_2 - T_7_2 - 353 x_7_5 >= -345
#
# _C904: T_6_2 - T_7_2 - 270 x_7_6 >= -255
#
# _C905: - T_7_2 + T_8_2 - 335 x_7_8 >= -327
#
# _C906: - T_7_2 + T_9_2 - 327 x_7_9 >= -319
#
# _C907: T_10_2 - T_7_2 - 330 x_7_10 >= -322
#
# _C908: T_11_2 - T_7_2 - 336 x_7_11 >= -328
#
# _C909: T_12_2 - T_7_2 - 209 x_7_12 >= -194
#
# _C910: T_13_2 - T_7_2 - 209 x_7_13 >= -194
#
# _C911: T_14_2 - T_7_2 - 236 x_7_14 >= -221
#
# _C912: T_15_2 - T_7_2 - 147 x_7_15 >= -132
#
# _C913: T_16_2 - T_7_2 - 174 x_7_16 >= -159
#
# _C914: T_17_2 - T_7_2 - 240 x_7_17 >= -225
#
# _C915: T_18_2 - T_7_2 - 301 x_7_18 >= -293
#
# _C916: T_19_2 - T_7_2 - 292 x_7_19 >= -284
#
# _C917: T_0_2 - T_8_2 - 514 x_8_0 >= -506
#
# _C918: T_1_2 - T_8_2 - 426 x_8_1 >= -411
#
# _C919: T_2_2 - T_8_2 - 458 x_8_2 >= -443
#
# _C920: T_3_2 - T_8_2 - 495 x_8_3 >= -487
#
# _C921: T_4_2 - T_8_2 - 379 x_8_4 >= -364
#
# _C922: T_5_2 - T_8_2 - 490 x_8_5 >= -482
#
# _C923: T_6_2 - T_8_2 - 407 x_8_6 >= -392
#
# _C924: T_7_2 - T_8_2 - 498 x_8_7 >= -490
#
# _C925: - T_8_2 + T_9_2 - 464 x_8_9 >= -456
#
# _C926: T_10_2 - T_8_2 - 467 x_8_10 >= -459
#
# _C927: T_11_2 - T_8_2 - 473 x_8_11 >= -465
#
# _C928: T_12_2 - T_8_2 - 346 x_8_12 >= -331
#
# _C929: T_13_2 - T_8_2 - 346 x_8_13 >= -331
#
# _C930: T_14_2 - T_8_2 - 373 x_8_14 >= -358
#
# _C931: T_15_2 - T_8_2 - 284 x_8_15 >= -269
#
# _C932: T_16_2 - T_8_2 - 311 x_8_16 >= -296
#
# _C933: T_17_2 - T_8_2 - 377 x_8_17 >= -362
#
# _C934: T_18_2 - T_8_2 - 438 x_8_18 >= -430
#
# _C935: T_19_2 - T_8_2 - 429 x_8_19 >= -421
#
# _C936: T_0_2 - T_9_2 - 459 x_9_0 >= -451
#
# _C937: T_1_2 - T_9_2 - 371 x_9_1 >= -356
#
# _C938: T_2_2 - T_9_2 - 403 x_9_2 >= -388
#
# _C939: T_3_2 - T_9_2 - 440 x_9_3 >= -432
#
# _C940: T_4_2 - T_9_2 - 324 x_9_4 >= -309
#
# _C941: T_5_2 - T_9_2 - 435 x_9_5 >= -427
#
# _C942: T_6_2 - T_9_2 - 352 x_9_6 >= -337
#
# _C943: T_7_2 - T_9_2 - 443 x_9_7 >= -435
#
# _C944: T_8_2 - T_9_2 - 417 x_9_8 >= -409
#
# _C945: T_10_2 - T_9_2 - 412 x_9_10 >= -404
#
# _C946: T_11_2 - T_9_2 - 418 x_9_11 >= -410
#
# _C947: T_12_2 - T_9_2 - 291 x_9_12 >= -276
#
# _C948: T_13_2 - T_9_2 - 291 x_9_13 >= -276
#
# _C949: T_14_2 - T_9_2 - 318 x_9_14 >= -303
#
# _C950: T_15_2 - T_9_2 - 229 x_9_15 >= -214
#
# _C951: T_16_2 - T_9_2 - 256 x_9_16 >= -241
#
# _C952: T_17_2 - T_9_2 - 322 x_9_17 >= -307
#
# _C953: T_18_2 - T_9_2 - 383 x_9_18 >= -375
#
# _C954: T_19_2 - T_9_2 - 374 x_9_19 >= -366
#
# _C955: T_0_2 - T_10_2 - 514 x_10_0 >= -506
#
# _C956: - T_10_2 + T_1_2 - 426 x_10_1 >= -411
#
# _C957: - T_10_2 + T_2_2 - 458 x_10_2 >= -443
#
# _C958: - T_10_2 + T_3_2 - 495 x_10_3 >= -487
#
# _C959: - T_10_2 + T_4_2 - 379 x_10_4 >= -364
#
# _C960: - T_10_2 + T_5_2 - 490 x_10_5 >= -482
#
# _C961: - T_10_2 + T_6_2 - 407 x_10_6 >= -392
#
# _C962: - T_10_2 + T_7_2 - 498 x_10_7 >= -490
#
# _C963: - T_10_2 + T_8_2 - 472 x_10_8 >= -464
#
# _C964: - T_10_2 + T_9_2 - 464 x_10_9 >= -456
#
# _C965: - T_10_2 + T_11_2 - 473 x_10_11 >= -465
#
# _C966: - T_10_2 + T_12_2 - 346 x_10_12 >= -331
#
# _C967: - T_10_2 + T_13_2 - 346 x_10_13 >= -331
#
# _C968: - T_10_2 + T_14_2 - 373 x_10_14 >= -358
#
# _C969: - T_10_2 + T_15_2 - 284 x_10_15 >= -269
#
# _C970: - T_10_2 + T_16_2 - 311 x_10_16 >= -296
#
# _C971: - T_10_2 + T_17_2 - 377 x_10_17 >= -362
#
# _C972: - T_10_2 + T_18_2 - 438 x_10_18 >= -430
#
# _C973: - T_10_2 + T_19_2 - 429 x_10_19 >= -421
#
# _C974: T_0_2 - T_11_2 - 455 x_11_0 >= -447
#
# _C975: - T_11_2 + T_1_2 - 367 x_11_1 >= -352
#
# _C976: - T_11_2 + T_2_2 - 399 x_11_2 >= -384
#
# _C977: - T_11_2 + T_3_2 - 436 x_11_3 >= -428
#
# _C978: - T_11_2 + T_4_2 - 320 x_11_4 >= -305
#
# _C979: - T_11_2 + T_5_2 - 431 x_11_5 >= -423
#
# _C980: - T_11_2 + T_6_2 - 348 x_11_6 >= -333
#
# _C981: - T_11_2 + T_7_2 - 439 x_11_7 >= -431
#
# _C982: - T_11_2 + T_8_2 - 413 x_11_8 >= -405
#
# _C983: - T_11_2 + T_9_2 - 405 x_11_9 >= -397
#
# _C984: T_10_2 - T_11_2 - 408 x_11_10 >= -400
#
# _C985: - T_11_2 + T_12_2 - 287 x_11_12 >= -272
#
# _C986: - T_11_2 + T_13_2 - 287 x_11_13 >= -272
#
# _C987: - T_11_2 + T_14_2 - 314 x_11_14 >= -299
#
# _C988: - T_11_2 + T_15_2 - 225 x_11_15 >= -210
#
# _C989: - T_11_2 + T_16_2 - 252 x_11_16 >= -237
#
# _C990: - T_11_2 + T_17_2 - 318 x_11_17 >= -303
#
# _C991: - T_11_2 + T_18_2 - 379 x_11_18 >= -371
#
# _C992: - T_11_2 + T_19_2 - 370 x_11_19 >= -362
#
# _C993: T_0_2 - T_12_2 - 1179 x_12_0 >= -1164
#
# _C994: - T_12_2 + T_1_2 - 1072 x_12_1 >= -1069
#
# _C995: - T_12_2 + T_2_2 - 1104 x_12_2 >= -1101
#
# _C996: - T_12_2 + T_3_2 - 1160 x_12_3 >= -1145
#
# _C997: - T_12_2 + T_4_2 - 1025 x_12_4 >= -1022
#
# _C998: - T_12_2 + T_5_2 - 1155 x_12_5 >= -1140
#
# _C999: - T_12_2 + T_6_2 - 1053 x_12_6 >= -1050
#
# _C1000: - T_12_2 + T_7_2 - 1163 x_12_7 >= -1148
#
# _C1001: - T_12_2 + T_8_2 - 1137 x_12_8 >= -1122
#
# _C1002: - T_12_2 + T_9_2 - 1129 x_12_9 >= -1114
#
# _C1003: T_10_2 - T_12_2 - 1132 x_12_10 >= -1117
#
# _C1004: T_11_2 - T_12_2 - 1138 x_12_11 >= -1123
#
# _C1005: - T_12_2 + T_13_2 - 992 x_12_13 >= -989
#
# _C1006: - T_12_2 + T_14_2 - 1019 x_12_14 >= -1016
#
# _C1007: - T_12_2 + T_15_2 - 930 x_12_15 >= -927
#
# _C1008: - T_12_2 + T_16_2 - 957 x_12_16 >= -954
#
# _C1009: - T_12_2 + T_17_2 - 1023 x_12_17 >= -1020
#
# _C1010: - T_12_2 + T_18_2 - 1103 x_12_18 >= -1088
#
# _C1011: - T_12_2 + T_19_2 - 1094 x_12_19 >= -1079
#
# _C1012: T_0_2 - T_13_2 - 976 x_13_0 >= -961
#
# _C1013: - T_13_2 + T_1_2 - 869 x_13_1 >= -866
#
# _C1014: - T_13_2 + T_2_2 - 901 x_13_2 >= -898
#
# _C1015: - T_13_2 + T_3_2 - 957 x_13_3 >= -942
#
# _C1016: - T_13_2 + T_4_2 - 822 x_13_4 >= -819
#
# _C1017: - T_13_2 + T_5_2 - 952 x_13_5 >= -937
#
# _C1018: - T_13_2 + T_6_2 - 850 x_13_6 >= -847
#
# _C1019: - T_13_2 + T_7_2 - 960 x_13_7 >= -945
#
# _C1020: - T_13_2 + T_8_2 - 934 x_13_8 >= -919
#
# _C1021: - T_13_2 + T_9_2 - 926 x_13_9 >= -911
#
# _C1022: T_10_2 - T_13_2 - 929 x_13_10 >= -914
#
# _C1023: T_11_2 - T_13_2 - 935 x_13_11 >= -920
#
# _C1024: T_12_2 - T_13_2 - 789 x_13_12 >= -786
#
# _C1025: - T_13_2 + T_14_2 - 816 x_13_14 >= -813
#
# ...
# 0 <= y_18_2 <= 1 Integer
# 0 <= y_19_0 <= 1 Integer
# 0 <= y_19_1 <= 1 Integer
# 0 <= y_19_2 <= 1 Integer
# 0 <= y_1_0 <= 1 Integer
# 0 <= y_1_1 <= 1 Integer
# 0 <= y_1_2 <= 1 Integer
# 0 <= y_2_0 <= 1 Integer
# 0 <= y_2_1 <= 1 Integer
# 0 <= y_2_2 <= 1 Integer
# 0 <= y_3_0 <= 1 Integer
# 0 <= y_3_1 <= 1 Integer
# 0 <= y_3_2 <= 1 Integer
# 0 <= y_4_0 <= 1 Integer
# 0 <= y_4_1 <= 1 Integer
# 0 <= y_4_2 <= 1 Integer
# 0 <= y_5_0 <= 1 Integer
# 0 <= y_5_1 <= 1 Integer
# 0 <= y_5_2 <= 1 Integer
# 0 <= y_6_0 <= 1 Integer
# 0 <= y_6_1 <= 1 Integer
# 0 <= y_6_2 <= 1 Integer
# 0 <= y_7_0 <= 1 Integer
# 0 <= y_7_1 <= 1 Integer
# 0 <= y_7_2 <= 1 Integer
# 0 <= y_8_0 <= 1 Integer
# 0 <= y_8_1 <= 1 Integer
# 0 <= y_8_2 <= 1 Integer
# 0 <= y_9_0 <= 1 Integer
# 0 <= y_9_1 <= 1 Integer
# 0 <= y_9_2 <= 1 Integer
# z free Continuous
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/mtds/anaconda3/lib/python3.11/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4112ba3a4d7d4384bb5558c25e156585-pulp.mps sec 60 timeMode elapsed branch printingOptions all solution /tmp/4112ba3a4d7d4384bb5558c25e156585-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 2849 COLUMNS
# At line 13395 RHS
# At line 16240 BOUNDS
# At line 16842 ENDATA
# Problem MODEL has 2844 rows, 681 columns and 9664 elements
# Coin0008I MODEL read with 0 errors
# seconds was changed from 1e+100 to 60
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.01 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 75 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 38 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2274 rows, 681 columns (440 integer (440 of which binary)) and 7497 elements
# Cbc0038I Initial state - 40 integers unsatisfied sum - 20
# Cbc0038I Pass   1: suminf.   18.00000 (36) obj. 1020 iterations 94
# Cbc0038I Pass   2: suminf.   18.00000 (36) obj. 1020 iterations 42
# Cbc0038I Pass   3: suminf.   18.00000 (36) obj. 1020 iterations 38
# Cbc0038I Pass   4: suminf.   18.00000 (36) obj. 1020 iterations 38
# Cbc0038I Pass   5: suminf.   18.00000 (36) obj. 1020 iterations 14
# Cbc0038I Pass   6: suminf.   18.00000 (36) obj. 1020 iterations 19
# Cbc0038I Pass   7: suminf.   18.00000 (36) obj. 1020 iterations 41
# Cbc0038I Pass   8: suminf.   18.00000 (36) obj. 1020 iterations 51
# Cbc0038I Pass   9: suminf.   18.00000 (36) obj. 1020 iterations 31
# Cbc0038I Pass  10: suminf.   18.00000 (36) obj. 1020 iterations 32
# Cbc0038I Pass  11: suminf.   18.00000 (36) obj. 1020 iterations 38
# Cbc0038I Pass  12: suminf.   18.00000 (36) obj. 1020 iterations 61
# Cbc0038I Pass  13: suminf.   18.00000 (36) obj. 1020 iterations 37
# Cbc0038I Pass  14: suminf.   18.00000 (36) obj. 1020 iterations 33
# Cbc0038I Pass  15: suminf.   18.00000 (36) obj. 1020 iterations 39
# Cbc0038I Pass  16: suminf.   18.00000 (36) obj. 1020 iterations 34
# Cbc0038I Pass  17: suminf.   18.00000 (36) obj. 1020 iterations 18
# Cbc0038I Pass  18: suminf.   18.00000 (36) obj. 1020 iterations 39
# Cbc0038I Pass  19: suminf.   18.00000 (36) obj. 1020 iterations 33
# Cbc0038I Pass  20: suminf.   18.00000 (36) obj. 1020 iterations 43
# Cbc0038I Pass  21: suminf.   18.00000 (36) obj. 1020 iterations 33
# Cbc0038I Pass  22: suminf.   18.00000 (36) obj. 1020 iterations 31
# Cbc0038I Pass  23: suminf.   18.00000 (36) obj. 1020 iterations 28
# Cbc0038I Pass  24: suminf.   18.00000 (36) obj. 1020 iterations 33
# Cbc0038I Pass  25: suminf.   18.00000 (36) obj. 1020 iterations 47
# Cbc0038I Pass  26: suminf.   18.00000 (36) obj. 1020 iterations 47
# Cbc0038I Pass  27: suminf.   18.00000 (36) obj. 1020 iterations 46
# Cbc0038I Pass  28: suminf.   18.00000 (36) obj. 1020 iterations 22
# Cbc0038I Pass  29: suminf.   18.00000 (36) obj. 1020 iterations 49
# Cbc0038I Pass  30: suminf.   18.00000 (36) obj. 1020 iterations 37
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 389 integers at bound fixed and 147 continuous
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 428 rows 51 columns
# Cbc0038I Mini branch and bound did not improve solution (0.25 seconds)
# Cbc0038I After 0.25 seconds - Feasibility pump exiting - took 0.16 seconds
# Cbc0031I 5 added rows had average density of 38.4
# Cbc0013I At root node, 5 cuts changed objective from 0 to 0 in 10 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 57 row cuts average 48.3 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 133 row cuts average 16.9 elements, 0 column cuts (0 active)  in 0.026 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 0 (0.62 seconds)
# Cbc0010I After 100 nodes, 58 on tree, 1e+50 best solution, best possible 0 (3.26 seconds)
# Cbc0004I Integer solution of 6710 found after 3922 iterations and 132 nodes (3.38 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 797 rows 349 columns
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 800 rows 348 columns
# Cbc0010I After 200 nodes, 81 on tree, 6710 best solution, best possible 0 (3.87 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 870 rows 363 columns
# Cbc0010I After 300 nodes, 130 on tree, 6710 best solution, best possible 0 (4.42 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 849 rows 355 columns
# Cbc0010I After 400 nodes, 185 on tree, 6710 best solution, best possible 0 (4.91 seconds)
# Cbc0012I Integer solution of 2100 found by rounding after 11538 iterations and 445 nodes (5.07 seconds)
# Cbc0004I Integer solution of 1940 found after 11781 iterations and 470 nodes (5.15 seconds)
# Cbc0004I Integer solution of 1890 found after 11880 iterations and 484 nodes (5.20 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 728 rows 324 columns
# Cbc0010I After 500 nodes, 125 on tree, 1890 best solution, best possible 0 (5.36 seconds)
# Cbc0010I After 600 nodes, 126 on tree, 1890 best solution, best possible 0 (5.72 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 790 rows 346 columns
# Cbc0010I After 700 nodes, 176 on tree, 1890 best solution, best possible 0 (6.30 seconds)
# Cbc0010I After 800 nodes, 227 on tree, 1890 best solution, best possible 0 (7.16 seconds)
# Cbc0010I After 900 nodes, 229 on tree, 1890 best solution, best possible 0 (7.83 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 761 rows 335 columns
# Cbc0010I After 1000 nodes, 239 on tree, 1890 best solution, best possible 0 (8.42 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 762 rows 337 columns
# Cbc0010I After 1100 nodes, 242 on tree, 1890 best solution, best possible 0 (9.09 seconds)
# Cbc0016I Integer solution of 1850 found by strong branching after 30365 iterations and 1179 nodes (10.03 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 690 rows 316 columns
# Cbc0010I After 1200 nodes, 230 on tree, 1850 best solution, best possible 0 (10.84 seconds)
# Cbc0016I Integer solution of 1790 found by strong branching after 33003 iterations and 1204 nodes (10.89 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 640 rows 298 columns
# Cbc0010I After 1300 nodes, 165 on tree, 1790 best solution, best possible 0 (12.46 seconds)
# Cbc0010I After 1400 nodes, 174 on tree, 1790 best solution, best possible 0 (13.30 seconds)
# Cbc0010I After 1500 nodes, 164 on tree, 1790 best solution, best possible 0 (13.97 seconds)
# Cbc0010I After 1600 nodes, 186 on tree, 1790 best solution, best possible 0 (15.26 seconds)
# Cbc0012I Integer solution of 1750 found by rounding after 47239 iterations and 1672 nodes (15.90 seconds)
# Cbc0010I After 1700 nodes, 131 on tree, 1750 best solution, best possible 0 (16.11 seconds)
# Cbc0010I After 1800 nodes, 132 on tree, 1750 best solution, best possible 0 (16.78 seconds)
# Cbc0010I After 1900 nodes, 133 on tree, 1750 best solution, best possible 0 (17.48 seconds)
# Cbc0010I After 2000 nodes, 139 on tree, 1750 best solution, best possible 0 (18.24 seconds)
# Cbc0010I After 2100 nodes, 138 on tree, 1750 best solution, best possible 0 (19.21 seconds)
# Cbc0010I After 2200 nodes, 154 on tree, 1750 best solution, best possible 0 (20.52 seconds)
# Cbc0010I After 2300 nodes, 159 on tree, 1750 best solution, best possible 0 (22.13 seconds)
# Cbc0016I Integer solution of 1710 found by strong branching after 78728 iterations and 2367 nodes (23.08 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 843 rows 364 columns
# Cbc0010I After 2400 nodes, 25 on tree, 1710 best solution, best possible 0 (23.88 seconds)
# Cbc0010I After 2500 nodes, 68 on tree, 1710 best solution, best possible 0 (24.62 seconds)
# Cbc0012I Integer solution of 1420 found by rounding after 85213 iterations and 2598 nodes (25.21 seconds)
# Cbc0010I After 2600 nodes, 114 on tree, 1420 best solution, best possible 0 (25.21 seconds)
# Cbc0004I Integer solution of 820 found after 85264 iterations and 2603 nodes (25.22 seconds)
# Cbc0012I Integer solution of 810 found by rounding after 85704 iterations and 2635 nodes (25.34 seconds)
# Cbc0016I Integer solution of 600 found by strong branching after 85837 iterations and 2647 nodes (25.39 seconds)
# Cbc0010I After 2700 nodes, 84 on tree, 600 best solution, best possible 0 (25.73 seconds)
# Cbc0010I After 2800 nodes, 116 on tree, 600 best solution, best possible 0 (26.34 seconds)
# Cbc0010I After 2900 nodes, 139 on tree, 600 best solution, best possible 0 (26.98 seconds)
# Cbc0010I After 3000 nodes, 167 on tree, 600 best solution, best possible 0 (27.73 seconds)
# Cbc0010I After 3100 nodes, 209 on tree, 600 best solution, best possible 0 (28.69 seconds)
# Cbc0010I After 3200 nodes, 256 on tree, 600 best solution, best possible 0 (29.48 seconds)
# Cbc0012I Integer solution of 560 found by rounding after 102361 iterations and 3217 nodes (29.57 seconds)
# Cbc0004I Integer solution of 350 found after 102435 iterations and 3224 nodes (29.60 seconds)
# Cbc0010I After 3300 nodes, 139 on tree, 350 best solution, best possible 0 (30.92 seconds)
# Cbc0010I After 3400 nodes, 142 on tree, 350 best solution, best possible 0 (31.88 seconds)
# Cbc0004I Integer solution of 330 found after 110251 iterations and 3418 nodes (31.97 seconds)
# Cbc0010I After 3500 nodes, 132 on tree, 330 best solution, best possible 0 (32.65 seconds)
# Cbc0010I After 3600 nodes, 145 on tree, 330 best solution, best possible 0 (33.56 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 840 rows 362 columns
# Cbc0010I After 3700 nodes, 156 on tree, 330 best solution, best possible 0 (34.47 seconds)
# Cbc0010I After 3800 nodes, 156 on tree, 330 best solution, best possible 0 (35.18 seconds)
# Cbc0010I After 3900 nodes, 154 on tree, 330 best solution, best possible 0 (36.14 seconds)
# Cbc0010I After 4000 nodes, 163 on tree, 330 best solution, best possible 0 (36.93 seconds)
# Cbc0010I After 4100 nodes, 153 on tree, 330 best solution, best possible 0 (37.95 seconds)
# Cbc0010I After 4200 nodes, 153 on tree, 330 best solution, best possible 0 (38.72 seconds)
# Cbc0010I After 4300 nodes, 157 on tree, 330 best solution, best possible 0 (39.94 seconds)
# Cbc0010I After 4400 nodes, 169 on tree, 330 best solution, best possible 0 (40.67 seconds)
# Cbc0010I After 4500 nodes, 164 on tree, 330 best solution, best possible 0 (41.32 seconds)
# Cbc0010I After 4600 nodes, 166 on tree, 330 best solution, best possible 0 (42.19 seconds)
# Cbc0010I After 4700 nodes, 169 on tree, 330 best solution, best possible 0 (42.82 seconds)
# Cbc0010I After 4800 nodes, 169 on tree, 330 best solution, best possible 0 (43.47 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 708 rows 322 columns
# Cbc0010I After 4900 nodes, 173 on tree, 330 best solution, best possible 0 (44.23 seconds)
# Cbc0010I After 5000 nodes, 177 on tree, 330 best solution, best possible 0 (45.23 seconds)
# Cbc0010I After 5100 nodes, 169 on tree, 330 best solution, best possible 0 (45.94 seconds)
# Cbc0010I After 5200 nodes, 164 on tree, 330 best solution, best possible 0 (46.52 seconds)
# Cbc0010I After 5300 nodes, 161 on tree, 330 best solution, best possible 0 (47.16 seconds)
# Cbc0010I After 5400 nodes, 156 on tree, 330 best solution, best possible 0 (48.10 seconds)
# Cbc0010I After 5500 nodes, 148 on tree, 330 best solution, best possible 0 (49.06 seconds)
# Cbc0010I After 5600 nodes, 148 on tree, 330 best solution, best possible 0 (49.81 seconds)
# Cbc0010I After 5700 nodes, 144 on tree, 330 best solution, best possible 0 (50.39 seconds)
# Cbc0010I After 5800 nodes, 143 on tree, 330 best solution, best possible 0 (50.90 seconds)
# Cbc0010I After 5900 nodes, 144 on tree, 330 best solution, best possible 0 (51.54 seconds)
# Cbc0038I Full problem 2274 rows 681 columns, reduced to 902 rows 374 columns
# Cbc0010I After 6000 nodes, 131 on tree, 330 best solution, best possible 0 (52.26 seconds)
# Cbc0010I After 6100 nodes, 126 on tree, 330 best solution, best possible 0 (53.33 seconds)
# Cbc0010I After 6200 nodes, 117 on tree, 330 best solution, best possible 0 (54.39 seconds)
# Cbc0010I After 6300 nodes, 118 on tree, 330 best solution, best possible 0 (55.29 seconds)
# Cbc0010I After 6400 nodes, 107 on tree, 330 best solution, best possible 0 (55.96 seconds)
# Cbc0010I After 6500 nodes, 106 on tree, 330 best solution, best possible 0 (56.88 seconds)
# Cbc0010I After 6600 nodes, 109 on tree, 330 best solution, best possible 0 (57.58 seconds)
# Cbc0010I After 6700 nodes, 110 on tree, 330 best solution, best possible 0 (58.36 seconds)
# Cbc0012I Integer solution of 310 found by rounding after 220212 iterations and 6711 nodes (58.40 seconds)
# Cbc0010I After 6800 nodes, 103 on tree, 310 best solution, best possible 0 (59.42 seconds)
# Cbc0020I Exiting on maximum time
# Cbc0005I Partial search - best objective 310 (best possible 0), took 227357 iterations and 6832 nodes (59.96 seconds)
# Cbc0032I Strong branching done 21642 times (237055 iterations), fathomed 737 nodes and fixed 4023 variables
# Cbc0035I Maximum depth 83, 1195 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.045 seconds)
# Gomory was tried 1076 times and created 5009 cuts of which 0 were active after adding rounds of cuts (1.646 seconds)
# Knapsack was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# Clique was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# MixedIntegerRounding2 was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# FlowCover was tried 10 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# TwoMirCuts was tried 10 times and created 133 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
#
# Result - Stopped on time limit
#
# Objective value:                310.00000000
# Lower bound:                    0.000
# Gap:                            inf
# Enumerated nodes:               6832
# Total iterations:               227357
# Time (CPU seconds):             57.66
# Time (Wallclock seconds):       59.99
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       57.67   (Wallclock seconds):       60.00

# %% [markdown]
# Affichage du résultat de l'optimisation

# %%
sc = ' (scenarios "{}")'.format(scenario_set_name.split(os.sep)[1][:-4])
print('Instance "{}"{}: {} planes'.format(
    instance_name.split(os.sep)[1][:-4], sc, len(P)))
print('Status: ', LpStatus[problem.status])
print('Objective: ', problem.objective.value())
# Out:
# Instance "airland3" (scenarios "airland3_3"): 20 planes
# Status:  Optimal
# Objective:  310.0

# %% [markdown]
# Récupération des valeurs des variables et affichage de la solution

# %%
print('Affectations: ')
vars = problem.variablesDict()
print(vars)
y = []
for i in P:
    for r in R:
        if vars['y_{}_{}'.format(i, r)].roundedValue():
            y.append(r)
Q = range(len(p))
t = [[round(vars['T_{}_{}'.format(i, s)].value()) for s in Q] for i in P]
for q in Q:
    print('  Scenario {}: '.format(q))
    for i in P:
        print('    Plane {} appearing at {}, landing at t={} on runway {} '
                '({}, [{}, {}]).'.format(P[i], A[i], t[i][q], y[i],
                                        T[i][q], E[i][q], L[i][q]))
# Out:
# Affectations:
# {'z': z, 'L_0_0': L_0_0, 'E_0_0': E_0_0, 'L_1_0': L_1_0, 'E_1_0': E_1_0, 'L_2_0': L_2_0, 'E_2_0': E_2_0, 'L_3_0': L_3_0, 'E_3_0': E_3_0, 'L_4_0': L_4_0, 'E_4_0': E_4_0, 'L_5_0': L_5_0, 'E_5_0': E_5_0, 'L_6_0': L_6_0, 'E_6_0': E_6_0, 'L_7_0': L_7_0, 'E_7_0': E_7_0, 'L_8_0': L_8_0, 'E_8_0': E_8_0, 'L_9_0': L_9_0, 'E_9_0': E_9_0, 'L_10_0': L_10_0, 'E_10_0': E_10_0, 'L_11_0': L_11_0, 'E_11_0': E_11_0, 'L_12_0': L_12_0, 'E_12_0': E_12_0, 'L_13_0': L_13_0, 'E_13_0': E_13_0, 'L_14_0': L_14_0, 'E_14_0': E_14_0, 'L_15_0': L_15_0, 'E_15_0': E_15_0, 'L_16_0': L_16_0, 'E_16_0': E_16_0, 'L_17_0': L_17_0, 'E_17_0': E_17_0, 'L_18_0': L_18_0, 'E_18_0': E_18_0, 'L_19_0': L_19_0, 'E_19_0': E_19_0, 'L_0_1': L_0_1, 'E_0_1': E_0_1, 'L_1_1': L_1_1, 'E_1_1': E_1_1, 'L_2_1': L_2_1, 'E_2_1': E_2_1, 'L_3_1': L_3_1, 'E_3_1': E_3_1, 'L_4_1': L_4_1, 'E_4_1': E_4_1, 'L_5_1': L_5_1, 'E_5_1': E_5_1, 'L_6_1': L_6_1, 'E_6_1': E_6_1, 'L_7_1': L_7_1, 'E_7_1': E_7_1, 'L_8_1': L_8_1, 'E_8_1': E_8_1, 'L_9_1': L_9_1, 'E_9_1': E_9_1, 'L_10_1': L_10_1, 'E_10_1': E_10_1, 'L_11_1': L_11_1, 'E_11_1': E_11_1, 'L_12_1': L_12_1, 'E_12_1': E_12_1, 'L_13_1': L_13_1, 'E_13_1': E_13_1, 'L_14_1': L_14_1, 'E_14_1': E_14_1, 'L_15_1': L_15_1, 'E_15_1': E_15_1, 'L_16_1': L_16_1, 'E_16_1': E_16_1, 'L_17_1': L_17_1, 'E_17_1': E_17_1, 'L_18_1': L_18_1, 'E_18_1': E_18_1, 'L_19_1': L_19_1, 'E_19_1': E_19_1, 'L_0_2': L_0_2, 'E_0_2': E_0_2, 'L_1_2': L_1_2, 'E_1_2': E_1_2, 'L_2_2': L_2_2, 'E_2_2': E_2_2, 'L_3_2': L_3_2, 'E_3_2': E_3_2, 'L_4_2': L_4_2, 'E_4_2': E_4_2, 'L_5_2': L_5_2, 'E_5_2': E_5_2, 'L_6_2': L_6_2, 'E_6_2': E_6_2, 'L_7_2': L_7_2, 'E_7_2': E_7_2, 'L_8_2': L_8_2, 'E_8_2': E_8_2, 'L_9_2': L_9_2, 'E_9_2': E_9_2, 'L_10_2': L_10_2, 'E_10_2': E_10_2, 'L_11_2': L_11_2, 'E_11_2': E_11_2, 'L_12_2': L_12_2, 'E_12_2': E_12_2, 'L_13_2': L_13_2, 'E_13_2': E_13_2, 'L_14_2': L_14_2, 'E_14_2': E_14_2, 'L_15_2': L_15_2, 'E_15_2': E_15_2, 'L_16_2': L_16_2, 'E_16_2': E_16_2, 'L_17_2': L_17_2, 'E_17_2': E_17_2, 'L_18_2': L_18_2, 'E_18_2': E_18_2, 'L_19_2': L_19_2, 'E_19_2': E_19_2, 'L_0_3': L_0_3, 'E_0_3': E_0_3, 'L_1_3': L_1_3, 'E_1_3': E_1_3, 'L_2_3': L_2_3, 'E_2_3': E_2_3, 'L_3_3': L_3_3, 'E_3_3': E_3_3, 'L_4_3': L_4_3, 'E_4_3': E_4_3, 'L_5_3': L_5_3, 'E_5_3': E_5_3, 'L_6_3': L_6_3, 'E_6_3': E_6_3, 'L_7_3': L_7_3, 'E_7_3': E_7_3, 'L_8_3': L_8_3, 'E_8_3': E_8_3, 'L_9_3': L_9_3, 'E_9_3': E_9_3, 'L_10_3': L_10_3, 'E_10_3': E_10_3, 'L_11_3': L_11_3, 'E_11_3': E_11_3, 'L_12_3': L_12_3, 'E_12_3': E_12_3, 'L_13_3': L_13_3, 'E_13_3': E_13_3, 'L_14_3': L_14_3, 'E_14_3': E_14_3, 'L_15_3': L_15_3, 'E_15_3': E_15_3, 'L_16_3': L_16_3, 'E_16_3': E_16_3, 'L_17_3': L_17_3, 'E_17_3': E_17_3, 'L_18_3': L_18_3, 'E_18_3': E_18_3, 'L_19_3': L_19_3, 'E_19_3': E_19_3, 'T_1_0': T_1_0, 'T_0_0': T_0_0, 'x_0_1': x_0_1, 'T_2_0': T_2_0, 'x_0_2': x_0_2, 'T_3_0': T_3_0, 'x_0_3': x_0_3, 'T_4_0': T_4_0, 'x_0_4': x_0_4, 'T_5_0': T_5_0, 'x_0_5': x_0_5, 'T_6_0': T_6_0, 'x_0_6': x_0_6, 'T_7_0': T_7_0, 'x_0_7': x_0_7, 'T_8_0': T_8_0, 'x_0_8': x_0_8, 'T_9_0': T_9_0, 'x_0_9': x_0_9, 'T_10_0': T_10_0, 'x_0_10': x_0_10, 'T_11_0': T_11_0, 'x_0_11': x_0_11, 'T_12_0': T_12_0, 'x_0_12': x_0_12, 'T_13_0': T_13_0, 'x_0_13': x_0_13, 'T_14_0': T_14_0, 'x_0_14': x_0_14, 'T_15_0': T_15_0, 'x_0_15': x_0_15, 'T_16_0': T_16_0, 'x_0_16': x_0_16, 'T_17_0': T_17_0, 'x_0_17': x_0_17, 'T_18_0': T_18_0, 'x_0_18': x_0_18, 'T_19_0': T_19_0, 'x_0_19': x_0_19, 'x_1_0': x_1_0, 'x_1_2': x_1_2, 'x_1_3': x_1_3, 'x_1_4': x_1_4, 'x_1_5': x_1_5, 'x_1_6': x_1_6, 'x_1_7': x_1_7, 'x_1_8': x_1_8, 'x_1_9': x_1_9, 'x_1_10': x_1_10, 'x_1_11': x_1_11, 'x_1_12': x_1_12, 'x_1_13': x_1_13, 'x_1_14': x_1_14, 'x_1_15': x_1_15, 'x_1_16': x_1_16, 'x_1_17': x_1_17, 'x_1_18': x_1_18, 'x_1_19': x_1_19, 'x_2_0': x_2_0, 'x_2_1': x_2_1, 'x_2_3': x_2_3, 'x_2_4': x_2_4, 'x_2_5': x_2_5, 'x_2_6': x_2_6, 'x_2_7': x_2_7, 'x_2_8': x_2_8, 'x_2_9': x_2_9, 'x_2_10': x_2_10, 'x_2_11': x_2_11, 'x_2_12': x_2_12, 'x_2_13': x_2_13, 'x_2_14': x_2_14, 'x_2_15': x_2_15, 'x_2_16': x_2_16, 'x_2_17': x_2 ...
#   Scenario 0:
#     Plane 0 appearing at 0, landing at t=93 on runway 1 (93, [80, 391]).
#     Plane 1 appearing at 82, landing at t=192 on runway 0 (175, [149, 655]).
#     Plane 2 appearing at 59, landing at t=162 on runway 1 (150, [131, 578]).
#     Plane 3 appearing at 28, landing at t=122 on runway 0 (122, [104, 504]).
#     Plane 4 appearing at 126, landing at t=210 on runway 1 (210, [189, 847]).
#     Plane 5 appearing at 20, landing at t=111 on runway 0 (111, [96, 472]).
#     Plane 6 appearing at 110, landing at t=207 on runway 1 (219, [188, 878]).
#     Plane 7 appearing at 23, landing at t=110 on runway 1 (110, [99, 443]).
#     Plane 8 appearing at 42, landing at t=132 on runway 0 (132, [120, 514]).
#     Plane 9 appearing at 42, landing at t=140 on runway 0 (136, [120, 537]).
#     Plane 10 appearing at 57, landing at t=152 on runway 0 (152, [127, 525]).
#     Plane 11 appearing at 39, landing at t=141 on runway 1 (141, [118, 578]).
#     Plane 12 appearing at 186, landing at t=323 on runway 0 (323, [271, 1217]).
#     Plane 13 appearing at 175, landing at t=272 on runway 1 (272, [240, 1052]).
#     Plane 14 appearing at 139, landing at t=280 on runway 0 (280, [235, 999]).
#     Plane 15 appearing at 235, landing at t=339 on runway 0 (339, [308, 1540]).
#     Plane 16 appearing at 194, landing at t=342 on runway 1 (342, [285, 1317]).
#     Plane 17 appearing at 162, landing at t=269 on runway 1 (282, [243, 1087]).
#     Plane 18 appearing at 69, landing at t=160 on runway 0 (160, [144, 676]).
#     Plane 19 appearing at 76, landing at t=177 on runway 1 (177, [147, 693]).
#   Scenario 1:
#     Plane 0 appearing at 0, landing at t=82 on runway 1 (82, [72, 346]).
#     Plane 1 appearing at 82, landing at t=185 on runway 0 (178, [149, 686]).
#     Plane 2 appearing at 59, landing at t=146 on runway 1 (143, [122, 504]).
#     Plane 3 appearing at 28, landing at t=118 on runway 0 (105, [93, 409]).
#     Plane 4 appearing at 126, landing at t=244 on runway 1 (244, [212, 995]).
#     Plane 5 appearing at 20, landing at t=110 on runway 0 (114, [101, 439]).
#     Plane 6 appearing at 110, landing at t=206 on runway 1 (206, [182, 896]).
#     Plane 7 appearing at 23, landing at t=116 on runway 1 (116, [100, 476]).
#     Plane 8 appearing at 42, landing at t=126 on runway 0 (126, [112, 492]).
#     Plane 9 appearing at 42, landing at t=142 on runway 0 (146, [123, 601]).
#     Plane 10 appearing at 57, landing at t=150 on runway 0 (150, [127, 559]).
#     Plane 11 appearing at 39, landing at t=131 on runway 1 (141, [124, 519]).
#     Plane 12 appearing at 186, landing at t=295 on runway 0 (286, [253, 1078]).
#     Plane 13 appearing at 175, landing at t=292 on runway 1 (292, [256, 1112]).
#     Plane 14 appearing at 139, landing at t=277 on runway 0 (277, [234, 967]).
#     Plane 15 appearing at 235, landing at t=346 on runway 0 (346, [295, 1310]).
#     Plane 16 appearing at 194, landing at t=304 on runway 1 (304, [264, 1086]).
#     Plane 17 appearing at 162, landing at t=289 on runway 1 (291, [248, 1047]).
#     Plane 18 appearing at 69, landing at t=170 on runway 0 (170, [146, 647]).
#     Plane 19 appearing at 76, landing at t=161 on runway 1 (161, [142, 586]).
#   Scenario 2:
#     Plane 0 appearing at 0, landing at t=95 on runway 1 (95, [81, 349]).
#     Plane 1 appearing at 82, landing at t=183 on runway 0 (180, [155, 698]).
#     Plane 2 appearing at 59, landing at t=144 on runway 1 (144, [129, 524]).
#     Plane 3 appearing at 28, landing at t=120 on runway 0 (123, [110, 537]).
#     Plane 4 appearing at 126, landing at t=231 on runway 1 (231, [199, 982]).
#     Plane 5 appearing at 20, landing at t=99 on runway 0 (99, [86, 427]).
#     Plane 6 appearing at 110, landing at t=222 on runway 1 (222, [196, 957]).
#     Plane 7 appearing at 23, landing at t=107 on runway 1 (107, [90, 393]).
#     Plane 8 appearing at 42, landing at t=128 on runway 0 (128, [113, 565]).
#     Plane 9 appearing at 42, landing at t=138 on runway 0 (148, [126, 540]).
#     Plane 10 appearing at 57, landing at t=146 on runway 0 (146, [131, 539]).
#     Plane 11 appearing at 39, landing at t=116 on runway 1 (116, [104, 485]).
#     Plane 12 appearing at 186, landing at t=339 on runway 0 (267, [236, 1136]).
#     Plane 13 appearing at 175, landing at t=311 on runway 1 (311, [275, 1370]).
#     Plane 14 appearing at 139, landing at t=232 on runway 0 (232, [207, 897]).
#     Plane 15 appearing at 235, landing at t=385 on runway 0 (385, [334, 1620]).
#     Plane 16 appearing at 194, landing at t=330 on runway 1 (330, [275, 1274]).
#     Plane 17 appearing at 162, landing at t=297 on runway 1 (297, [258, 1038]).
#     Plane 18 appearing at 69, landing at t=161 on runway 0 (161, [135, 555]).
#     Plane 19 appearing at 76, landing at t=168 on runway 1 (168, [151, 633]).
#   Scenario 3:
#     Plane 0 appearing at 0, landing at t=82 on runway 1 (82, [75, 486]).
#     Plane 1 appearing at 82, landing at t=197 on runway 0 (197, [157, 628]).
#     Plane 2 appearing at 59, landing at t=154 on runway 1 (160, [134, 561]).
#     Plane 3 appearing at 28, landing at t=117 on runway 0 (117, [103, 565]).
#     Plane 4 appearing at 126, landing at t=261 on runway 1 (261, [201, 735]).
#     Plane 5 appearing at 20, landing at t=106 on runway 0 (106, [95, 524]).
#     Plane 6 appearing at 110, landing at t=229 on runway 1 (229, [185, 664]).
#     Plane 7 appearing at 23, landing at t=108 on runway 1 (108, [98, 523]).
#     Plane 8 appearing at 42, landing at t=125 on runway 0 (132, [117, 578]).
#     Plane 9 appearing at 42, landing at t=133 on runway 0 (130, [117, 569]).
#     Plane 10 appearing at 57, landing at t=149 on runway 0 (149, [132, 615]).
#     Plane 11 appearing at 39, landing at t=126 on runway 1 (126, [114, 551]).
#     Plane 12 appearing at 186, landing at t=336 on runway 0 (336, [261, 834]).
#     Plane 13 appearing at 175, landing at t=316 on runway 1 (316, [250, 790]).
#     Plane 14 appearing at 139, landing at t=258 on runway 0 (258, [214, 688]).
#     Plane 15 appearing at 235, landing at t=409 on runway 0 (409, [310, 967]).
#     Plane 16 appearing at 194, landing at t=338 on runway 1 (338, [269, 818]).
#     Plane 17 appearing at 162, landing at t=287 on runway 1 (287, [237, 726]).
#     Plane 18 appearing at 69, landing at t=160 on runway 0 (160, [144, 607]).
#     Plane 19 appearing at 76, landing at t=169 on runway 1 (169, [151, 624]).

# %% [markdown]
# Vérification de la validité de solution et affichage de la valeur de l'objectif pour chaque scénario

# %%
# Verify for each scenario:
verif = True
for q in Q:
    u = ''
    c, w = verifier.verify(t, y, E, T, L, S, G, H, q)
    print('Scenario {}{}: '.format(q, u), end='')
    print('Ok (obj. = {})'.format(w) if c else w)
    verif = verif and c
# Out:
# i=0 diff=0
# i=1 diff=17
# i=2 diff=12
# i=3 diff=0
# i=4 diff=0
# i=5 diff=0
# i=6 diff=-12
# i=7 diff=0
# i=8 diff=0
# i=9 diff=4
# i=10 diff=0
# i=11 diff=0
# i=12 diff=0
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=-13
# i=18 diff=0
# i=19 diff=0
# Scenario 0: Ok (obj. = 660.0)
# i=0 diff=0
# i=1 diff=7
# i=2 diff=3
# i=3 diff=13
# i=4 diff=0
# i=5 diff=-4
# i=6 diff=0
# i=7 diff=0
# i=8 diff=0
# i=9 diff=-4
# i=10 diff=0
# i=11 diff=-10
# i=12 diff=9
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=-2
# i=18 diff=0
# i=19 diff=0
# Scenario 1: Ok (obj. = 1140.0)
# i=0 diff=0
# i=1 diff=3
# i=2 diff=0
# i=3 diff=-3
# i=4 diff=0
# i=5 diff=0
# i=6 diff=0
# i=7 diff=0
# i=8 diff=0
# i=9 diff=-10
# i=10 diff=0
# i=11 diff=0
# i=12 diff=72
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=0
# i=18 diff=0
# i=19 diff=0
# Scenario 2: Ok (obj. = 1140.0)
# i=0 diff=0
# i=1 diff=0
# i=2 diff=-6
# i=3 diff=0
# i=4 diff=0
# i=5 diff=0
# i=6 diff=0
# i=7 diff=0
# i=8 diff=-7
# i=9 diff=3
# i=10 diff=0
# i=11 diff=0
# i=12 diff=0
# i=13 diff=0
# i=14 diff=0
# i=15 diff=0
# i=16 diff=0
# i=17 diff=0
# i=18 diff=0
# i=19 diff=0
# Scenario 3: Ok (obj. = 360.0)
